# %%
import os
import pandas as pd
import regex as re
import spacy
from collections import defaultdict, Counter
import numpy as np

# %%
from spacy.lang.pl import Polish
nlp = Polish()
tokenizer = nlp.tokenizer

# %%
directory = 'ustawy'
def load_bills(directory):
    bills = {}
    for file_name in os.listdir(directory):
        path = os.path.join(directory, file_name)
        if os.path.isfile(path):
            with open(path, encoding='utf-8') as f:
                content = f.read()
                content = content.replace("\xa0", " ").replace("\xad", "")
                content = re.sub(r"\s+", " ", content)
                content = content.lower()
                bills[file_name] = content
    return bills
bills = load_bills(directory)

# %% [markdown]
# ### Use SpaCy tokenizer API to tokenize the text from the law corpus.

# %%
tokenized_bills = {name: [token.text for token in tokenizer(content)] for name, content in bills.items()}

# %%
tokenized_bills['2004_1264.txt']
# Out:
# [' ',
#  'dz.u',
#  '.',
#  'z',
#  '2004',
#  'r',
#  '.',
#  'nr',
#  '121',
#  ',',
#  'poz',
#  '.',
#  '1264',
#  'u',
#  's',
#  't',
#  'a',
#  'w',
#  'a',
#  'z',
#  'dnia',
#  '20',
#  'kwietnia',
#  '2004',
#  'r',
#  '.',
#  'o',
#  'zmianie',
#  'ustawy',
#  'o',
#  'emeryturach',
#  'i',
#  'rentach',
#  'z',
#  'funduszu',
#  'ubezpieczeń',
#  'społecznych',
#  'oraz',
#  'niektórych',
#  'innych',
#  'ustaw[1',
#  ']',
#  'art',
#  '.',
#  '1',
#  '.',
#  'w',
#  'ustawie',
#  'z',
#  'dnia',
#  '17',
#  'grudnia',
#  '1998',
#  'r',
#  '.',
#  'o',
#  'emeryturach',
#  'i',
#  'rentach',
#  'z',
#  'funduszu',
#  'ubezpieczeń',
#  'społecznych',
#  '(',
#  'dz.u',
#  '.',
#  'z',
#  '2004',
#  'r',
#  '.',
#  'nr',
#  '39',
#  ',',
#  'poz',
#  '.',
#  '353',
#  ')',
#  'wprowadza',
#  'się',
#  'następujące',
#  'zmiany',
#  ':',
#  '1',
#  ')',
#  'w',
#  'art',
#  '.',
#  '4',
#  ':',
#  'a',
#  ')',
#  'po',
#  'pkt',
#  '4',
#  'dodaje',
#  'się',
#  'pkt',
#  '4a',
#  'w',
#  'brzmieniu',
#  ':',
#  '"',
#  '4a',
#  ')',
#  'kwota',
#  'rocznej',
#  'podstawy',
#  'wymiaru',
#  'składek',
#  'na',
#  'ubezpieczenia',
#  'emerytalne',
#  'i',
#  'rentowe',
#  '-',
#  'roczną',
#  'podstawę',
#  'wymiaru',
#  'składek',
#  'na',
#  'ubezpieczenia',
#  'emerytalne',
#  'i',
#  'rentowe',
#  'w',
#  'danym',
#  'roku',
#  'kalendarzowym',
#  ',',
#  'określoną',
#  'w',
#  'art',
#  '.',
#  '19',
#  'ust',
#  '.',
#  '1',
#  'ustawy',
#  'z',
#  'dnia',
#  '13',
#  'października',
#  '1998',
#  'r',
#  '.',
#  'o',
#  'systemie',
#  'ubezpieczeń',
#  'społecznych',
#  '(',
#  'dz.u',
#  '.',
#  'nr',
#  '137',
#  ',',
#  'poz',
#  '.',
#  '887',
#  ',',
#  'z',
#  'późn',
#  '.',
#  'zm.)[2',
#  ']',
#  ',',
#  '"',
#  ',',
#  'b',
#  ')',
#  'pkt',
#  '6',
#  'otrzymuje',
#  'brzmienie',
#  ':',
#  '"',
#  '6',
#  ')',
#  'organ',
#  'rentowy',
#  '-',
#  'jednostkę',
#  'organizacyjną',
#  'zakładu',
#  ',',
#  'określoną',
#  'w',
#  'przepisach',
#  'o',
#  'systemie',
#  'ubezpieczeń',
#  'społecznych',
#  ',',
#  'właściwą',
#  'do',
#  'wydawania',
#  'decyzji',
#  'w',
#  'sprawach',
#  'świadczeń',
#  ',',
#  '"',
#  ';',
#  '2',
#  ')',
#  'w',
#  'art',
#  '.',
#  '5',
#  'ust',
#  '.',
#  '4',
#  'i',
#  '5',
#  'otrzymują',
#  'brzmienie',
#  ':',
#  '"',
#  '4',
#  '.',
#  'przy',
#  'ustalaniu',
#  'prawa',
#  'do',
#  'emerytury',
#  'lub',
#  'renty',
#  'dla',
#  ':',
#  '1',
#  ')',
#  'płatników',
#  'składek',
#  ',',
#  'zobowiązanych',
#  'do',
#  'opłacania',
#  'składek',
#  'na',
#  'własne',
#  'ubezpieczenia',
#  'emerytalne',
#  'i',
#  'rentowe',
#  ',',
#  '2',
#  ')',
#  'osób',
#  'współpracujących',
#  'z',
#  'osobami',
#  'prowadzącymi',
#  'pozarolniczą',
#  'działalność',
#  '-',
#  'nie',
#  'uwzględnia',
#  'się',
#  'okresu',
#  ',',
#  'za',
#  'który',
#  'nie',
#  'zostały',
#  'opłacone',
#  'składki',
#  ',',
#  'mimo',
#  'podlegania',
#  'obowiązkowo',
#  'ubezpieczeniom',
#  'emerytalnemu',
#  'i',
#  'rentowym',
#  'w',
#  'tym',
#  'okresie',
#  '.',
#  '5',
#  '.',
#  'wobec',
#  'ubezpieczonych',
#  'zobowiązanych',
#  'do',
#  'opłacania',
#  'składek',
#  'na',
#  'własne',
#  'ubezpieczenie',
#  'społeczne',
#  'za',
#  'okres',
#  'przypadający',
#  'przed',
#  'dniem',
#  'wejścia',
#  'w',
#  'życie',
#  'ustawy',
#  'oraz',
#  'osób',
#  'współpracujących',
#  'z',
#  'osobami',
#  'prowadzącymi',
#  'pozarolniczą',
#  'działalność',
#  'przed',
#  'dniem',
#  'wejścia',
#  'w',
#  'życie',
#  'ustawy',
#  'przepis',
#  'ust',
#  '.',
#  '4',
#  'stosuje',
#  'się',
#  'odpowiednio',
#  '.',
#  '"',
#  ';',
#  '3',
#  ')',
#  'w',
#  'art',
#  '.',
#  '9',
#  'ust',
#  '.',
#  '2',
#  'otrzymuje',
#  'brzmienie',
#  ':',
#  '"',
#  '2',
#  '.',
#  'okresy',
#  'zatrudnienia',
#  ',',
#  'o',
#  'których',
#  'mowa',
#  'w',
#  'art',
#  '.',
#  '6',
#  'ust',
#  '.',
#  '2',
#  'pkt',
#  '1',
#  'lit',
#  '.',
#  'a',
#  ')',
#  ',',
#  'wykonywanego',
#  'na',
#  'obszarze',
#  'państwa',
#  'polskiego',
#  'w',
#  'czasie',
#  ',',
#  'gdy',
#  'obszar',
#  'ten',
#  'nie',
#  'wchodził',
#  'w',
#  'skład',
#  'państwa',
#  'polskiego',
#  ',',
#  'oraz',
#  'okresy',
#  'pracy',
#  'przymusowej',
#  ',',
#  'o',
#  'których',
#  'mowa',
#  'w',
#  'art',
#  '.',
#  '6',
#  'ust',
#  '.',
#  '2',
#  'pkt',
#  '2',
#  'lit',
#  '.',
#  'a',
#  ')',
#  'i',
#  'b',
#  ')',
#  ',',
#  'uwzględnia',
#  'się',
#  'pod',
#  'warunkiem',
#  'stałego',
#  'zamieszkania',
#  'zainteresowanego',
#  'na',
#  'obecnym',
#  'obszarze',
#  'rzeczypospolitej',
#  'polskiej',
#  ',',
#  'z',
#  'zastrzeżeniem',
#  'ust',
#  '.',
#  '3',
#  '.',
#  '"',
#  ';',
#  '4',
#  ')',
#  'po',
#  'art',
#  '.',
#  '10',
#  'dodaje',
#  'się',
#  'art',
#  '.',
#  '10a',
#  'w',
#  'brzmieniu',
#  ':',
#  '"',
#  'art',
#  '.',
#  '10a',
#  '.',
#  '1',
#  '.',
#  'przy',
#  'ustalaniu',
#  'prawa',
#  'do',
#  'emerytury',
#  'osoby',
#  ',',
#  'która',
#  'osiągnęła',
#  'wiek',
#  'emerytalny',
#  'wynoszący',
#  'co',
#  'najmniej',
#  '60',
#  'lat',
#  'dla',
#  'kobiet',
#  'i',
#  'co',
#  'najmniej',
#  '65',
#  'lat',
#  'dla',
#  'mężczyzn',
#  'i',
#  'utraciła',
#  'prawo',
#  'do',
#  'renty',
#  'z',
#  'tytułu',
#  'niezdolności',
#  'do',
#  'pracy',
#  'przysługującej',
#  'z',
#  'funduszu',
#  'z',
#  'powodu',
#  'odzyskania',
#  'zdolności',
#  'do',
#  'pracy',
#  ',',
#  'uwzględnia',
#  'się',
#  'również',
#  'okresy',
#  'pobierania',
#  'tej',
#  'renty',
#  ',',
#  'jeżeli',
#  'okresy',
#  'składkowe',
#  'i',
#  'nieskładkowe',
#  ',',
#  'ustalone',
#  'na',
#  'zasadach',
#  'określonych',
#  'w',
#  'art',
#  '.',
#  '5',
#  '-',
#  '7',
#  'i',
#  '10',
#  ',',
#  'są',
#  'krótsze',
#  'od',
#  'okresu',
#  'wymaganego',
#  'do',
#  'przyznania',
#  'emerytury',
#  ',',
#  'w',
#  'zakresie',
#  'niezbędnym',
#  'do',
#  'uzupełnienia',
#  'tego',
#  'okresu',
#  '.',
#  '2',
#  '.',
#  'okresów',
#  'pobierania',
#  'renty',
#  'z',
#  'tytułu',
#  'niezdolności',
#  'do',
#  'pracy',
#  'nie',
#  'uwzględnia',
#  'się',
#  ',',
#  'jeżeli',
#  'zbiegają',
#  'się',
#  'w',
#  'czasie',
#  'z',
#  'okresami',
#  ',',
#  'o',
#  'których',
#  'mowa',
#  'w',
#  'art',
#  '.',
#  '6',
#  ',',
#  '7',
#  'i',
#  '10',
#  ',',
#  'uwzględnionymi',
#  'przy',
#  'ustalaniu',
#  'prawa',
#  'do',
#  'emerytury',
#  '.',
#  '"',
#  ';',
#  '5',
#  ')',
#  'w',
#  'art',
#  '.',
#  '13',
#  'ust',
#  '.',
#  '5',
#  'otrzymuje',
#  'brzmienie',
#  ':',
#  '"',
#  '5',
#  '.',
#  'w',
#  'przypadku',
#  'stwierdzenia',
#  'naruszenia',
#  'sprawności',
#  'organizmu',
#  'w',
#  'stopniu',
#  'powodującym',
#  'konieczność',
#  'stałej',
#  'lub',
#  'długotrwałej',
#  'opieki',
#  'i',
#  'pomocy',
#  'innej',
#  'osoby',
#  'w',
#  'zaspokajaniu',
#  'podstawowych',
#  'potrzeb',
#  'życiowych',
#  'orzeka',
#  'się',
#  'niezdolność',
#  'do',
#  'samodzielnej',
#  'egzystencji',
#  '.',
#  'przepisy',
#  'ust',
#  '.',
#  '2',
#  'i',
#  '3',
#  'stosuje',
#  'się',
#  'odpowiednio',
#  '.',
#  '"',
#  ';',
#  '6',
#  ')',
#  'w',
#  'art',
#  '.',
#  '14',
#  ':',
#  'a',
#  ')',
#  'ust',
#  '.',
#  '1',
#  'otrzymuje',
#  'brzmienie',
#  ':',
#  '"',
#  '1',
#  '.',
#  'oceny',
#  'niezdolności',
#  'do',
#  'pracy',
#  ',',
#  'jej',
#  'stopnia',
#  'oraz',
#  'ustalenia',
#  ':',
#  '1',
#  ')',
#  'daty',
#  'powstania',
#  'niezdolności',
#  'do',
#  'pracy',
#  ',',
#  '2',
#  ')',
#  'trwałości',
#  'lub',
#  'przewidywanego',
#  'okresu',
#  'niezdolności',
#  'do',
#  'pracy',
#  ',',
#  '3',
#  ')',
#  'związku',
#  'przyczynowego',
#  'niezdolności',
#  'do',
#  'pracy',
#  'lub',
#  'śmierci',
#  'z',
#  'określonymi',
#  'okolicznościami',
#  ',',
#  '4',
#  ')',
#  'trwałości',
#  'lub',
#  'przewidywanego',
#  'okresu',
#  'niezdolności',
#  'do',
#  'samodzielnej',
#  'egzystencji',
#  ',',
#  '5',
#  ')',
#  'celowości',
#  'przekwalifikowania',
#  'zawodowego',
#  '-',
#  'dokonuje',
#  'w',
#  'formie',
#  'orzeczenia',
#  'lekarz',
#  'orzecznik',
#  'zakładu',
#  ',',
#  'zwany',
#  'dalej',
#  '"',
#  'lekarzem',
#  'orzecznikiem',
#  '"',
#  '.',
#  '"',
#  ',',
#  'b',
#  ')',
#  'po',
#  'ust',
#  '.',
#  '2',
#  'dodaje',
#  'się',
#  'ust',
#  '.',
#  '2a',
#  '-',
#  '2f',
#  'w',
#  'brzmieniu',
#  ':',
#  '"',
#  '2a',
#  '.',
#  'od',
#  'orzeczenia',
#  'lekarza',
#  'orzecznika',
#  'osobie',
#  'zainteresowanej',
#  'przysługuje',
#  'sprzeciw',
#  'do',
#  'komisji',
#  'lekarskiej',
#  'zakładu',
#  ',',
#  'zwanej',
#  'dalej',
#  '"',
#  'komisją',
#  'lekarską',
#  '"',
#  ',',
#  'w',
#  'ciągu',
#  '14',
#  'dni',
#  'od',
#  'dnia',
#  'doręczenia',
#  'tego',
#  'orzeczenia',
#  '.',
#  '2b',
#  '.',
#  'sprzeciw',
#  'wnosi',
#  'się',
#  'za',
#  'pośrednictwem',
#  'jednostki',
#  'organizacyjnej',
#  'zakładu',
#  'właściwej',
#  'ze',
#  'względu',
#  'na',
#  'miejsce',
#  'zamieszkania',
#  'osoby',
#  'zainteresowanej',
#  '.',
#  '2c',
#  '.',
#  'komisja',
#  'lekarska',
#  'nie',
#  'rozpatruje',
#  'sprzeciwu',
#  'wniesionego',
#  'po',
#  'terminie',
#  '.',
#  'w',
#  'uzasadnionych',
#  'przypadkach',
#  'zakład',
#  ',',
#  'na',
#  'wniosek',
#  'osoby',
#  'zainteresowanej',
#  ',',
#  'moe',
#  'przywrcić',
#  'termin',
#  'na',
#  'wniesienie',
#  'sprzeciwu',
#  ',',
#  'w',
#  'tym',
#  'w',
#  'szczególności',
#  'w',
#  'razie',
#  'odrzucenia',
#  'przez',
#  'sąd',
#  'odwołania',
#  'od',
#  'decyzji',
#  'w',
#  'przypadku',
#  'określonym',
#  'w',
#  'art',
#  '.',
#  '477{9',
#  '}',
#  '3{1',
#  '}',
#  'ustawy',
#  'z',
#  'dnia',
#  '17',
#  'listopada',
#  '1964',
#  'r',
#  '.',
#  '-',
#  'kodeks',
#  'postępowania',
#  'cywilnego',
#  '.',
#  '2d',
#  '.',
#  'prezes',
#  'zakładu',
#  ',',
#  'w',
#  'terminie',
#  '14',
#  'dni',
#  'od',
#  'dnia',
#  'wydania',
#  'orzeczenia',
#  'przez',
#  'lekarza',
#  'orzecznika',
#  ',',
#  'może',
#  'zgłosić',
#  'zarzut',
#  'wadliwości',
#  'orzeczenia',
#  'i',
#  'przekazać',
#  'sprawę',
#  'do',
#  'rozpatrzenia',
#  'komisji',
#  'lekarskiej',
#  '.',
#  'o',
#  'zgłoszeniu',
#  'zarzutu',
#  'wadliwości',
#  'orzeczenia',
#  'jednostka',
#  'organizacyjna',
#  'zakładu',
#  'niezwłocznie',
#  'zawiadamia',
#  'osobę',
#  'zainteresowaną',
#  '.',
#  '2e',
#  '.',
#  'komisja',
#  'lekarska',
#  ',',
#  'rozpatrując',
#  'sprzeciw',
#  'lub',
#  'zarzut',
#  'wadliwości',
#  ',',
#  'dokonuje',
#  'oceny',
#  'niezdolności',
#  'do',
#  'pracy',
#  'i',
#  'jej',
#  'stopnia',
#  'oraz',
#  'ustalenia',
#  'okoliczności',
#  ',',
#  'o',
#  'których',
#  'mowa',
#  'w',
#  'ust',
#  '.',
#  '1',
#  '.',
#  '2f',
#  '.',
#  'komisja',
#  'lekarska',
#  'dokonuje',
#  'rozstrzygnięcia',
#  'w',
#  'formie',
#  'orzeczenia',
#  '.',
#  '"',
#  ',',
#  'c',
#  ')',
#  'ust',
#  '.',
#  '3',
#  'otrzymuje',
#  'brzmienie',
#  ':',
#  '"',
#  '3',
#  '.',
#  'orzeczenie',
#  'lekarza',
#  'orzecznika',
#  ',',
#  'od',
#  'którego',
#  'nie',
#  'wniesiono',
#  'sprzeciwu',
#  'lub',
#  'co',
#  'do',
#  'którego',
#  'nie',
#  'zgłoszono',
#  'zarzutu',
#  'wadliwości',
#  ',',
#  'albo',
#  'orzeczenie',
#  'komisji',
#  'lekarskiej',
#  ',',
#  'stanowi',
#  'dla',
#  'organu',
#  'rentowego',
#  'podstawę',
#  'do',
#  'wydania',
#  'decyzji',
#  'w',
#  'sprawie',
#  'świadczeń',
#  'przewidzianych',
#  'w',
#  'ustawie',
#  ',',
#  'do',
#  'których',
#  'prawo',
#  'jest',
#  'uzależnione',
#  'od',
#  'stwierdzenia',
#  'niezdolności',
#  'do',
#  'pracy',
#  ...]

# %% [markdown]
# ### Compute bigram counts of downcased tokens.

# %%
def create_ngram(text, n = 2):  
    result = []
    count = 0
    for token in text[:len(text)-n+1]:  
        result.append(tuple(text[count:count+n]))
        count += 1  
    return result

# %%
bigrams_global = []

for _, content in tokenized_bills.items():   
    bigrams_global.extend(create_ngram(content))

# %%
bigrams_global_count = Counter(bigrams_global)

# %%
bigrams_global_count.most_common(10)
# Out:
# [(('art', '.'), 83778),
#  (('ust', '.'), 53552),
#  (('poz', '.'), 45198),
#  ((',', 'poz'), 43188),
#  (('.', '1'), 39927),
#  (('-', '-'), 36547),
#  (('r', '.'), 33010),
#  (('w', 'art'), 32043),
#  ((',', 'o'), 29926),
#  (('mowa', 'w'), 28471)]

# %% [markdown]
# ### Discard bigrams containing characters other than letters. Make sure that you discard the invalid entries after computing the bigram counts.

# %%
bigrams_global_clean = defaultdict(int)

for key, value in bigrams_global_count.items():
    if key[0].isalpha() and key[1].isalpha():
        bigrams_global_clean[key] = value

# %%
bigrams_global_clean
# Out:
# defaultdict(int,
#             {('ustawa', 'z'): 1190,
#              ('z', 'dnia'): 9527,
#              ('o', 'zmianie'): 1299,
#              ('zmianie', 'ustawy'): 850,
#              ('ustawy', 'o'): 1444,
#              ('o', 'podatku'): 533,
#              ('podatku', 'od'): 382,
#              ('od', 'towarów'): 273,
#              ('towarów', 'i'): 530,
#              ('i', 'usług'): 565,
#              ('usług', 'oraz'): 122,
#              ('oraz', 'o'): 945,
#              ('podatku', 'akcyzowym'): 75,
#              ('akcyzowym', 'art'): 15,
#              ('w', 'ustawie'): 5180,
#              ('ustawie', 'z'): 3661,
#              ('i', 'nr'): 8435,
#              ('wprowadza', 'się'): 1849,
#              ('się', 'następujące'): 1855,
#              ('następujące', 'zmiany'): 1808,
#              ('w', 'art'): 32043,
#              ('dotychczasowa', 'treść'): 37,
#              ('treść', 'otrzymuje'): 37,
#              ('otrzymuje', 'oznaczenie'): 41,
#              ('oznaczenie', 'ust'): 62,
#              ('dodaje', 'się'): 8195,
#              ('się', 'ust'): 3484,
#              ('w', 'brzmieniu'): 7281,
#              ('rada', 'ministrów'): 890,
#              ('ministrów', 'może'): 145,
#              ('może', 'określać'): 52,
#              ('w', 'drodze'): 7127,
#              ('drodze', 'rozporządzenia'): 4691,
#              ('towary', 'i'): 21,
#              ('i', 'usługi'): 27,
#              ('z', 'wyjątkiem'): 1619,
#              ('wyjątkiem', 'wyrobów'): 19,
#              ('wyrobów', 'akcyzowych'): 469,
#              ('akcyzowych', 'i'): 6,
#              ('i', 'wyrobów'): 139,
#              ('wyrobów', 'z'): 41,
#              ('z', 'metali'): 33,
#              ('metali', 'szlachetnych'): 24,
#              ('do', 'których'): 412,
#              ('których', 'nie'): 153,
#              ('nie', 'stosuje'): 1414,
#              ('stosuje', 'się'): 6535,
#              ('się', 'przepisów'): 179,
#              ('przepisów', 'ustawy'): 782,
#              ('w', 'pkt'): 3765,
#              ('użytkowania', 'wynosi'): 1,
#              ('zastępuje', 'się'): 4779,
#              ('się', 'wyrazami'): 2942,
#              ('używania', 'wyniósł'): 1,
#              ('kropkę', 'zastępuje'): 643,
#              ('się', 'średnikiem'): 174,
#              ('średnikiem', 'i'): 169,
#              ('i', 'dodaje'): 893,
#              ('dodaje', 'wyrazy'): 100,
#              ('w', 'pozostałych'): 97,
#              ('pozostałych', 'przypadkach'): 45,
#              ('przypadkach', 'właściwym'): 2,
#              ('właściwym', 'urzędem'): 6,
#              ('urzędem', 'skarbowym'): 6,
#              ('skarbowym', 'jest'): 4,
#              ('jest', 'drugi'): 4,
#              ('drugi', 'urząd'): 4,
#              ('urząd', 'skarbowy'): 138,
#              ('skarbowy', 'warszawy'): 1,
#              ('otrzymuje', 'brzmienie'): 9553,
#              ('jeżeli', 'sprzedaż'): 17,
#              ('sprzedaż', 'towaru'): 7,
#              ('towaru', 'lub'): 56,
#              ('lub', 'wykonanie'): 21,
#              ('wykonanie', 'usługi'): 6,
#              ('usługi', 'powinno'): 1,
#              ('powinno', 'być'): 155,
#              ('być', 'potwierdzone'): 11,
#              ('potwierdzone', 'fakturą'): 2,
#              ('fakturą', 'lub'): 1,
#              ('lub', 'rachunkiem'): 1,
#              ('rachunkiem', 'uproszczonym'): 2,
#              ('obowiązek', 'podatkowy'): 109,
#              ('podatkowy', 'powstaje'): 19,
#              ('powstaje', 'z'): 93,
#              ('z', 'chwilą'): 356,
#              ('chwilą', 'wystawienia'): 4,
#              ('wystawienia', 'faktury'): 12,
#              ('faktury', 'lub'): 9,
#              ('lub', 'rachunku'): 11,
#              ('rachunku', 'uproszczonego'): 2,
#              ('nie', 'później'): 820,
#              ('później', 'jednak'): 138,
#              ('jednak', 'niż'): 682,
#              ('niż', 'w'): 514,
#              ('dniu', 'od'): 14,
#              ('od', 'dnia'): 5324,
#              ('dnia', 'wydania'): 112,
#              ('wydania', 'towaru'): 4,
#              ('lub', 'wykonania'): 30,
#              ('wykonania', 'usługi'): 14,
#              ('wystawienie', 'faktury'): 1,
#              ('uproszczonego', 'następuje'): 1,
#              ('następuje', 'nie'): 26,
#              ('później', 'niż'): 688,
#              ('w', 'ostatnim'): 92,
#              ('ostatnim', 'dniu'): 49,
#              ('dniu', 'miesiąca'): 16,
#              ('w', 'którym'): 1825,
#              ('którym', 'wydano'): 27,
#              ('wydano', 'towar'): 1,
#              ('towar', 'lub'): 12,
#              ('lub', 'wykonano'): 2,
#              ('wykonano', 'usługę'): 1,
#              ('w', 'ust'): 23557,
#              ('faktur', 'i'): 1,
#              ('i', 'rachunków'): 22,
#              ('rachunków', 'uproszczonych'): 7,
#              ('po', 'ust'): 1541,
#              ('przepis', 'ust'): 613,
#              ('się', 'również'): 378,
#              ('również', 'w'): 245,
#              ('w', 'przypadku'): 6027,
#              ('przypadku', 'eksportu'): 7,
#              ('eksportu', 'towarów'): 10,
#              ('wywóz', 'towarów'): 18,
#              ('towarów', 'nastąpi'): 1,
#              ('nastąpi', 'w'): 27,
#              ('w', 'ciągu'): 1050,
#              ('ciągu', 'sześciu'): 15,
#              ('sześciu', 'miesięcy'): 100,
#              ('miesięcy', 'od'): 1284,
#              ('dnia', 'otrzymania'): 297,
#              ('otrzymania', 'zaliczki'): 1,
#              ('eksporter', 'przedstawi'): 2,
#              ('przedstawi', 'w'): 5,
#              ('w', 'urzędzie'): 190,
#              ('urzędzie', 'skarbowym'): 27,
#              ('skarbowym', 'zabezpieczenie'): 1,
#              ('zabezpieczenie', 'majątkowe'): 13,
#              ('majątkowe', 'kwoty'): 1,
#              ('kwoty', 'zwrotu'): 7,
#              ('zwrotu', 'różnicy'): 19,
#              ('różnicy', 'podatku'): 29,
#              ('o', 'której'): 5530,
#              ('której', 'mowa'): 5511,
#              ('mowa', 'w'): 28471,
#              ('import', 'towarów'): 7,
#              ('towarów', 'zwolnionych'): 10,
#              ('zwolnionych', 'od'): 52,
#              ('od', 'cła'): 237,
#              ('cła', 'na'): 23,
#              ('na', 'podstawie'): 6677,
#              ('podstawie', 'art'): 1496,
#              ('oraz', 'art'): 785,
#              ('ustawy', 'z'): 3075,
#              ('prawo', 'celne'): 19,
#              ('oraz', 'z'): 4265,
#              ('wyrazy', 'w'): 2,
#              ('w', 'nawiasie'): 6,
#              ('nawiasie', 'zastępuje'): 1,
#              ('skreśla', 'się'): 2710,
#              ('się', 'wyrazy'): 2180,
#              ('niż', 'na'): 124,
#              ('przypadku', 'gdy'): 826,
#              ('gdy', 'zaprzestanie'): 1,
#              ('zaprzestanie', 'wykonania'): 1,
#              ('wykonania', 'czynności'): 58,
#              ('czynności', 'podlegających'): 19,
#              ('podlegających', 'opodatkowaniu'): 30,
#              ('opodatkowaniu', 'nie'): 2,
#              ('nie', 'zostało'): 97,
#              ('zostało', 'zgłoszone'): 12,
#              ('zgłoszone', 'zgodnie'): 5,
#              ('zgodnie', 'z'): 2555,
#              ('z', 'ust'): 231,
#              ('który', 'dokonał'): 42,
#              ('dokonał', 'rejestracji'): 3,
#              ('wykreśla', 'z'): 9,
#              ('z', 'urzędu'): 645,
#              ('urzędu', 'podatnika'): 1,
#              ('podatnika', 'z'): 15,
#              ('z', 'rejestru'): 305,
#              ('a', 'w'): 2182,
#              ('w', 'przypadkach'): 755,
#              ('przypadkach', 'określonych'): 228,
#              ('określonych', 'w'): 4041,
#              ('następuje', 'również'): 9,
#              ('również', 'unieważnienie'): 1,
#              ('unieważnienie', 'numeru'): 1,
#              ('numeru', 'identyfikacyjnego'): 24,
#              ('rachunkach', 'uproszczonych'): 2,
#              ('się', 'odpowiednio'): 3177,
#              ('odpowiednio', 'do'): 747,
#              ('do', 'kwoty'): 87,
#              ('podatku', 'wynikającej'): 5,
#              ('wynikającej', 'z'): 177,
#              ('z', 'deklaracji'): 13,
#              ('deklaracji', 'podatkowej'): 26,
#              ('przepisu', 'ust'): 259,
#              ('się', 'do'): 2109,
#              ('do', 'podatników'): 58,
#              ('podatników', 'zwolnionych'): 5,
#              ('od', 'podatku'): 180,
#              ('usług', 'na'): 33,
#              ('oraz', 'podmiotów'): 27,
#              ('podmiotów', 'wykonujących'): 17,
#              ('wykonujących', 'wyłącznie'): 3,
#              ('wyłącznie', 'czynności'): 14,
#              ('czynności', 'zwolnione'): 3,
#              ('zwolnione', 'od'): 109,
#              ('podatku', 'na'): 34,
#              ('lub', 'na'): 558,
#              ('podstawie', 'przepisów'): 863,
#              ('przepisów', 'wydanych'): 56,
#              ('wydanych', 'na'): 546,
#              ('chyba', 'że'): 1306,
#              ('że', 'przysługuje'): 5,
#              ('przysługuje', 'im'): 13,
#              ('im', 'zwrot'): 1,
#              ('zwrot', 'różnicy'): 10,
#              ('podatku', 'lub'): 31,
#              ('lub', 'zwrot'): 7,
#              ('zwrot', 'podatku'): 16,
#              ('podatku', 'naliczonego'): 25,
#              ('naliczonego', 'zgodnie'): 1,
#              ('z', 'art'): 822,
#              ('zwalnia', 'się'): 139,
#              ('się', 'od'): 463,
#              ('podatku', 'podatników'): 1,
#              ('u', 'których'): 39,
#              ('których', 'wartość'): 57,
#              ('wartość', 'sprzedaży'): 20,
#              ('sprzedaży', 'towarów'): 98,
#              ('towarów', 'w'): 50,
#              ('w', 'rozumieniu'): 1786,
#              ('rozumieniu', 'art'): 326,
#              ('a', 'także'): 3783,
#              ('także', 'wartość'): 8,
#              ('wartość', 'eksportu'): 3,
#              ('towarów', 'lub'): 73,
#              ('lub', 'usług'): 86,
#              ('usług', 'nie'): 10,
#              ('nie', 'przekroczyła'): 14,
#              ('przekroczyła', 'łącznie'): 2,
#              ('łącznie', 'w'): 12,
#              ('w', 'poprzednim'): 104,
#              ('poprzednim', 'roku'): 77,
#              ('roku', 'podatkowym'): 261,
#              ('mld', 'zł'): 10,
#              ('opłacających', 'podatek'): 2,
#              ('podatek', 'dochodowy'): 123,
#              ('dochodowy', 'w'): 17,
#              ('w', 'formie'): 1159,
#              ('formie', 'karty'): 79,
#              ('karty', 'podatkowej'): 98,
#              ('w', 'zakresie'): 5456,
#              ('zakresie', 'działalności'): 60,
#              ('działalności', 'objętej'): 66,
#              ('objętej', 'tą'): 1,
#              ('tą', 'formą'): 1,
#              ('formą', 'opodatkowania'): 1,
#              ('z', 'uwzględnieniem'): 1183,
#              ('uwzględnieniem', 'art'): 72,
#              ('o', 'których'): 13885,
#              ('których', 'mowa'): 13858,
#              ('mogą', 'zrezygnować'): 1,
#              ('zrezygnować', 'ze'): 3,
#              ('ze', 'zwolnienia'): 80,
#              ('zwolnienia', 'określonego'): 7,
#              ('określonego', 'w'): 917,
#              ('pod', 'warunkiem'): 480,
#              ('warunkiem', 'zawiadomienia'): 1,
#              ('zawiadomienia', 'o'): 138,
#              ('o', 'tym'): 474,
#              ('tym', 'zamiarze'): 1,
#              ('zamiarze', 'właściwego'): 1,
#              ('właściwego', 'urzędu'): 67,
#              ('urzędu', 'skarbowego'): 226,
#              ('skarbowego', 'przed'): 1,
#              ('przed', 'początkiem'): 3,
#              ('początkiem', 'miesiąca'): 4,
#              ('którym', 'rezygnują'): 1,
#              ('rezygnują', 'ze'): 1,
#              ('rezygnacja', 'obowiązuje'): 1,
#              ('obowiązuje', 'do'): 17,
#              ('do', 'końca'): 274,
#              ('końca', 'roku'): 116,
#              ('roku', 'podatkowego'): 214,
#              ('jeżeli', 'wartość'): 147,
#              ('towarów', 'u'): 4,
#              ('u', 'podatników'): 10,
#              ('podstawie', 'ust'): 236,
#              ('przekroczy', 'kwotę'): 4,
#              ('zwolnienie', 'traci'): 3,
#              ('traci', 'moc'): 149,
#              ('moc', 'w'): 18,
#              ('w', 'momencie'): 39,
#              ('momencie', 'przekroczenie'): 1,
#              ('przekroczenie', 'tej'): 4,
#              ('tej', 'kwoty'): 59,
#              ('chwilą', 'przekroczenia'): 3,
#              ('przekroczenia', 'tej'): 5,
#              ('a', 'opodatkowaniu'): 2,
#              ('opodatkowaniu', 'podlega'): 4,
#              ('podlega', 'nadwyżka'): 4,
#              ('nadwyżka', 'ponad'): 2,
#              ('ponad', 'tę'): 11,
#              ('tę', 'kwotę'): 25,
#              ('za', 'zgodą'): 442,
#              ('zgodą', 'właściwego'): 12,
#              ('skarbowego', 'podatnik'): 3,
#              ('podatnik', 'może'): 18,
#              ('może', 'zmniejszyć'): 8,
#              ('zmniejszyć', 'podatek'): 4,
#              ('podatek', 'należny'): 17,
#              ('należny', 'o'): 4,
#              ('o', 'podatek'): 19,
#              ('podatek', 'naliczony'): 21,
#              ('wynikający', 'z'): 81,
#              ('z', 'rachunków'): 13,
#              ('uproszczonych', 'dokumentujących'): 1,
#              ('dokumentujących', 'zakupy'): 4,
#              ('zakupy', 'dokonane'): 4,
#              ('dokonane', 'przed'): 32,
#              ('przed', 'dniem'): 1464,
#              ('dniem', 'utraty'): 13,
#              ('utraty', 'zwolnienia'): 6,
#              ('warunkiem', 'sporządzenia'): 2,
#              ('sporządzenia', 'spisu'): 15,
#              ('spisu', 'z'): 19,
#              ('z', 'natury'): 38,
#              ('natury', 'zapasów'): 4,
#              ('zapasów', 'tych'): 4,
#              ('tych', 'towarów'): 57,
#              ('towarów', 'posiadanych'): 3,
#              ('posiadanych', 'w'): 11,
#              ('w', 'dniu'): 1008,
#              ('dniu', 'przekroczenia'): 1,
#              ('przekroczenia', 'kwoty'): 1,
#              ('przypadku', 'podatników'): 20,
#              ('przez', 'wartość'): 4,
#              ('towarów', 'określoną'): 1,
#              ('określoną', 'w'): 191,
#              ('rozumie', 'się'): 994,
#              ('krotność', 'kwoty'): 1,
#              ('kwoty', 'prowizji'): 1,
#              ('podatników', 'dokonujących'): 7,
#              ('dokonujących', 'sprzedaży'): 2,
#              ('sprzedaży', 'będącej'): 1,
#              ('będącej', 'przedmiotem'): 20,
#              ('przedmiotem', 'umowy'): 21,
#              ('umowy', 'pośrednictwa'): 1,
#              ('wartość', 'sprzedanych'): 14,
#              ('sprzedanych', 'towarów'): 13,
#              ('towarów', 'będącej'): 1,
#              ('umowy', 'komisu'): 4,
#              ('podatnicy', 'będący'): 6,
#              ('będący', 'zakładami'): 2,
#              ('zakładami', 'pracy'): 5,
#              ('pracy', 'chronionej'): 22,
#              ('chronionej', 'w'): 3,
#              ('rozumieniu', 'przepisów'): 669,
#              ('przepisów', 'o'): 1176,
#              ('o', 'zatrudnieniu'): 94,
#              ('zatrudnieniu', 'i'): 84,
#              ('i', 'rehabilitacji'): 36,
#              ('rehabilitacji', 'zawodowej'): 78,
#              ('zawodowej', 'osób'): 18,
#              ('osób', 'niepełnosprawnych'): 252,
#              ('niepełnosprawnych', 'mogą'): 1,
#              ('mogą', 'wybrać'): 2,
#              ('wybrać', 'zwolnienie'): 2,
#              ('zwolnienie', 'od'): 95,
#              ('bez', 'względu'): 227,
#              ('względu', 'na'): 1410,
#              ('na', 'wartość'): 17,
#              ('warunkiem', 'złożenia'): 9,
#              ('złożenia', 'przez'): 82,
#              ('przez', 'podatnika'): 157,
#              ('podatnika', 'pisemnego'): 2,
#              ('pisemnego', 'oświadczenia'): 29,
#              ('oświadczenia', 'we'): 1,
#              ('we', 'właściwym'): 77,
#              ('właściwym', 'urzędzie'): 16,
#              ('podatnik', 'rozpoczynający'): 1,
#              ('rozpoczynający', 'wykonywanie'): 1,
#              ('wykonywanie', 'czynności'): 121,
#              ('czynności', 'określonych'): 39,
#              ('ciągu', 'roku'): 128,
#              ('podatkowego', 'może'): 2,
#              ('może', 'wybrać'): 6,
#              ('jeżeli', 'przewidywana'): 2,
#              ('przewidywana', 'przez'): 4,
#              ('podatnika', 'wartość'): 2,
#              ('określona', 'w'): 167,
#              ('w', 'złożonym'): 6,
#              ('złożonym', 'oświadczeniu'): 1,
#              ('nie', 'przekroczy'): 35,
#              ('w', 'proporcji'): 18,
#              ('proporcji', 'do'): 13,
#              ('do', 'okresu'): 168,
#              ('okresu', 'prowadzonej'): 1,
#              ('prowadzonej', 'sprzedaży'): 1,
#              ('kwoty', 'wymienionej'): 2,
#              ('wymienionej', 'w'): 441,
#              ('podatnik', 'składa'): 2,
#              ('składa', 'oświadczenie'): 16,
#              ('oświadczenie', 'w'): 8,
#              ('skarbowym', 'przed'): 1,
#              ('dniem', 'dokonania'): 4,
#              ('dokonania', 'pierwszej'): 3,
#              ('pierwszej', 'sprzedaży'): 4,
#              ('świadczenia', 'usługi'): 15,
#              ('towarów', 'określona'): 1,
#              ('określona', 'zgodnie'): 7,
#              ('zostanie', 'przekroczona'): 2,
#              ('przekroczona', 'w'): 4,
#              ('moc', 'od'): 2,
#              ('od', 'momentu'): 17,
#              ('momentu', 'przekroczenia'): 1,
#              ('tej', 'wartości'): 16,
#              ('nadwyżka', 'sprzedaży'): 1,
#              ('sprzedaży', 'ponad'): 1,
#              ('ponad', 'wartość'): 7,
#              ('wartość', 'określoną'): 1,
#              ('określoną', 'zgodnie'): 11,
#              ('a', 'obowiązek'): 4,
#              ('zdanie', 'trzecie'): 36,
#              ('trzecie', 'stosuje'): 4,
#              ('jeżeli', 'podatnicy'): 10,
#              ('podatnicy', 'określeni'): 2,
#              ('określeni', 'w'): 15,
#              ('wykorzystując', 'związki'): 1,
#              ('związki', 'z'): 8,
#              ('z', 'kontrahentami'): 3,
#              ('tak', 'układają'): 1,
#              ('układają', 'swoje'): 3,
#              ('swoje', 'interesy'): 1,
#              ('że', 'uzyskują'): 1,
#              ('uzyskują', 'wartość'): 1,
#              ('towarów', 'znacznie'): 1,
#              ('znacznie', 'niższą'): 2,
#              ('niższą', 'niż'): 16,
#              ('niż', 'uzyskaliby'): 1,
#              ('uzyskaliby', 'w'): 1,
#              ('gdyby', 'związek'): 1,
#              ('związek', 'ten'): 7,
#              ('ten', 'nie'): 122,
#              ('nie', 'istniał'): 5,
#              ('w', 'wyniku'): 935,
#              ('wyniku', 'tych'): 8,
#              ('tych', 'związków'): 3,
#              ('związków', 'nastąpiło'): 1,
#              ('nastąpiło', 'zmniejszenie'): 1,
#              ('zmniejszenie', 'wpływów'): 1,
#              ('wpływów', 'podatkowych'): 1,
#              ('podatku', 'traci'): 1,
#              ('od', 'początku'): 83,
#              ('początku', 'roku'): 64,
#              ('poczynając', 'od'): 77,
#              ('i', 'ust'): 423,
#              ('ulega', 'corocznie'): 1,
#              ('corocznie', 'podwyższeniu'): 3,
#              ('podwyższeniu', 'w'): 13,
#              ('w', 'stopniu'): 88,
#              ('stopniu', 'odpowiadającym'): 22,
#              ('odpowiadającym', 'wskaźnikowi'): 12,
#              ('wskaźnikowi', 'cen'): 6,
#              ('cen', 'konsumpcyjnych'): 4,
#              ('konsumpcyjnych', 'towarów'): 4,
#              ('usług', 'w'): 70,
#              ('w', 'okresie'): 1460,
#              ('okresie', 'pierwszych'): 18,
#              ('pierwszych', 'trzech'): 9,
#              ('trzech', 'kwartałów'): 11,
#              ('kwartałów', 'roku'): 6,
#              ('roku', 'poprzedzającego'): 146,
#              ('poprzedzającego', 'rok'): 144,
#              ('rok', 'kalendarzowy'): 81,
#              ('kalendarzowy', 'w'): 9,
#              ('w', 'stosunku'): 1368,
#              ('stosunku', 'do'): 1189,
#              ('do', 'tego'): 380,
#              ('tego', 'samego'): 225,
#              ('samego', 'okresu'): 6,
#              ('okresu', 'roku'): 8,
#              ('roku', 'ubiegłego'): 8,
#              ('podatników', 'określonych'): 3,
#              ('do', 'importu'): 8,
#              ('importu', 'towarów'): 15,
#              ('oraz', 'podatników'): 5,
#              ('wyroby', 'z'): 30,
#              ('szlachetnych', 'lub'): 1,
#              ('lub', 'z'): 435,
#              ('z', 'udziałem'): 234,
#              ('udziałem', 'tych'): 12,
#              ('tych', 'metali'): 5,
#              ('wyroby', 'akcyzowe'): 118,
#              ('wyrobów', 'wymienionych'): 3,
#              ('wymienionych', 'w'): 1053,
#              ('w', 'załączniku'): 424,
#              ('załączniku', 'nr'): 302,
#              ('świadczących', 'usługi'): 61,
#              ('usługi', 'prawnicze'): 4,
#              ('prawnicze', 'oraz'): 2,
#              ('oraz', 'usługi'): 17,
#              ('usługi', 'w'): 124,
#              ('zakresie', 'doradztwa'): 6,
#              ('minister', 'finansów'): 407,
#              ('finansów', 'określi'): 78,
#              ('listę', 'towarów'): 10,
#              ('i', 'pkt'): 177,
#              ('uwzględnieniem', 'klasyfikacji'): 3,
#              ('klasyfikacji', 'wydanych'): 3,
#              ('o', 'statystyce'): 50,
#              ('statystyce', 'państwowej'): 6,
#              ('finansów', 'w'): 68,
#              ('w', 'porozumieniu'): 1709,
#              ('porozumieniu', 'z'): 1733,
#              ('z', 'prezesem'): 85,
#              ('prezesem', 'głównego'): 20,
#              ('głównego', 'urzędu'): 407,
#              ('urzędu', 'statystycznego'): 247,
#              ('statystycznego', 'ustala'): 3,
#              ('ustala', 'do'): 2,
#              ('listopada', 'roku'): 28,
#              ('rok', 'podatkowy'): 207,
#              ('drodze', 'obwieszczenia'): 117,
#              ('uwzględnieniem', 'zasady'): 18,
#              ('zasady', 'określonej'): 4,
#              ('określonej', 'w'): 598,
#              ('zaokrąglając', 'tę'): 1,
#              ('kwotę', 'do'): 3,
#              ('do', 'pełnych'): 32,
#              ('mln', 'zł'): 33,
#              ('w', 'zdaniu'): 355,
#              ('zdaniu', 'drugim'): 67,
#              ('drugim', 'po'): 19,
#              ('po', 'wyrazie'): 551,
#              ('się', 'wyraz'): 242,
#              ('faktur', 'lub'): 3,
#              ('lub', 'rachunków'): 14,
#              ('podstawą', 'opodatkowania'): 35,
#              ('opodatkowania', 'w'): 87,
#              ('w', 'imporcie'): 9,
#              ('imporcie', 'towarów'): 9,
#              ('towarów', 'jest'): 7,
#              ('jest', 'wartość'): 56,
#              ('wartość', 'celna'): 73,
#              ('celna', 'powiększona'): 13,
#              ('powiększona', 'o'): 40,
#              ('o', 'należne'): 21,
#              ('należne', 'cło'): 16,
#              ('cło', 'i'): 8,
#              ('i', 'podatek'): 11,
#              ('podatek', 'importowy'): 8,
#              ('jeżeli', 'przedmiotem'): 70,
#              ('przedmiotem', 'importu'): 8,
#              ('importu', 'są'): 3,
#              ('są', 'towary'): 30,
#              ('towary', 'opodatkowane'): 5,
#              ('opodatkowane', 'podatkiem'): 8,
#              ('podatkiem', 'akcyzowym'): 12,
#              ('wartość', 'celną'): 18,
#              ('celną', 'powiększoną'): 1,
#              ('powiększoną', 'o'): 24,
#              ('importowy', 'zwiększa'): 1,
#              ('zwiększa', 'się'): 26,
#              ('również', 'o'): 29,
#              ('podatek', 'akcyzowy'): 26,
#              ('się', 'wyrazem'): 713,
#              ('obniżenie', 'kwoty'): 11,
#              ('kwoty', 'podatku'): 41,
#              ('podatku', 'należnego'): 47,
#              ('następuje', 'w'): 505,
#              ('w', 'rozliczeniu'): 23,
#              ('rozliczeniu', 'za'): 10,
#              ('za', 'miesiąc'): 55,
#              ('którym', 'podatnik'): 16,
#              ('podatnik', 'otrzymał'): 5,
#              ('otrzymał', 'fakturę'): 4,
#              ('rachunek', 'uproszczony'): 4,
#              ('uproszczony', 'w'): 2,
#              ('przypadku', 'określonym'): 81,
#              ('określonym', 'w'): 1153,
#              ('lub', 'dokument'): 11,
#              ('dokument', 'odprawy'): 6,
#              ('odprawy', 'celnej'): 25,
#              ('albo', 'w'): 442,
#              ('w', 'miesiącu'): 75,
#              ('miesiącu', 'następnym'): 5,
#              ('kropkę', 'skreśla'): 2,
#              ('się', 'i'): 94,
#              ('od', 'końca'): 91,
#              ('końca', 'miesiąca'): 37,
#              ('fakturę', 'lub'): 3,
#              ('przypadku', 'nabycia'): 36,
#              ('nabycia', 'towarów'): 12,
#              ('procentowy', 'udział'): 17,
#              ('udział', 'wartości'): 1,
#              ('wartości', 'sprzedaży'): 9,
#              ('towarów', 'opodatkowanych'): 8,
#              ('opodatkowanych', 'w'): 14,
#              ('w', 'wartości'): 18,
#              ('sprzedaży', 'ogółem'): 1,
#              ('ogółem', 'oblicza'): 1,
#              ('oblicza', 'się'): 137,
#              ('się', 'na'): 1560,
#              ('podstawie', 'sprzedaży'): 1,
#              ('sprzedaży', 'z'): 8,
#              ('z', 'ostatnich'): 13,
#              ('ostatnich', 'sześciu'): 3,
#              ('podatnicy', 'dokonujący'): 4,
#              ('dokonujący', 'czynności'): 11,
#              ('okresie', 'krótszym'): 7,
#              ('krótszym', 'niż'): 80,
#              ('niż', 'sześć'): 21,
#              ('sześć', 'miesięcy'): 52,
#              ('miesięcy', 'obliczają'): 1,
#              ('obliczają', 'procentowy'): 1,
#              ('udział', 'zgodnie'): 2,
#              ('przy', 'czym'): 298,
#              ('czym', 'po'): 3,
#              ('po', 'upływie'): 1627,
#              ('upływie', 'sześciu'): 16,
#              ('od', 'rozpoczęcia'): 21,
#              ('rozpoczęcia', 'działalności'): 86,
#              ('działalności', 'wyliczają'): 1,
#              ('wyliczają', 'ten'): 1,
#              ('ten', 'udział'): 1,
#              ('i', 'dokonują'): 4,
#              ('dokonują', 'korekty'): 1,
#              ('korekty', 'podatku'): 3,
#              ('gdy', 'kwota'): 20,
#              ('kwota', 'zwrotu'): 4,
#              ('podatku', 'dla'): 5,
#              ('dla', 'podatnika'): 12,
#              ('podatnika', 'dokonującego'): 2,
#              ('dokonującego', 'sprzedaży'): 2,
#              ('opodatkowanych', 'stawkami'): 2,
#              ('stawkami', 'niższymi'): 4,
#              ('niższymi', 'niż'): 1,
#              ('niż', 'stawka'): 12,
#              ('stawka', 'określona'): 3,
#              ('przekracza', 'kwotę'): 22,
#              ('kwotę', 'wynoszącą'): 7,
#              ('całości', 'obrotu'): 2,
#              ('obrotu', 'opodatkowanego'): 2,
#              ('opodatkowanego', 'stawkami'): 2,
#              ('skarbowy', 'może'): 6,
#              ('może', 'na'): 51,
#              ('na', 'czas'): 889,
#              ('czas', 'nie'): 148,
#              ('nie', 'dłuższy'): 353,
#              ('dłuższy', 'niż'): 484,
#              ('niż', 'trzy'): 49,
#              ('trzy', 'miesiące'): 48,
#              ('miesiące', 'ograniczyć'): 1,
#              ('ograniczyć', 'jej'): 2,
#              ('jej', 'wysokość'): 20,
#              ('wysokość', 'do'): 2,
#              ('do', 'wysokości'): 333,
#              ('wysokości', 'tej'): 11,
#              ('podatku', 'następuje'): 3,
#              ('następuje', 'na'): 291,
#              ('na', 'rachunek'): 273,
#              ('rachunek', 'bankowy'): 102,
#              ('bankowy', 'podatnika'): 4,
#              ('podatnika', 'w'): 25,
#              ('dni', 'od'): 2475,
#              ('dnia', 'złożenia'): 211,
#              ('złożenia', 'rozliczenia'): 2,
#              ('rozliczenia', 'przez'): 1,
#              ('jeżeli', 'w'): 679,
#              ('zasadność', 'zwrotu'): 5,
#              ('zwrotu', 'wymaga'): 1,
#              ('wymaga', 'dodatkowego'): 4,
#              ('dodatkowego', 'sprawdzenia'): 1,
#              ('może', 'dokonać'): 71,
#              ('dokonać', 'zwrotu'): 4,
#              ('podatku', 'ratalnie'): 1,
#              ('ratalnie', 'w'): 1,
#              ('w', 'dwóch'): 73,
#              ('dwóch', 'równych'): 7,
#              ('równych', 'ratach'): 21,
#              ('ratach', 'w'): 8,
#              ('ciągu', 'dwóch'): 41,
#              ('dwóch', 'miesięcy'): 56,
#              ('miesięcy', 'następujących'): 6,
#              ('następujących', 'po'): 28,
#              ('po', 'miesiącu'): 130,
#              ('którym', 'wystąpiła'): 6,
#              ('wystąpiła', 'sytuacja'): 2,
#              ('sytuacja', 'uzasadniająca'): 2,
#              ('uzasadniająca', 'zwrot'): 2,
#              ('rozliczenie', 'powinno'): 2,
#              ('być', 'złożone'): 40,
#              ('złożone', 'w'): 42,
#              ('w', 'terminie'): 4061,
#              ('terminie', 'do'): 684,
#              ('dnia', 'miesiąca'): 144,
#              ('miesiąca', 'następującego'): 146,
#              ('następującego', 'po'): 257,
#              ('się', 'art'): 2328,
#              ('może', 'określić'): 435,
#              ('określić', 'listę'): 3,
#              ('usług', 'lub'): 28,
#              ('lub', 'przypadki'): 2,
#              ('w', 'których'): 934,
#              ('których', 'nabycie'): 3,
#              ('nabycie', 'towarów'): 7,
#              ('nie', 'uprawnia'): 5,
#              ('uprawnia', 'do'): 33,
#              ('do', 'obniżenia'): 12,
#              ('obniżenia', 'podatku'): 8,
#              ('należnego', 'oraz'): 1,
#              ('oraz', 'zwrotu'): 24,
#              ('o', 'którym'): 9184,
#              ('którym', 'mowa'): 9171,
#              ('określi', 'przypadki'): 3,
#              ('przypadki', 'i'): 15,
#              ('i', 'warunki'): 283,
#              ('warunki', 'zwrotu'): 12,
#              ('zwrotu', 'podatku'): 44,
#              ('naliczonego', 'przy'): 3,
#              ('przy', 'nabyciu'): 6,
#              ('nabyciu', 'towarów'): 3,
#              ('służących', 'całkowicie'): 2,
#              ('całkowicie', 'lub'): 32,
#              ('lub', 'częściowo'): 41,
#              ('częściowo', 'czynnościom'): 2,
#              ('czynnościom', 'zwolnionym'): 2,
#              ('zwolnionym', 'od'): 5,
#              ('określić', 'inne'): 10,
#              ('inne', 'niż'): 299,
#              ('niż', 'wymienione'): 200,
#              ('wymienione', 'w'): 691,
#              ('przypadki', 'nabycia'): 1,
#              ('usług', 'uprawniające'): 1,
#              ('uprawniające', 'do'): 41,
#              ('należnego', 'lub'): 1,
#              ('lub', 'zwrotu'): 14,
#              ('określić', 'przypadki'): 9,
#              ('gdy', 'podatek'): 1,
#              ('naliczony', 'może'): 1,
#              ('może', 'być'): 2681,
#              ('być', 'zwrócony'): 4,
#              ('zwrócony', 'jednostce'): 1,
#              ('jednostce', 'dokonującej'): 1,
#              ('dokonującej', 'zakupu'): 1,
#              ('oraz', 'określić'): 34,
#              ('określić', 'zasady'): 19,
#              ('zasady', 'dokonywanie'): 1,
#              ('dokonywanie', 'tego'): 1,
#              ('tego', 'zwrotu'): 4,
#              ('się', 'przecinkiem'): 596,
#              ('po', 'pkt'): 662,
#              ('się', 'pkt'): 1793,
#              ('zostało', 'udokumentowane'): 2,
#              ('udokumentowane', 'rachunkiem'): 1,
#              ('wyjątkiem', 'przypadku'): 27,
#              ('przypadku', 'określonego'): 10,
#              ('albo', 'fakturą'): 1,
#              ('fakturą', 'wystawioną'): 1,
#              ('wystawioną', 'niezgodnie'): 1,
#              ('niezgodnie', 'z'): 191,
#              ('nastąpiło', 'w'): 56,
#              ('wyniku', 'darowizny'): 1,
#              ('darowizny', 'lub'): 11,
#              ('lub', 'nieodpłatnego'): 3,
#              ('nieodpłatnego', 'przekazania'): 7,
#              ('przekazania', 'usługi'): 1,
#              ('nie', 'dotyczy'): 492,
#              ('wydatków', 'związanych'): 48,
#              ('związanych', 'z'): 1201,
#              ('z', 'nabyciem'): 11,
#              ('nabyciem', 'towarów'): 1,
#              ('przekazanych', 'towarów'): 1,
#              ('towarów', 'oraz'): 31,
#              ('oraz', 'świadczonych'): 4,
#              ('świadczonych', 'usług'): 26,
#              ('oraz', 'darowizn'): 1,
#              ('darowizn', 'określonych'): 1,
#              ('części', 'wydatków'): 2,
#              ('które', 'nie'): 350,
#              ('nie', 'zostały'): 242,
#              ('zostały', 'zaliczone'): 23,
#              ('zaliczone', 'do'): 65,
#              ('do', 'kosztów'): 141,
#              ('kosztów', 'uzyskania'): 120,
#              ('uzyskania', 'przychodów'): 211,
#              ('przychodów', 'z'): 118,
#              ('z', 'powodu'): 490,
#              ('powodu', 'przekroczeń'): 1,
#              ('przekroczeń', 'norm'): 1,
#              ('norm', 'w'): 7,
#              ('podatku', 'dochodowym'): 354,
#              ('od', 'importu'): 6,
#              ('towarów', 'stanowiących'): 3,
#              ('stanowiących', 'wkłady'): 1,
#              ('wkłady', 'niepieniężne'): 33,
#              ('do', 'spółek'): 55,
#              ('spółek', 'prawa'): 22,
#              ('prawa', 'handlowego'): 60,
#              ('oraz', 'wyrazy'): 92,
#              ('otrzymują', 'brzmienie'): 983,
#              ('przedmiotu', 'i'): 14,
#              ('i', 'podstawy'): 15,
#              ('podstawy', 'opodatkowania'): 127,
#              ('organ', 'podatkowy'): 232,
#              ('podatkowy', 'określa'): 11,
#              ('określa', 'wartość'): 3,
#              ('wartość', 'nie'): 25,
#              ('nie', 'zaewidencjonowanej'): 1,
#              ('zaewidencjonowanej', 'sprzedaży'): 1,
#              ('sprzedaży', 'w'): 37,
#              ('drodze', 'oszacowania'): 18,
#              ('oszacowania', 'i'): 6,
#              ('i', 'ustala'): 15,
#              ('ustala', 'podatek'): 1,
#              ('podatek', 'przy'): 1,
#              ('przy', 'zastosowaniu'): 133,
#              ('zastosowaniu', 'stawki'): 5,
#              ('z', 'tym'): 837,
#              ('tym', 'że'): 569,
#              ('że', 'kwota'): 11,
#              ('kwota', 'ustalonego'): 1,
#              ('ustalonego', 'w'): 39,
#              ('w', 'ten'): 71,
#              ('ten', 'sposób'): 65,
#              ('sposób', 'podatku'): 1,
#              ('podatku', 'ulega'): 1,
#              ('ulega', 'podwyższeniu'): 22,
#              ('podwyższeniu', 'o'): 11,
#              ('wysokość', 'podatku'): 16,
#              ('wyniku', 'czego'): 7,
#              ('czego', 'nastąpiło'): 1,
#              ('nastąpiło', 'jego'): 3,
#              ('jego', 'zawyżenie'): 1,
#              ('kwotę', 'podatku'): 19,
#              ('należnego', 'zwiększa'): 1,
#              ('się', 'o'): 783,
#              ('o', 'kwotę'): 190,
#              ('kwotę', 'trzykrotności'): 1,
#              ('trzykrotności', 'tego'): 1,
#              ('tego', 'zawyżenia'): 1,
#              ('prezesem', 'polskiego'): 2,
#              ('polskiego', 'komitetu'): 17,
#              ('komitetu', 'normalizacji'): 3,
#              ('miar', 'i'): 22,
#              ('i', 'jakości'): 60,
#              ('się', 'zdanie'): 229,
#              ('zdanie', 'drugie'): 343,
#              ('drugie', 'w'): 128,
#              ('dla', 'obliczenia'): 5,
#              ('obliczenia', 'tych'): 2,
#              ('tych', 'proporcji'): 1,
#              ('proporcji', 'przyjmuje'): 1,
#              ('przyjmuje', 'się'): 193,
#              ('się', 'wyłącznie'): 85,
#              ('wyłącznie', 'towary'): 7,
#              ('towary', 'przeznaczone'): 24,
#              ('przeznaczone', 'do'): 327,
#              ('do', 'dalszej'): 14,
#              ('dalszej', 'sprzedaży'): 3,
#              ('sprzedaży', 'według'): 2,
#              ('według', 'cen'): 49,
#              ('cen', 'uwzględniających'): 1,
#              ('uwzględniających', 'podatek'): 3,
#              ('lub', 'rachunek'): 8,
#              ('uproszczony', 'stwierdzający'): 2,
#              ('stwierdzający', 'w'): 1,
#              ('w', 'szczególności'): 3474,
#              ('a', 'po'): 86,
#              ('po', 'wyrazach'): 935,
#              ('przypadku', 'czynności'): 5,
#              ('czynności', 'wymienionych'): 22,
#              ('wystawiane', 'są'): 2,
#              ('są', 'rachunki'): 3,
#              ('rachunki', 'uproszczone'): 1,
#              ('zdanie', 'pierwsze'): 120,
#              ('pierwsze', 'otrzymuje'): 71,
#              ('akcyzie', 'podlegają'): 1,
#              ('podlegają', 'również'): 32,
#              ('również', 'nadmierne'): 1,
#              ('nadmierne', 'ubytki'): 2,
#              ('ubytki', 'lub'): 2,
#              ('lub', 'zawinione'): 2,
#              ('zawinione', 'niedobory'): 2,
#              ('niedobory', 'wyrobów'): 2,
#              ('akcyzowych', 'wymienionych'): 5,
#              ('i', 'poz'): 108,
#              ('wysokość', 'dopuszczalnych'): 1,
#              ('dopuszczalnych', 'ubytków'): 17,
#              ('ubytków', 'wyrobów'): 22,
#              ('akcyzowych', 'dla'): 1,
#              ('dla', 'poszczególnych'): 149,
#              ('poszczególnych', 'producentów'): 2,
#              ('producentów', 'ustalają'): 1,
#              ('ustalają', 'dyrektorzy'): 1,
#              ('dyrektorzy', 'urzędów'): 26,
#              ('urzędów', 'kontroli'): 10,
#              ('kontroli', 'skarbowej'): 242,
#              ('uwzględnieniem', 'warunków'): 21,
#              ('warunków', 'technicznych'): 30,
#              ('technicznych', 'podatnika'): 1,
#              ('towarów', 'akcyzowych'): 1,
#              ('akcyzowych', 'podstawą'): 1,
#              ('opodatkowania', 'akcyzą'): 18,
#              ('akcyzą', 'jest'): 10,
#              ('jest', 'ich'): 25,
#              ('ich', 'wartość'): 51,
#              ('o', 'cło'): 8,
#              ('cło', 'obliczone'): 1,
#              ('obliczone', 'według'): 6,
#              ('według', 'stawki'): 16,
#              ('stawki', 'podstawowej'): 6,
#              ('podstawowej', 'i'): 13,
#              ('także', 'w'): 380,
#              ('gdy', 'towary'): 8,
#              ('towary', 'te'): 32,
#              ('te', 'na'): 2,
#              ('podstawie', 'odrębnych'): 506,
#              ('odrębnych', 'przepisów'): 600,
#              ('przepisów', 'zostały'): 1,
#              ('zostały', 'w'): 25,
#              ('w', 'całości'): 592,
#              ('całości', 'lub'): 362,
#              ('lub', 'w'): 1564,
#              ('w', 'części'): 811,
#              ('części', 'zwolnione'): 1,
#              ('cła', 'bądź'): 1,
#              ('bądź', 'cło'): 1,
#              ('cło', 'zostało'): 2,
#              ('zostało', 'zawieszone'): 12,
#              ('zawieszone', 'albo'): 2,
#              ('albo', 'zastosowano'): 3,
#              ('zastosowano', 'preferencyjną'): 3,
#              ('preferencyjną', 'stawkę'): 2,
#              ('stawkę', 'celną'): 6,
#              ('jeżeli', 'podstawowa'): 1,
#              ('podstawowa', 'stawka'): 1,
#              ('stawka', 'celna'): 4,
#              ('celna', 'nie'): 8,
#              ('nie', 'została'): 165,
#              ('została', 'określona'): 10,
#              ('się', 'stawkę'): 18,
#              ('stawkę', 'autonomiczną'): 1,
#              ('finansów', 'może'): 56,
#              ('inną', 'podstawę'): 2,
#              ('podstawę', 'odpodatkowania'): 1,
#              ('odpodatkowania', 'akcyzą'): 1,
#              ('akcyzą', 'w'): 2,
#              ('gdy', 'podatnikami'): 2,
#              ('podatnikami', 'akcyzy'): 2,
#              ('akcyzy', 'są'): 11,
#              ('są', 'osoby'): 30,
#              ('osoby', 'lub'): 65,
#              ('lub', 'jednostki'): 106,
#              ('jednostki', 'inne'): 7,
#              ('niż', 'producent'): 1,
#              ('producent', 'lub'): 49,
#              ('lub', 'importer'): 33,
#              ('importer', 'wyrobów'): 1,
#              ('wartości', 'celnej'): 64,
#              ('celnej', 'powiększonej'): 2,
#              ('powiększonej', 'o'): 18,
#              ('do', 'podstawy'): 23,
#              ('opodatkowania', 'określonej'): 3,
#              ('w', 'procencie'): 4,
#              ('procencie', 'podstawy'): 2,
#              ('usługi', 'remontowe'): 1,
#              ('remontowe', 'obiektów'): 1,
#              ('obiektów', 'pływających'): 5,
#              ('świadczone', 'na'): 5,
#              ('na', 'rzecz'): 1106,
#              ('rzecz', 'osób'): 46,
#              ('osób', 'zagranicznych'): 26,
#              ('zagranicznych', 'w'): 28,
#              ('przepisów', 'prawa'): 358,
#              ('prawa', 'dewizowego'): 24,
#              ('nie', 'będących'): 84,
#              ('będących', 'podatnikami'): 14,
#              ('podatnikami', 'podatku'): 32,
#              ('usługi', 'polegające'): 4,
#              ('polegające', 'na'): 98,
#              ('na', 'naprawie'): 3,
#              ('przerobie', 'lub'): 1,
#              ('lub', 'przetwarzaniu'): 6,
#              ('przetwarzaniu', 'towarów'): 1,
#              ('towarów', 'przywiezionych'): 10,
#              ('przywiezionych', 'na'): 3,
#              ('na', 'polski'): 268,
#              ('polski', 'obszar'): 325,
#              ('obszar', 'celny'): 342,
#              ('celny', 'na'): 12,
#              ('czas', 'oznaczony'): 223,
#              ('jeżeli', 'towary'): 28,
#              ('te', 'zostaną'): 7,
#              ...})

# %% [markdown]
# ### Use pointwise mutual information to compute the measure for all pairs of words.

# %%
words_global = []

for _, content in tokenized_bills.items():
    for word in content:
        if word.isalpha():
            words_global.append(word)

# %%
words_global_counter = Counter(words_global)

# %%
number_of_words = sum(words_global_counter.values())
number_of_bigrams = sum(bigrams_global_clean.values())
(number_of_words, number_of_bigrams)
# Out:
# (3568022, 2756037)

# %%
pmi = defaultdict(float)

for bigram, value in bigrams_global_clean.items():
    pmi[bigram] = np.log2( (value/number_of_bigrams) / ((words_global_counter[bigram[0]]/number_of_words) * (words_global_counter[bigram[1]]/number_of_words) ))

# %% [markdown]
# ### Sort the word pairs according to that measure in the descending order and determine top 10 entries.

# %%
pmi_sorted = sorted(pmi.items(), key=lambda x:x[1], reverse = True)

# %%
pd.DataFrame.from_dict(pmi_sorted)
# Out:
#                                  0          1
# 0            (kołowe, jednoosiowe)  22.139222
# 1               (zbrojeń, żelbeto)  22.139222
# 2       (prefabrykatów, wnętrzowe)  22.139222
# 3               (gołe, aluminiowe)  22.139222
# 4       (polistyrenu, spienionego)  22.139222
# ...                            ...        ...
# 524688                      (w, o) -10.462220
# 524689                   (w, oraz) -10.513418
# 524690                    (w, lub) -10.962108
# 524691                     (na, w) -11.107124
# 524692                     (w, do) -11.369218
#
# [524693 rows x 2 columns]

# %%
pmi_sorted[:10]
# Out:
# [(('kołowe', 'jednoosiowe'), 22.139222334408554),
#  (('zbrojeń', 'żelbeto'), 22.139222334408554),
#  (('prefabrykatów', 'wnętrzowe'), 22.139222334408554),
#  (('gołe', 'aluminiowe'), 22.139222334408554),
#  (('polistyrenu', 'spienionego'), 22.139222334408554),
#  (('objaśnieniem', 'figur'), 22.139222334408554),
#  (('wkładzie', 'wnoszonym'), 22.139222334408554),
#  (('doktorem', 'habilitowanym'), 22.139222334408554),
#  (('losy', 'loteryjne'), 22.139222334408554),
#  (('uw', 'zględnieniu'), 22.139222334408554)]

# %% [markdown]
# ### Filter bigrams with number of occurrences lower than 5. Determine top 10 entries for the remaining dataset (>=5 occurrences).

# %%
bigrams_filtered = defaultdict(int)

for k, v in bigrams_global_clean.items():
    if v >= 5:
        bigrams_filtered[k] = v

# %%
bigrams_filtered
# Out:
# defaultdict(int,
#             {('ustawa', 'z'): 1190,
#              ('z', 'dnia'): 9527,
#              ('o', 'zmianie'): 1299,
#              ('zmianie', 'ustawy'): 850,
#              ('ustawy', 'o'): 1444,
#              ('o', 'podatku'): 533,
#              ('podatku', 'od'): 382,
#              ('od', 'towarów'): 273,
#              ('towarów', 'i'): 530,
#              ('i', 'usług'): 565,
#              ('usług', 'oraz'): 122,
#              ('oraz', 'o'): 945,
#              ('podatku', 'akcyzowym'): 75,
#              ('akcyzowym', 'art'): 15,
#              ('w', 'ustawie'): 5180,
#              ('ustawie', 'z'): 3661,
#              ('i', 'nr'): 8435,
#              ('wprowadza', 'się'): 1849,
#              ('się', 'następujące'): 1855,
#              ('następujące', 'zmiany'): 1808,
#              ('w', 'art'): 32043,
#              ('dotychczasowa', 'treść'): 37,
#              ('treść', 'otrzymuje'): 37,
#              ('otrzymuje', 'oznaczenie'): 41,
#              ('oznaczenie', 'ust'): 62,
#              ('dodaje', 'się'): 8195,
#              ('się', 'ust'): 3484,
#              ('w', 'brzmieniu'): 7281,
#              ('rada', 'ministrów'): 890,
#              ('ministrów', 'może'): 145,
#              ('może', 'określać'): 52,
#              ('w', 'drodze'): 7127,
#              ('drodze', 'rozporządzenia'): 4691,
#              ('towary', 'i'): 21,
#              ('i', 'usługi'): 27,
#              ('z', 'wyjątkiem'): 1619,
#              ('wyjątkiem', 'wyrobów'): 19,
#              ('wyrobów', 'akcyzowych'): 469,
#              ('akcyzowych', 'i'): 6,
#              ('i', 'wyrobów'): 139,
#              ('wyrobów', 'z'): 41,
#              ('z', 'metali'): 33,
#              ('metali', 'szlachetnych'): 24,
#              ('do', 'których'): 412,
#              ('których', 'nie'): 153,
#              ('nie', 'stosuje'): 1414,
#              ('stosuje', 'się'): 6535,
#              ('się', 'przepisów'): 179,
#              ('przepisów', 'ustawy'): 782,
#              ('w', 'pkt'): 3765,
#              ('zastępuje', 'się'): 4779,
#              ('się', 'wyrazami'): 2942,
#              ('kropkę', 'zastępuje'): 643,
#              ('się', 'średnikiem'): 174,
#              ('średnikiem', 'i'): 169,
#              ('i', 'dodaje'): 893,
#              ('dodaje', 'wyrazy'): 100,
#              ('w', 'pozostałych'): 97,
#              ('pozostałych', 'przypadkach'): 45,
#              ('właściwym', 'urzędem'): 6,
#              ('urzędem', 'skarbowym'): 6,
#              ('urząd', 'skarbowy'): 138,
#              ('otrzymuje', 'brzmienie'): 9553,
#              ('jeżeli', 'sprzedaż'): 17,
#              ('sprzedaż', 'towaru'): 7,
#              ('towaru', 'lub'): 56,
#              ('lub', 'wykonanie'): 21,
#              ('wykonanie', 'usługi'): 6,
#              ('powinno', 'być'): 155,
#              ('być', 'potwierdzone'): 11,
#              ('obowiązek', 'podatkowy'): 109,
#              ('podatkowy', 'powstaje'): 19,
#              ('powstaje', 'z'): 93,
#              ('z', 'chwilą'): 356,
#              ('wystawienia', 'faktury'): 12,
#              ('faktury', 'lub'): 9,
#              ('lub', 'rachunku'): 11,
#              ('nie', 'później'): 820,
#              ('później', 'jednak'): 138,
#              ('jednak', 'niż'): 682,
#              ('niż', 'w'): 514,
#              ('dniu', 'od'): 14,
#              ('od', 'dnia'): 5324,
#              ('dnia', 'wydania'): 112,
#              ('lub', 'wykonania'): 30,
#              ('wykonania', 'usługi'): 14,
#              ('następuje', 'nie'): 26,
#              ('później', 'niż'): 688,
#              ('w', 'ostatnim'): 92,
#              ('ostatnim', 'dniu'): 49,
#              ('dniu', 'miesiąca'): 16,
#              ('w', 'którym'): 1825,
#              ('którym', 'wydano'): 27,
#              ('towar', 'lub'): 12,
#              ('w', 'ust'): 23557,
#              ('i', 'rachunków'): 22,
#              ('rachunków', 'uproszczonych'): 7,
#              ('po', 'ust'): 1541,
#              ('przepis', 'ust'): 613,
#              ('się', 'również'): 378,
#              ('również', 'w'): 245,
#              ('w', 'przypadku'): 6027,
#              ('przypadku', 'eksportu'): 7,
#              ('eksportu', 'towarów'): 10,
#              ('wywóz', 'towarów'): 18,
#              ('nastąpi', 'w'): 27,
#              ('w', 'ciągu'): 1050,
#              ('ciągu', 'sześciu'): 15,
#              ('sześciu', 'miesięcy'): 100,
#              ('miesięcy', 'od'): 1284,
#              ('dnia', 'otrzymania'): 297,
#              ('przedstawi', 'w'): 5,
#              ('w', 'urzędzie'): 190,
#              ('urzędzie', 'skarbowym'): 27,
#              ('zabezpieczenie', 'majątkowe'): 13,
#              ('kwoty', 'zwrotu'): 7,
#              ('zwrotu', 'różnicy'): 19,
#              ('różnicy', 'podatku'): 29,
#              ('o', 'której'): 5530,
#              ('której', 'mowa'): 5511,
#              ('mowa', 'w'): 28471,
#              ('import', 'towarów'): 7,
#              ('towarów', 'zwolnionych'): 10,
#              ('zwolnionych', 'od'): 52,
#              ('od', 'cła'): 237,
#              ('cła', 'na'): 23,
#              ('na', 'podstawie'): 6677,
#              ('podstawie', 'art'): 1496,
#              ('oraz', 'art'): 785,
#              ('ustawy', 'z'): 3075,
#              ('prawo', 'celne'): 19,
#              ('oraz', 'z'): 4265,
#              ('w', 'nawiasie'): 6,
#              ('skreśla', 'się'): 2710,
#              ('się', 'wyrazy'): 2180,
#              ('niż', 'na'): 124,
#              ('przypadku', 'gdy'): 826,
#              ('wykonania', 'czynności'): 58,
#              ('czynności', 'podlegających'): 19,
#              ('podlegających', 'opodatkowaniu'): 30,
#              ('nie', 'zostało'): 97,
#              ('zostało', 'zgłoszone'): 12,
#              ('zgłoszone', 'zgodnie'): 5,
#              ('zgodnie', 'z'): 2555,
#              ('z', 'ust'): 231,
#              ('który', 'dokonał'): 42,
#              ('wykreśla', 'z'): 9,
#              ('z', 'urzędu'): 645,
#              ('podatnika', 'z'): 15,
#              ('z', 'rejestru'): 305,
#              ('a', 'w'): 2182,
#              ('w', 'przypadkach'): 755,
#              ('przypadkach', 'określonych'): 228,
#              ('określonych', 'w'): 4041,
#              ('następuje', 'również'): 9,
#              ('numeru', 'identyfikacyjnego'): 24,
#              ('się', 'odpowiednio'): 3177,
#              ('odpowiednio', 'do'): 747,
#              ('do', 'kwoty'): 87,
#              ('podatku', 'wynikającej'): 5,
#              ('wynikającej', 'z'): 177,
#              ('z', 'deklaracji'): 13,
#              ('deklaracji', 'podatkowej'): 26,
#              ('przepisu', 'ust'): 259,
#              ('się', 'do'): 2109,
#              ('do', 'podatników'): 58,
#              ('podatników', 'zwolnionych'): 5,
#              ('od', 'podatku'): 180,
#              ('usług', 'na'): 33,
#              ('oraz', 'podmiotów'): 27,
#              ('podmiotów', 'wykonujących'): 17,
#              ('wyłącznie', 'czynności'): 14,
#              ('zwolnione', 'od'): 109,
#              ('podatku', 'na'): 34,
#              ('lub', 'na'): 558,
#              ('podstawie', 'przepisów'): 863,
#              ('przepisów', 'wydanych'): 56,
#              ('wydanych', 'na'): 546,
#              ('chyba', 'że'): 1306,
#              ('że', 'przysługuje'): 5,
#              ('przysługuje', 'im'): 13,
#              ('zwrot', 'różnicy'): 10,
#              ('podatku', 'lub'): 31,
#              ('lub', 'zwrot'): 7,
#              ('zwrot', 'podatku'): 16,
#              ('podatku', 'naliczonego'): 25,
#              ('z', 'art'): 822,
#              ('zwalnia', 'się'): 139,
#              ('się', 'od'): 463,
#              ('u', 'których'): 39,
#              ('których', 'wartość'): 57,
#              ('wartość', 'sprzedaży'): 20,
#              ('sprzedaży', 'towarów'): 98,
#              ('towarów', 'w'): 50,
#              ('w', 'rozumieniu'): 1786,
#              ('rozumieniu', 'art'): 326,
#              ('a', 'także'): 3783,
#              ('także', 'wartość'): 8,
#              ('towarów', 'lub'): 73,
#              ('lub', 'usług'): 86,
#              ('usług', 'nie'): 10,
#              ('nie', 'przekroczyła'): 14,
#              ('łącznie', 'w'): 12,
#              ('w', 'poprzednim'): 104,
#              ('poprzednim', 'roku'): 77,
#              ('roku', 'podatkowym'): 261,
#              ('mld', 'zł'): 10,
#              ('podatek', 'dochodowy'): 123,
#              ('dochodowy', 'w'): 17,
#              ('w', 'formie'): 1159,
#              ('formie', 'karty'): 79,
#              ('karty', 'podatkowej'): 98,
#              ('w', 'zakresie'): 5456,
#              ('zakresie', 'działalności'): 60,
#              ('działalności', 'objętej'): 66,
#              ('z', 'uwzględnieniem'): 1183,
#              ('uwzględnieniem', 'art'): 72,
#              ('o', 'których'): 13885,
#              ('których', 'mowa'): 13858,
#              ('ze', 'zwolnienia'): 80,
#              ('zwolnienia', 'określonego'): 7,
#              ('określonego', 'w'): 917,
#              ('pod', 'warunkiem'): 480,
#              ('zawiadomienia', 'o'): 138,
#              ('o', 'tym'): 474,
#              ('właściwego', 'urzędu'): 67,
#              ('urzędu', 'skarbowego'): 226,
#              ('obowiązuje', 'do'): 17,
#              ('do', 'końca'): 274,
#              ('końca', 'roku'): 116,
#              ('roku', 'podatkowego'): 214,
#              ('jeżeli', 'wartość'): 147,
#              ('u', 'podatników'): 10,
#              ('podstawie', 'ust'): 236,
#              ('traci', 'moc'): 149,
#              ('moc', 'w'): 18,
#              ('w', 'momencie'): 39,
#              ('tej', 'kwoty'): 59,
#              ('przekroczenia', 'tej'): 5,
#              ('ponad', 'tę'): 11,
#              ('tę', 'kwotę'): 25,
#              ('za', 'zgodą'): 442,
#              ('zgodą', 'właściwego'): 12,
#              ('podatnik', 'może'): 18,
#              ('może', 'zmniejszyć'): 8,
#              ('podatek', 'należny'): 17,
#              ('o', 'podatek'): 19,
#              ('podatek', 'naliczony'): 21,
#              ('wynikający', 'z'): 81,
#              ('z', 'rachunków'): 13,
#              ('dokonane', 'przed'): 32,
#              ('przed', 'dniem'): 1464,
#              ('dniem', 'utraty'): 13,
#              ('utraty', 'zwolnienia'): 6,
#              ('sporządzenia', 'spisu'): 15,
#              ('spisu', 'z'): 19,
#              ('z', 'natury'): 38,
#              ('tych', 'towarów'): 57,
#              ('posiadanych', 'w'): 11,
#              ('w', 'dniu'): 1008,
#              ('przypadku', 'podatników'): 20,
#              ('określoną', 'w'): 191,
#              ('rozumie', 'się'): 994,
#              ('podatników', 'dokonujących'): 7,
#              ('będącej', 'przedmiotem'): 20,
#              ('przedmiotem', 'umowy'): 21,
#              ('wartość', 'sprzedanych'): 14,
#              ('sprzedanych', 'towarów'): 13,
#              ('podatnicy', 'będący'): 6,
#              ('zakładami', 'pracy'): 5,
#              ('pracy', 'chronionej'): 22,
#              ('rozumieniu', 'przepisów'): 669,
#              ('przepisów', 'o'): 1176,
#              ('o', 'zatrudnieniu'): 94,
#              ('zatrudnieniu', 'i'): 84,
#              ('i', 'rehabilitacji'): 36,
#              ('rehabilitacji', 'zawodowej'): 78,
#              ('zawodowej', 'osób'): 18,
#              ('osób', 'niepełnosprawnych'): 252,
#              ('zwolnienie', 'od'): 95,
#              ('bez', 'względu'): 227,
#              ('względu', 'na'): 1410,
#              ('na', 'wartość'): 17,
#              ('warunkiem', 'złożenia'): 9,
#              ('złożenia', 'przez'): 82,
#              ('przez', 'podatnika'): 157,
#              ('pisemnego', 'oświadczenia'): 29,
#              ('we', 'właściwym'): 77,
#              ('właściwym', 'urzędzie'): 16,
#              ('wykonywanie', 'czynności'): 121,
#              ('czynności', 'określonych'): 39,
#              ('ciągu', 'roku'): 128,
#              ('może', 'wybrać'): 6,
#              ('określona', 'w'): 167,
#              ('w', 'złożonym'): 6,
#              ('nie', 'przekroczy'): 35,
#              ('w', 'proporcji'): 18,
#              ('proporcji', 'do'): 13,
#              ('do', 'okresu'): 168,
#              ('wymienionej', 'w'): 441,
#              ('składa', 'oświadczenie'): 16,
#              ('oświadczenie', 'w'): 8,
#              ('świadczenia', 'usługi'): 15,
#              ('określona', 'zgodnie'): 7,
#              ('od', 'momentu'): 17,
#              ('tej', 'wartości'): 16,
#              ('ponad', 'wartość'): 7,
#              ('określoną', 'zgodnie'): 11,
#              ('zdanie', 'trzecie'): 36,
#              ('jeżeli', 'podatnicy'): 10,
#              ('określeni', 'w'): 15,
#              ('związki', 'z'): 8,
#              ('niższą', 'niż'): 16,
#              ('związek', 'ten'): 7,
#              ('ten', 'nie'): 122,
#              ('nie', 'istniał'): 5,
#              ('w', 'wyniku'): 935,
#              ('wyniku', 'tych'): 8,
#              ('od', 'początku'): 83,
#              ('początku', 'roku'): 64,
#              ('poczynając', 'od'): 77,
#              ('i', 'ust'): 423,
#              ('podwyższeniu', 'w'): 13,
#              ('w', 'stopniu'): 88,
#              ('stopniu', 'odpowiadającym'): 22,
#              ('odpowiadającym', 'wskaźnikowi'): 12,
#              ('wskaźnikowi', 'cen'): 6,
#              ('usług', 'w'): 70,
#              ('w', 'okresie'): 1460,
#              ('okresie', 'pierwszych'): 18,
#              ('pierwszych', 'trzech'): 9,
#              ('trzech', 'kwartałów'): 11,
#              ('kwartałów', 'roku'): 6,
#              ('roku', 'poprzedzającego'): 146,
#              ('poprzedzającego', 'rok'): 144,
#              ('rok', 'kalendarzowy'): 81,
#              ('kalendarzowy', 'w'): 9,
#              ('w', 'stosunku'): 1368,
#              ('stosunku', 'do'): 1189,
#              ('do', 'tego'): 380,
#              ('tego', 'samego'): 225,
#              ('samego', 'okresu'): 6,
#              ('okresu', 'roku'): 8,
#              ('roku', 'ubiegłego'): 8,
#              ('do', 'importu'): 8,
#              ('importu', 'towarów'): 15,
#              ('oraz', 'podatników'): 5,
#              ('wyroby', 'z'): 30,
#              ('lub', 'z'): 435,
#              ('z', 'udziałem'): 234,
#              ('udziałem', 'tych'): 12,
#              ('tych', 'metali'): 5,
#              ('wyroby', 'akcyzowe'): 118,
#              ('wymienionych', 'w'): 1053,
#              ('w', 'załączniku'): 424,
#              ('załączniku', 'nr'): 302,
#              ('świadczących', 'usługi'): 61,
#              ('oraz', 'usługi'): 17,
#              ('usługi', 'w'): 124,
#              ('zakresie', 'doradztwa'): 6,
#              ('minister', 'finansów'): 407,
#              ('finansów', 'określi'): 78,
#              ('listę', 'towarów'): 10,
#              ('i', 'pkt'): 177,
#              ('o', 'statystyce'): 50,
#              ('statystyce', 'państwowej'): 6,
#              ('finansów', 'w'): 68,
#              ('w', 'porozumieniu'): 1709,
#              ('porozumieniu', 'z'): 1733,
#              ('z', 'prezesem'): 85,
#              ('prezesem', 'głównego'): 20,
#              ('głównego', 'urzędu'): 407,
#              ('urzędu', 'statystycznego'): 247,
#              ('listopada', 'roku'): 28,
#              ('rok', 'podatkowy'): 207,
#              ('drodze', 'obwieszczenia'): 117,
#              ('uwzględnieniem', 'zasady'): 18,
#              ('określonej', 'w'): 598,
#              ('do', 'pełnych'): 32,
#              ('mln', 'zł'): 33,
#              ('w', 'zdaniu'): 355,
#              ('zdaniu', 'drugim'): 67,
#              ('drugim', 'po'): 19,
#              ('po', 'wyrazie'): 551,
#              ('się', 'wyraz'): 242,
#              ('lub', 'rachunków'): 14,
#              ('podstawą', 'opodatkowania'): 35,
#              ('opodatkowania', 'w'): 87,
#              ('w', 'imporcie'): 9,
#              ('imporcie', 'towarów'): 9,
#              ('towarów', 'jest'): 7,
#              ('jest', 'wartość'): 56,
#              ('wartość', 'celna'): 73,
#              ('celna', 'powiększona'): 13,
#              ('powiększona', 'o'): 40,
#              ('o', 'należne'): 21,
#              ('należne', 'cło'): 16,
#              ('cło', 'i'): 8,
#              ('i', 'podatek'): 11,
#              ('podatek', 'importowy'): 8,
#              ('jeżeli', 'przedmiotem'): 70,
#              ('przedmiotem', 'importu'): 8,
#              ('są', 'towary'): 30,
#              ('towary', 'opodatkowane'): 5,
#              ('opodatkowane', 'podatkiem'): 8,
#              ('podatkiem', 'akcyzowym'): 12,
#              ('wartość', 'celną'): 18,
#              ('powiększoną', 'o'): 24,
#              ('zwiększa', 'się'): 26,
#              ('również', 'o'): 29,
#              ('podatek', 'akcyzowy'): 26,
#              ('się', 'wyrazem'): 713,
#              ('obniżenie', 'kwoty'): 11,
#              ('kwoty', 'podatku'): 41,
#              ('podatku', 'należnego'): 47,
#              ('następuje', 'w'): 505,
#              ('w', 'rozliczeniu'): 23,
#              ('rozliczeniu', 'za'): 10,
#              ('za', 'miesiąc'): 55,
#              ('którym', 'podatnik'): 16,
#              ('podatnik', 'otrzymał'): 5,
#              ('przypadku', 'określonym'): 81,
#              ('określonym', 'w'): 1153,
#              ('lub', 'dokument'): 11,
#              ('dokument', 'odprawy'): 6,
#              ('odprawy', 'celnej'): 25,
#              ('albo', 'w'): 442,
#              ('w', 'miesiącu'): 75,
#              ('miesiącu', 'następnym'): 5,
#              ('się', 'i'): 94,
#              ('od', 'końca'): 91,
#              ('końca', 'miesiąca'): 37,
#              ('przypadku', 'nabycia'): 36,
#              ('nabycia', 'towarów'): 12,
#              ('procentowy', 'udział'): 17,
#              ('wartości', 'sprzedaży'): 9,
#              ('towarów', 'opodatkowanych'): 8,
#              ('opodatkowanych', 'w'): 14,
#              ('w', 'wartości'): 18,
#              ('oblicza', 'się'): 137,
#              ('się', 'na'): 1560,
#              ('sprzedaży', 'z'): 8,
#              ('z', 'ostatnich'): 13,
#              ('dokonujący', 'czynności'): 11,
#              ('okresie', 'krótszym'): 7,
#              ('krótszym', 'niż'): 80,
#              ('niż', 'sześć'): 21,
#              ('sześć', 'miesięcy'): 52,
#              ('przy', 'czym'): 298,
#              ('po', 'upływie'): 1627,
#              ('upływie', 'sześciu'): 16,
#              ('od', 'rozpoczęcia'): 21,
#              ('rozpoczęcia', 'działalności'): 86,
#              ('gdy', 'kwota'): 20,
#              ('podatku', 'dla'): 5,
#              ('dla', 'podatnika'): 12,
#              ('niż', 'stawka'): 12,
#              ('przekracza', 'kwotę'): 22,
#              ('kwotę', 'wynoszącą'): 7,
#              ('skarbowy', 'może'): 6,
#              ('może', 'na'): 51,
#              ('na', 'czas'): 889,
#              ('czas', 'nie'): 148,
#              ('nie', 'dłuższy'): 353,
#              ('dłuższy', 'niż'): 484,
#              ('niż', 'trzy'): 49,
#              ('trzy', 'miesiące'): 48,
#              ('jej', 'wysokość'): 20,
#              ('do', 'wysokości'): 333,
#              ('wysokości', 'tej'): 11,
#              ('następuje', 'na'): 291,
#              ('na', 'rachunek'): 273,
#              ('rachunek', 'bankowy'): 102,
#              ('podatnika', 'w'): 25,
#              ('dni', 'od'): 2475,
#              ('dnia', 'złożenia'): 211,
#              ('jeżeli', 'w'): 679,
#              ('zasadność', 'zwrotu'): 5,
#              ('może', 'dokonać'): 71,
#              ('w', 'dwóch'): 73,
#              ('dwóch', 'równych'): 7,
#              ('równych', 'ratach'): 21,
#              ('ratach', 'w'): 8,
#              ('ciągu', 'dwóch'): 41,
#              ('dwóch', 'miesięcy'): 56,
#              ('miesięcy', 'następujących'): 6,
#              ('następujących', 'po'): 28,
#              ('po', 'miesiącu'): 130,
#              ('którym', 'wystąpiła'): 6,
#              ('być', 'złożone'): 40,
#              ('złożone', 'w'): 42,
#              ('w', 'terminie'): 4061,
#              ('terminie', 'do'): 684,
#              ('dnia', 'miesiąca'): 144,
#              ('miesiąca', 'następującego'): 146,
#              ('następującego', 'po'): 257,
#              ('się', 'art'): 2328,
#              ('może', 'określić'): 435,
#              ('usług', 'lub'): 28,
#              ('w', 'których'): 934,
#              ('nabycie', 'towarów'): 7,
#              ('nie', 'uprawnia'): 5,
#              ('uprawnia', 'do'): 33,
#              ('do', 'obniżenia'): 12,
#              ('obniżenia', 'podatku'): 8,
#              ('oraz', 'zwrotu'): 24,
#              ('o', 'którym'): 9184,
#              ('którym', 'mowa'): 9171,
#              ('przypadki', 'i'): 15,
#              ('i', 'warunki'): 283,
#              ('warunki', 'zwrotu'): 12,
#              ('zwrotu', 'podatku'): 44,
#              ('przy', 'nabyciu'): 6,
#              ('całkowicie', 'lub'): 32,
#              ('lub', 'częściowo'): 41,
#              ('zwolnionym', 'od'): 5,
#              ('określić', 'inne'): 10,
#              ('inne', 'niż'): 299,
#              ('niż', 'wymienione'): 200,
#              ('wymienione', 'w'): 691,
#              ('uprawniające', 'do'): 41,
#              ('lub', 'zwrotu'): 14,
#              ('określić', 'przypadki'): 9,
#              ('może', 'być'): 2681,
#              ('oraz', 'określić'): 34,
#              ('określić', 'zasady'): 19,
#              ('się', 'przecinkiem'): 596,
#              ('po', 'pkt'): 662,
#              ('się', 'pkt'): 1793,
#              ('wyjątkiem', 'przypadku'): 27,
#              ('przypadku', 'określonego'): 10,
#              ('niezgodnie', 'z'): 191,
#              ('nastąpiło', 'w'): 56,
#              ('darowizny', 'lub'): 11,
#              ('nieodpłatnego', 'przekazania'): 7,
#              ('nie', 'dotyczy'): 492,
#              ('wydatków', 'związanych'): 48,
#              ('związanych', 'z'): 1201,
#              ('z', 'nabyciem'): 11,
#              ('towarów', 'oraz'): 31,
#              ('świadczonych', 'usług'): 26,
#              ('które', 'nie'): 350,
#              ('nie', 'zostały'): 242,
#              ('zostały', 'zaliczone'): 23,
#              ('zaliczone', 'do'): 65,
#              ('do', 'kosztów'): 141,
#              ('kosztów', 'uzyskania'): 120,
#              ('uzyskania', 'przychodów'): 211,
#              ('przychodów', 'z'): 118,
#              ('z', 'powodu'): 490,
#              ('norm', 'w'): 7,
#              ('podatku', 'dochodowym'): 354,
#              ('od', 'importu'): 6,
#              ('wkłady', 'niepieniężne'): 33,
#              ('do', 'spółek'): 55,
#              ('spółek', 'prawa'): 22,
#              ('prawa', 'handlowego'): 60,
#              ('oraz', 'wyrazy'): 92,
#              ('otrzymują', 'brzmienie'): 983,
#              ('przedmiotu', 'i'): 14,
#              ('i', 'podstawy'): 15,
#              ('podstawy', 'opodatkowania'): 127,
#              ('organ', 'podatkowy'): 232,
#              ('podatkowy', 'określa'): 11,
#              ('wartość', 'nie'): 25,
#              ('sprzedaży', 'w'): 37,
#              ('drodze', 'oszacowania'): 18,
#              ('oszacowania', 'i'): 6,
#              ('i', 'ustala'): 15,
#              ('przy', 'zastosowaniu'): 133,
#              ('zastosowaniu', 'stawki'): 5,
#              ('z', 'tym'): 837,
#              ('tym', 'że'): 569,
#              ('że', 'kwota'): 11,
#              ('ustalonego', 'w'): 39,
#              ('w', 'ten'): 71,
#              ('ten', 'sposób'): 65,
#              ('ulega', 'podwyższeniu'): 22,
#              ('podwyższeniu', 'o'): 11,
#              ('wysokość', 'podatku'): 16,
#              ('wyniku', 'czego'): 7,
#              ('kwotę', 'podatku'): 19,
#              ('się', 'o'): 783,
#              ('o', 'kwotę'): 190,
#              ('polskiego', 'komitetu'): 17,
#              ('miar', 'i'): 22,
#              ('i', 'jakości'): 60,
#              ('się', 'zdanie'): 229,
#              ('zdanie', 'drugie'): 343,
#              ('drugie', 'w'): 128,
#              ('dla', 'obliczenia'): 5,
#              ('przyjmuje', 'się'): 193,
#              ('się', 'wyłącznie'): 85,
#              ('wyłącznie', 'towary'): 7,
#              ('towary', 'przeznaczone'): 24,
#              ('przeznaczone', 'do'): 327,
#              ('do', 'dalszej'): 14,
#              ('według', 'cen'): 49,
#              ('lub', 'rachunek'): 8,
#              ('w', 'szczególności'): 3474,
#              ('a', 'po'): 86,
#              ('po', 'wyrazach'): 935,
#              ('przypadku', 'czynności'): 5,
#              ('czynności', 'wymienionych'): 22,
#              ('zdanie', 'pierwsze'): 120,
#              ('pierwsze', 'otrzymuje'): 71,
#              ('podlegają', 'również'): 32,
#              ('akcyzowych', 'wymienionych'): 5,
#              ('i', 'poz'): 108,
#              ('dopuszczalnych', 'ubytków'): 17,
#              ('ubytków', 'wyrobów'): 22,
#              ('dla', 'poszczególnych'): 149,
#              ('dyrektorzy', 'urzędów'): 26,
#              ('urzędów', 'kontroli'): 10,
#              ('kontroli', 'skarbowej'): 242,
#              ('uwzględnieniem', 'warunków'): 21,
#              ('warunków', 'technicznych'): 30,
#              ('opodatkowania', 'akcyzą'): 18,
#              ('akcyzą', 'jest'): 10,
#              ('jest', 'ich'): 25,
#              ('ich', 'wartość'): 51,
#              ('o', 'cło'): 8,
#              ('obliczone', 'według'): 6,
#              ('według', 'stawki'): 16,
#              ('stawki', 'podstawowej'): 6,
#              ('podstawowej', 'i'): 13,
#              ('także', 'w'): 380,
#              ('gdy', 'towary'): 8,
#              ('towary', 'te'): 32,
#              ('podstawie', 'odrębnych'): 506,
#              ('odrębnych', 'przepisów'): 600,
#              ('zostały', 'w'): 25,
#              ('w', 'całości'): 592,
#              ('całości', 'lub'): 362,
#              ('lub', 'w'): 1564,
#              ('w', 'części'): 811,
#              ('zostało', 'zawieszone'): 12,
#              ('stawkę', 'celną'): 6,
#              ('celna', 'nie'): 8,
#              ('nie', 'została'): 165,
#              ('została', 'określona'): 10,
#              ('się', 'stawkę'): 18,
#              ('finansów', 'może'): 56,
#              ('akcyzy', 'są'): 11,
#              ('są', 'osoby'): 30,
#              ('osoby', 'lub'): 65,
#              ('lub', 'jednostki'): 106,
#              ('jednostki', 'inne'): 7,
#              ('producent', 'lub'): 49,
#              ('lub', 'importer'): 33,
#              ('wartości', 'celnej'): 64,
#              ('powiększonej', 'o'): 18,
#              ('do', 'podstawy'): 23,
#              ('obiektów', 'pływających'): 5,
#              ('świadczone', 'na'): 5,
#              ('na', 'rzecz'): 1106,
#              ('rzecz', 'osób'): 46,
#              ('osób', 'zagranicznych'): 26,
#              ('zagranicznych', 'w'): 28,
#              ('przepisów', 'prawa'): 358,
#              ('prawa', 'dewizowego'): 24,
#              ('nie', 'będących'): 84,
#              ('będących', 'podatnikami'): 14,
#              ('podatnikami', 'podatku'): 32,
#              ('polegające', 'na'): 98,
#              ('lub', 'przetwarzaniu'): 6,
#              ('towarów', 'przywiezionych'): 10,
#              ('na', 'polski'): 268,
#              ('polski', 'obszar'): 325,
#              ('obszar', 'celny'): 342,
#              ('celny', 'na'): 12,
#              ('czas', 'oznaczony'): 223,
#              ('jeżeli', 'towary'): 28,
#              ('te', 'zostaną'): 7,
#              ('za', 'granicę'): 189,
#              ('z', 'warunkami'): 129,
#              ('warunkami', 'określonymi'): 59,
#              ('określonymi', 'w'): 269,
#              ('w', 'przepisach'): 1670,
#              ('lat', 'od'): 531,
#              ('dnia', 'ogłoszenia'): 963,
#              ('ogłoszenia', 'ustawy'): 41,
#              ('przekroczyła', 'w'): 5,
#              ('powinna', 'być'): 210,
#              ('kwota', 'podatku'): 24,
#              ('przypadająca', 'na'): 12,
#              ('na', 'poszczególne'): 80,
#              ('poszczególne', 'grupy'): 5,
#              ('wykazane', 'w'): 14,
#              ('w', 'tym'): 4228,
#              ('obowiązani', 'są'): 92,
#              ('poinformować', 'właściwy'): 5,
#              ('właściwy', 'urząd'): 29,
#              ('skarbowy', 'o'): 11,
#              ('o', 'łącznej'): 42,
#              ('łącznej', 'kwocie'): 22,
#              ('ustalonej', 'w'): 35,
#              ('przez', 'okres'): 720,
#              ('miesięcy', 'licząc'): 7,
#              ('licząc', 'od'): 277,
#              ('dnia', 'wejścia'): 965,
#              ('wejścia', 'ustawy'): 45,
#              ('ustawy', 'w'): 147,
#              ('w', 'życie'): 4280,
#              ('się', 'liczbą'): 17,
#              ('może', 'ustalić'): 55,
#              ('drodze', 'zarządzenia'): 376,
#              ('na', 'okres'): 688,
#              ('okres', 'do'): 120,
#              ('terminy', 'składania'): 23,
#              ('obliczania', 'i'): 45,
#              ('i', 'wpłat'): 16,
#              ('niż', 'określone'): 231,
#              ('określone', 'w'): 2137,
#              ('ustalić', 'inne'): 5,
#              ('inne', 'terminy'): 5,
#              ('terminy', 'zwrotu'): 10,
#              ('oraz', 'w'): 1396,
#              ('okres', 'nie'): 249,
#              ('których', 'stosuje'): 53,
#              ('oraz', 'przypadki'): 26,
#              ('gdy', 'sprzedaż'): 6,
#              ('sprzedaż', 'towarów'): 5,
#              ('towarów', 'do'): 28,
#              ('wolnych', 'obszarów'): 9,
#              ('obszarów', 'i'): 15,
#              ('składów', 'celnych'): 10,
#              ('celnych', 'jest'): 5,
#              ('na', 'równi'): 59,
#              ('równi', 'z'): 50,
#              ('oddanie', 'do'): 7,
#              ('do', 'użytku'): 159,
#              ('budownictwa', 'mieszkaniowego'): 36,
#              ('związane', 'są'): 9,
#              ('są', 'one'): 110,
#              ('one', 'z'): 11,
#              ('z', 'obiektami'): 17,
#              ('przypadku', 'wprowadzenia'): 11,
#              ('zobowiązuje', 'się'): 35,
#              ('się', 'ministra'): 72,
#              ('ministra', 'finansów'): 159,
#              ('statystycznego', 'do'): 9,
#              ('do', 'ogłoszenia'): 27,
#              ('do', 'ustawy'): 460,
#              ('w', 'pozycji'): 9,
#              ('z', 'wyłączeniem'): 792,
#              ('lokali', 'w'): 21,
#              ('w', 'budynkach'): 54,
#              ('budynkach', 'mieszkalnych'): 5,
#              ('mieszkalnych', 'na'): 12,
#              ('na', 'cele'): 536,
#              ('cele', 'inne'): 8,
#              ('reklamowych', 'i'): 6,
#              ('załączniki', 'nr'): 7,
#              ('brzmienie', 'określone'): 38,
#              ('w', 'załącznikach'): 48,
#              ('załącznikach', 'nr'): 39,
#              ('do', 'niniejszej'): 52,
#              ('niniejszej', 'ustawy'): 1446,
#              ('symbol', 'sww'): 9,
#              ('okresie', 'od'): 208,
#              ('wejścia', 'w'): 2374,
#              ('życie', 'ustawy'): 1233,
#              ('ustawy', 'do'): 63,
#              ('przepisu', 'art'): 266,
#              ('brzmieniu', 'nadanym'): 427,
#              ('nadanym', 'niniejszą'): 415,
#              ('niniejszą', 'ustawą'): 661,
#              ('do', 'wyrobów'): 31,
#              ('finansów', 'ogłosi'): 12,
#              ('ogłosi', 'w'): 93,
#              ('w', 'dzienniku'): 508,
#              ('dzienniku', 'ustaw'): 119,
#              ('ustaw', 'rzeczypospolitej'): 113,
#              ('rzeczypospolitej', 'polskiej'): 3401,
#              ('polskiej', 'jednolity'): 69,
#              ('jednolity', 'tekst'): 83,
#              ('tekst', 'ustawy'): 300,
#              ('uwzględnieniem', 'zmian'): 95,
#              ('zmian', 'wynikających'): 93,
#              ('wynikających', 'z'): 793,
#              ('z', 'przepisów'): 276,
#              ('przepisów', 'ogłoszonych'): 80,
#              ('ogłoszonych', 'przed'): 82,
#              ('dniem', 'wydania'): 104,
#              ('wydania', 'jednolitego'): 71,
#              ('jednolitego', 'tekstu'): 72,
#              ('ustawa', 'wchodzi'): 1185,
#              ('wchodzi', 'w'): 1464,
#              ('życie', 'z'): 836,
#              ('z', 'dniem'): 1830,
#              ('załączniki', 'do'): 39,
#              ('załącznik', 'nr'): 241,
#              ('w', 'y'): 7,
#              ('a', 'z'): 159,
#              ('z', 'towarów'): 12,
#              ('sprzedaż', 'lub'): 30,
#              ('lub', 'świadczenie'): 36,
#              ('jest', 'objęte'): 5,
#              ('podatku', 'w'): 46,
#              ('w', 'wysokości'): 1745,
#              ('nazwa', 'towaru'): 11,
#              ('lub', 'usługi'): 78,
#              ('grupy', 'towarów'): 11,
#              ('związane', 'z'): 943,
#              ('z', 'gospodarką'): 17,
#              ('i', 'wyroby'): 48,
#              ('dla', 'celów'): 195,
#              ('gospodarcze', 'i'): 11,
#              ('i', 'sprzęt'): 19,
#              ('urządzenia', 'i'): 122,
#              ('i', 'narzędzia'): 7,
#              ('narzędzia', 'rolnicze'): 5,
#              ('dla', 'gospodarki'): 17,
#              ('gospodarki', 'leśnej'): 12,
#              ('paszowych', 'oraz'): 5,
#              ('z', 'ochroną'): 83,
#              ('ochroną', 'zdrowia'): 8,
#              ('części', 'do'): 21,
#              ('do', 'tych'): 230,
#              ('dla', 'inwalidów'): 7,
#              ('oraz', 'inne'): 361,
#              ('uznane', 'za'): 31,
#              ('medyczne', 'i'): 8,
#              ('i', 'sanitarne'): 12,
#              ('sanitarne', 'oraz'): 9,
#              ('z', 'tworzyw'): 16,
#              ('tworzyw', 'sztucznych'): 21,
#              ('tych', 'wyrobów'): 64,
#              ('do', 'zapisywania'): 9,
#              ('przemysłu', 'spożywczego'): 8,
#              ('wyłączeniem', 'wyrobów'): 8,
#              ('wyrobów', 'przemysłu'): 8,
#              ('i', 'produktów'): 138,
#              ('wód', 'mineralnych'): 7,
#              ('mineralnych', 'i'): 17,
#              ('i', 'innych'): 947,
#              ('i', 'ich'): 727,
#              ('wyrobów', 'tytoniowych'): 68,
#              ('dla', 'dzieci'): 46,
#              ('dla', 'niemowląt'): 8,
#              ('dzieci', 'do'): 29,
#              ('z', 'dzianin'): 11,
#              ('z', 'drewna'): 19,
#              ('do', 'gry'): 6,
#              ('wszelkiego', 'rodzaju'): 39,
#              ('rodzaju', 'i'): 132,
#              ('o', 'długości'): 39,
#              ('długości', 'do'): 7,
#              ('higieniczne', 'i'): 5,
#              ('gospodarki', 'rolnej'): 20,
#              ('i', 'części'): 18,
#              ('rolniczych', 'oraz'): 16,
#              ('oraz', 'do'): 297,
#              ('ratownictwa', 'górniczego'): 17,
#              ('usług', 'objętych'): 5,
#              ('objętych', 'stawką'): 9,
#              ('w', 'wagonach'): 6,
#              ('z', 'utrzymaniem'): 28,
#              ('utrzymaniem', 'i'): 14,
#              ('oraz', 'obiektów'): 30,
#              ('z', 'budową'): 33,
#              ('dróg', 'i'): 19,
#              ('sprzedaży', 'napojów'): 13,
#              ('napojów', 'alkoholowych'): 94,
#              ('alkoholowych', 'o'): 9,
#              ('zawartości', 'alkoholu'): 17,
#              ('alkoholu', 'powyżej'): 9,
#              ('wraz', 'z'): 1425,
#              ('napojów', 'bezalkoholowych'): 12,
#              ('w', 'stanie'): 332,
#              ('stanie', 'nie'): 9,
#              ('innych', 'towarów'): 5,
#              ('usług', 'świadczonych'): 30,
#              ('świadczonych', 'w'): 7,
#              ('turystyki', 'i'): 22,
#              ('i', 'wypoczynku'): 11,
#              ('wyłączeniem', 'usług'): 5,
#              ('świadczonych', 'przez'): 30,
#              ('osoby', 'fizyczne'): 227,
#              ('fizyczne', 'nie'): 5,
#              ('z', 'materiałów'): 41,
#              ('materiałów', 'i'): 106,
#              ('sprzedaż', 'jest'): 5,
#              ('jest', 'objęta'): 11,
#              ('ropy', 'naftowej'): 37,
#              ('i', 'inne'): 426,
#              ('inne', 'wyroby'): 5,
#              ('hutnictwa', 'żelaza'): 21,
#              ('i', 'ze'): 11,
#              ('centralnego', 'ogrzewania'): 9,
#              ('ciepła', 'i'): 7,
#              ('z', 'blachy'): 7,
#              ('do', 'centralnego'): 12,
#              ('maszyn', 'i'): 40,
#              ('i', 'urządzeń'): 212,
#              ('silników', 'spalinowych'): 13,
#              ('urządzeń', 'do'): 34,
#              ('ciepła', 'oraz'): 8,
#              ('do', 'pomiaru'): 9,
#              ('rozdzielcze', 'i'): 6,
#              ('do', 'urządzeń'): 46,
#              ('w', 'instalacjach'): 19,
#              ('oraz', 'sprzęt'): 5,
#              ('do', 'linii'): 7,
#              ('i', 'materiały'): 89,
#              ('i', 'szeregowych'): 5,
#              ('i', 'roboty'): 9,
#              ('z', 'bieżącą'): 6,
#              ('i', 'infrastruktury'): 8,
#              ('roboty', 'budowlane'): 67,
#              ('w', 'obiektach'): 34,
#              ('oświaty', 'i'): 235,
#              ('i', 'wychowania'): 259,
#              ('kultury', 'i'): 273,
#              ('i', 'sztuki'): 120,
#              ('radia', 'i'): 5,
#              ('i', 'telewizji'): 98,
#              ('ochrony', 'zdrowia'): 127,
#              ('zdrowia', 'i'): 410,
#              ('i', 'opieki'): 348,
#              ('opieki', 'społecznej'): 344,
#              ('kultury', 'fizycznej'): 233,
#              ('użytku', 'publicznego'): 20,
#              ('mieszkalnych', 'i'): 61,
#              ('zmianie', 'niektórych'): 289,
#              ('niektórych', 'ustaw'): 217,
#              ('ustaw', 'dotyczących'): 6,
#              ('zaopatrzenia', 'emerytalnego'): 52,
#              ('o', 'zaopatrzeniu'): 174,
#              ('zaopatrzeniu', 'inwalidów'): 26,
#              ('inwalidów', 'wojennych'): 32,
#              ('wojennych', 'i'): 74,
#              ('i', 'wojskowych'): 52,
#              ('wojskowych', 'oraz'): 61,
#              ('oraz', 'ich'): 488,
#              ('ich', 'rodzin'): 284,
#              ('i', 'z'): 534,
#              ('podstawę', 'wymiaru'): 148,
#              ('wymiaru', 'renty'): 25,
#              ('renty', 'inwalidzkiej'): 76,
#              ('ustala', 'się'): 771,
#              ('od', 'kwoty'): 93,
#              ('kwoty', 'stanowiącej'): 53,
#              ('stanowiącej', 'podstawę'): 17,
#              ('waloryzacji', 'na'): 13,
#              ('zaopatrzeniu', 'emerytalnym'): 143,
#              ('emerytalnym', 'pracowników'): 66,
#              ('pracowników', 'i'): 103,
#              ('podstawy', 'wymiaru'): 205,
#              ('następuje', 'od'): 10,
#              ('od', 'miesiąca'): 80,
#              ('którym', 'jest'): 88,
#              ('jest', 'przeprowadzana'): 27,
#              ('przeprowadzana', 'waloryzacja'): 15,
#              ('ustalenie', 'wysokości'): 31,
#              ('wysokości', 'renty'): 6,
#              ('renty', 'następuje'): 7,
#              ('następuje', 'przez'): 34,
#              ('przez', 'pomnożenie'): 7,
#              ('w', 'myśl'): 109,
#              ('myśl', 'ust'): 15,
#              ('wymiaru', 'świadczenia'): 10,
#              ('karta', 'nauczyciela'): 55,
#              ('którzy', 'w'): 88,
#              ('w', 'czasie'): 844,
#              ('tajne', 'nauczanie'): 10,
#              ('przysługuje', 'dodatek'): 37,
#              ('dodatek', 'do'): 22,
#              ('do', 'emerytury'): 233,
#              ('emerytury', 'lub'): 189,
#              ('lub', 'renty'): 210,
#              ('renty', 'w'): 10,
#              ('przeciętnego', 'wynagrodzenia'): 169,
#              ('wynagrodzenia', 'w'): 168,
#              ('w', 'kwartale'): 43,
#              ('kwartale', 'kalendarzowym'): 31,
#              ('kalendarzowym', 'poprzedzającym'): 43,
#              ('poprzedzającym', 'termin'): 26,
#              ('termin', 'waloryzacji'): 19,
#              ('jeżeli', 'nie'): 630,
#              ('dodatku', 'z'): 15,
#              ('z', 'innego'): 52,
#              ('innego', 'tytułu'): 45,
#              ('zmiana', 'wysokości'): 12,
#              ('wysokości', 'dodatku'): 12,
#              ('o', 'kombatantach'): 41,
#              ('kombatantach', 'oraz'): 41,
#              ('oraz', 'niektórych'): 182,
#              ('niektórych', 'osobach'): 41,
#              ('osobach', 'będących'): 42,
#              ('będących', 'ofiarami'): 42,
#              ('ofiarami', 'represji'): 42,
#              ('represji', 'wojennych'): 42,
#              ('i', 'okresu'): 56,
#              ('okresu', 'powojennego'): 47,
#              ('kombatantom', 'i'): 6,
#              ('i', 'innym'): 51,
#              ('innym', 'osobom'): 60,
#              ('osobom', 'uprawnionym'): 50,
#              ...})

# %%
pmi_filtered = defaultdict(float)

for bigram, value in bigrams_filtered.items():
    pmi_filtered[bigram] = np.log2( (value/number_of_bigrams) / ((words_global_counter[bigram[0]]/number_of_words) * (words_global_counter[bigram[1]]/number_of_words) ))
pmi_filtered_sorted = sorted(pmi_filtered.items(), key=lambda x:x[1], reverse = True)

# %%
pmi_filtered_sorted[:10]
# Out:
# [(('świeckie', 'przygotowujące'), 19.817294239521193),
#  (('klęskami', 'żywiołowymi'), 19.817294239521193),
#  (('ręcznego', 'miotacza'), 19.817294239521193),
#  (('stajnią', 'wyścigową'), 19.817294239521193),
#  (('otworami', 'wiertniczymi'), 19.817294239521193),
#  (('teryto', 'rialnego'), 19.817294239521193),
#  (('obcowania', 'płciowego'), 19.817294239521193),
#  (('nietykalność', 'cielesną'), 19.817294239521193),
#  (('młyny', 'kulowe'), 19.817294239521193),
#  (('młynki', 'młotkowe'), 19.817294239521193)]

# %% [markdown]
# ### Use KRNNT or Clarin-PL API(https://ws.clarin-pl.eu/tager.shtml) to tag and lemmatize the corpus.

# %%
import xmltodict

CLARIN_PATH = 'clarin'
def load_clarin_bills(directory):
    clarin_tokens = {}
    for file_name in os.listdir(directory):
        print(file_name)
        name = re.search(r'(\d+.*).txt', file_name).group(1)
        path = os.path.join(directory, file_name)
        if os.path.isfile(path):
            tokens_per_file = []
            with open(path, mode='r', encoding = 'utf-8') as f:
                bill_clarin = xmltodict.parse(f.read())
                for sentence in bill_clarin['chunkList']['chunk']:
                    for token in sentence['sentence']['tok']:
                        try:
                            if isinstance(token['lex'], list):
                                tokens_per_file.append(f"{token['lex'][0]['base'].lower()}:{token['lex'][0]['ctag'].split(':')[0].lower()}")
                            else:
                                tokens_per_file.append(f"{token['lex']['base'].lower()}:{token['lex']['ctag'].split(':')[0].lower()}")
                        except TypeError:
                            pass
                clarin_tokens[name] = tokens_per_file
    return clarin_tokens

# %%
clarin_data = load_clarin_bills(CLARIN_PATH)
# Out:
# ustawy%1993_599.txt
# ustawy%1993_602.txt
# ustawy%1993_645.txt
# ustawy%1993_646.txt
# ustawy%1994_150.txt
# ustawy%1994_195.txt
# ustawy%1994_201.txt
# ustawy%1994_214.txt
# ustawy%1994_215.txt
# ustawy%1994_288.txt
# ustawy%1994_294.txt
# ustawy%1994_331.txt
# ustawy%1994_332.txt
# ustawy%1994_344.txt
# ustawy%1994_362.txt
# ustawy%1994_363.txt
# ustawy%1994_368.txt
# ustawy%1994_369.txt
# ustawy%1994_37.txt
# ustawy%1994_384.txt
# ustawy%1994_385.txt
# ustawy%1994_395.txt
# ustawy%1994_396.txt
# ustawy%1994_419.txt
# ustawy%1994_472.txt
# ustawy%1994_473.txt
# ustawy%1994_516.txt
# ustawy%1994_536.txt
# ustawy%1994_591.txt
# ustawy%1994_592.txt
# ustawy%1994_600.txt
# ustawy%1994_601.txt
# ustawy%1994_602.txt
# ustawy%1994_615.txt
# ustawy%1994_627.txt
# ustawy%1994_645.txt
# ustawy%1994_669.txt
# ustawy%1994_670.txt
# ustawy%1994_704.txt
# ustawy%1994_97.txt
# ustawy%1995_1.txt
# ustawy%1995_121.txt
# ustawy%1995_141.txt
# ustawy%1995_143.txt
# ustawy%1995_152.txt
# ustawy%1995_164.txt
# ustawy%1995_184.txt
# ustawy%1995_2.txt
# ustawy%1995_208.txt
# ustawy%1995_221.txt
# ustawy%1995_242.txt
# ustawy%1995_261.txt
# ustawy%1995_29.txt
# ustawy%1995_31.txt
# ustawy%1995_310.txt
# ustawy%1995_334.txt
# ustawy%1995_335.txt
# ustawy%1995_368.txt
# ustawy%1995_390.txt
# ustawy%1995_4.txt
# ustawy%1995_406.txt
# ustawy%1995_417.txt
# ustawy%1995_419.txt
# ustawy%1995_420.txt
# ustawy%1995_426.txt
# ustawy%1995_427.txt
# ustawy%1995_428.txt
# ustawy%1995_434.txt
# ustawy%1995_435.txt
# ustawy%1995_436.txt
# ustawy%1995_439.txt
# ustawy%1995_444.txt
# ustawy%1995_446.txt
# ustawy%1995_471.txt
# ustawy%1995_472.txt
# ustawy%1995_473.txt
# ustawy%1995_479.txt
# ustawy%1995_480.txt
# ustawy%1995_481.txt
# ustawy%1995_482.txt
# ustawy%1995_485.txt
# ustawy%1995_486.txt
# ustawy%1995_488.txt
# ustawy%1995_5.txt
# ustawy%1995_504.txt
# ustawy%1995_515.txt
# ustawy%1995_565.txt
# ustawy%1995_576.txt
# ustawy%1995_577.txt
# ustawy%1995_59.txt
# ustawy%1995_60.txt
# ustawy%1995_617.txt
# ustawy%1995_618.txt
# ustawy%1995_629.txt
# ustawy%1995_640.txt
# ustawy%1995_641.txt
# ustawy%1995_654.txt
# ustawy%1995_681.txt
# ustawy%1995_683.txt
# ustawy%1995_684.txt
# ustawy%1995_692.txt
# ustawy%1995_701.txt
# ustawy%1995_702.txt
# ustawy%1995_703.txt
# ustawy%1995_704.txt
# ustawy%1995_713.txt
# ustawy%1995_724.txt
# ustawy%1995_729.txt
# ustawy%1995_730.txt
# ustawy%1995_731.txt
# ustawy%1995_79.txt
# ustawy%1995_791.txt
# ustawy%1995_792.txt
# ustawy%1995_793.txt
# ustawy%1995_794.txt
# ustawy%1996_1.txt
# ustawy%1996_102.txt
# ustawy%1996_110.txt
# ustawy%1996_113.txt
# ustawy%1996_118.txt
# ustawy%1996_128.txt
# ustawy%1996_140.txt
# ustawy%1996_145.txt
# ustawy%1996_146.txt
# ustawy%1996_147.txt
# ustawy%1996_148.txt
# ustawy%1996_159.txt
# ustawy%1996_175.txt
# ustawy%1996_176.txt
# ustawy%1996_177.txt
# ustawy%1996_189.txt
# ustawy%1996_190.txt
# ustawy%1996_198.txt
# ustawy%1996_199.txt
# ustawy%1996_2.txt
# ustawy%1996_261.txt
# ustawy%1996_262.txt
# ustawy%1996_267.txt
# ustawy%1996_268.txt
# ustawy%1996_269.txt
# ustawy%1996_283.txt
# ustawy%1996_3.txt
# ustawy%1996_32.txt
# ustawy%1996_33.txt
# ustawy%1996_34.txt
# ustawy%1996_347.txt
# ustawy%1996_350.txt
# ustawy%1996_352.txt
# ustawy%1996_355.txt
# ustawy%1996_356.txt
# ustawy%1996_357.txt
# ustawy%1996_367.txt
# ustawy%1996_395.txt
# ustawy%1996_396.txt
# ustawy%1996_40.txt
# ustawy%1996_401.txt
# ustawy%1996_402.txt
# ustawy%1996_404.txt
# ustawy%1996_405.txt
# ustawy%1996_406.txt
# ustawy%1996_407.txt
# ustawy%1996_409.txt
# ustawy%1996_41.txt
# ustawy%1996_410.txt
# ustawy%1996_42.txt
# ustawy%1996_43.txt
# ustawy%1996_44.txt
# ustawy%1996_459.txt
# ustawy%1996_460.txt
# ustawy%1996_461.txt
# ustawy%1996_462.txt
# ustawy%1996_463.txt
# ustawy%1996_464.txt
# ustawy%1996_465.txt
# ustawy%1996_474.txt
# ustawy%1996_475.txt
# ustawy%1996_488.txt
# ustawy%1996_489.txt
# ustawy%1996_490.txt
# ustawy%1996_491.txt
# ustawy%1996_492.txt
# ustawy%1996_493.txt
# ustawy%1996_494.txt
# ustawy%1996_495.txt
# ustawy%1996_496.txt
# ustawy%1996_497.txt
# ustawy%1996_498.txt
# ustawy%1996_499.txt
# ustawy%1996_542.txt
# ustawy%1996_56.txt
# ustawy%1996_561.txt
# ustawy%1996_583.txt
# ustawy%1996_584.txt
# ustawy%1996_585.txt
# ustawy%1996_593.txt
# ustawy%1996_602.txt
# ustawy%1996_603.txt
# ustawy%1996_615.txt
# ustawy%1996_621.txt
# ustawy%1996_622.txt
# ustawy%1996_636.txt
# ustawy%1996_638.txt
# ustawy%1996_639.txt
# ustawy%1996_640.txt
# ustawy%1996_646.txt
# ustawy%1996_647.txt
# ustawy%1996_678.txt
# ustawy%1996_679.txt
# ustawy%1996_680.txt
# ustawy%1996_686.txt
# ustawy%1996_687.txt
# ustawy%1996_703.txt
# ustawy%1996_704.txt
# ustawy%1996_719.txt
# ustawy%1996_720.txt
# ustawy%1996_721.txt
# ustawy%1996_722.txt
# ustawy%1996_723.txt
# ustawy%1996_757.txt
# ustawy%1996_773.txt
# ustawy%1996_774.txt
# ustawy%1996_775.txt
# ustawy%1996_776.txt
# ustawy%1996_777.txt
# ustawy%1996_87.txt
# ustawy%1997_106.txt
# ustawy%1997_117.txt
# ustawy%1997_118.txt
# ustawy%1997_119.txt
# ustawy%1997_152.txt
# ustawy%1997_153.txt
# ustawy%1997_154.txt
# ustawy%1997_163.txt
# ustawy%1997_164.txt
# ustawy%1997_165.txt
# ustawy%1997_183.txt
# ustawy%1997_184.txt
# ustawy%1997_24.txt
# ustawy%1997_251.txt
# ustawy%1997_252.txt
# ustawy%1997_253.txt
# ustawy%1997_254.txt
# ustawy%1997_255.txt
# ustawy%1997_270.txt
# ustawy%1997_271.txt
# ustawy%1997_272.txt
# ustawy%1997_297.txt
# ustawy%1997_298.txt
# ustawy%1997_299.txt
# ustawy%1997_30.txt
# ustawy%1997_31.txt
# ustawy%1997_32.txt
# ustawy%1997_348.txt
# ustawy%1997_349.txt
# ustawy%1997_370.txt
# ustawy%1997_405.txt
# ustawy%1997_406.txt
# ustawy%1997_407.txt
# ustawy%1997_435.txt
# ustawy%1997_44.txt
# ustawy%1997_449.txt
# ustawy%1997_467.txt
# ustawy%1997_468.txt
# ustawy%1997_469.txt
# ustawy%1997_470.txt
# ustawy%1997_471.txt
# ustawy%1997_484.txt
# ustawy%1997_485.txt
# ustawy%1997_491.txt
# ustawy%1997_492.txt
# ustawy%1997_493.txt
# ustawy%1997_494.txt
# ustawy%1997_495.txt
# ustawy%1997_496.txt
# ustawy%1997_497.txt
# ustawy%1997_498.txt
# ustawy%1997_499.txt
# ustawy%1997_500.txt
# ustawy%1997_501.txt
# ustawy%1997_502.txt
# ustawy%1997_503.txt
# ustawy%1997_504.txt
# ustawy%1997_505.txt
# ustawy%1997_506.txt
# ustawy%1997_507.txt
# ustawy%1997_508.txt
# ustawy%1997_509.txt
# ustawy%1997_510.txt
# ustawy%1997_511.txt
# ustawy%1997_512.txt
# ustawy%1997_518.txt
# ustawy%1997_538.txt
# ustawy%1997_539.txt
# ustawy%1997_553.txt
# ustawy%1997_554.txt
# ustawy%1997_555.txt
# ustawy%1997_556.txt
# ustawy%1997_557.txt
# ustawy%1997_569.txt
# ustawy%1997_589.txt
# ustawy%1997_590.txt
# ustawy%1997_591.txt
# ustawy%1997_592.txt
# ustawy%1997_593.txt
# ustawy%1997_602.txt
# ustawy%1997_603.txt
# ustawy%1997_604.txt
# ustawy%1997_628.txt
# ustawy%1997_629.txt
# ustawy%1997_630.txt
# ustawy%1997_642.txt
# ustawy%1997_643.txt
# ustawy%1997_650.txt
# ustawy%1997_651.txt
# ustawy%1997_652.txt
# ustawy%1997_661.txt
# ustawy%1997_673.txt
# ustawy%1997_674.txt
# ustawy%1997_675.txt
# ustawy%1997_676.txt
# ustawy%1997_677.txt
# ustawy%1997_678.txt
# ustawy%1997_679.txt
# ustawy%1997_680.txt
# ustawy%1997_681.txt
# ustawy%1997_682.txt
# ustawy%1997_684.txt
# ustawy%1997_685.txt
# ustawy%1997_686.txt
# ustawy%1997_688.txt
# ustawy%1997_689.txt
# ustawy%1997_690.txt
# ustawy%1997_691.txt
# ustawy%1997_692.txt
# ustawy%1997_714.txt
# ustawy%1997_715.txt
# ustawy%1997_72.txt
# ustawy%1997_722.txt
# ustawy%1997_723.txt
# ustawy%1997_724.txt
# ustawy%1997_726.txt
# ustawy%1997_731.txt
# ustawy%1997_732.txt
# ustawy%1997_733.txt
# ustawy%1997_734.txt
# ustawy%1997_735.txt
# ustawy%1997_736.txt
# ustawy%1997_738.txt
# ustawy%1997_739.txt
# ustawy%1997_740.txt
# ustawy%1997_741.txt
# ustawy%1997_751.txt
# ustawy%1997_752.txt
# ustawy%1997_753.txt
# ustawy%1997_754.txt
# ustawy%1997_769.txt
# ustawy%1997_770.txt
# ustawy%1997_774.txt
# ustawy%1997_775.txt
# ustawy%1997_776.txt
# ustawy%1997_777.txt
# ustawy%1997_778.txt
# ustawy%1997_779.txt
# ustawy%1997_780.txt
# ustawy%1997_781.txt
# ustawy%1997_782.txt
# ustawy%1997_783.txt
# ustawy%1997_805.txt
# ustawy%1997_83.txt
# ustawy%1997_84.txt
# ustawy%1997_882.txt
# ustawy%1997_883.txt
# ustawy%1997_884.txt
# ustawy%1997_885.txt
# ustawy%1997_926.txt
# ustawy%1997_932.txt
# ustawy%1997_933.txt
# ustawy%1997_934.txt
# ustawy%1997_938.txt
# ustawy%1997_939.txt
# ustawy%1997_940.txt
# ustawy%1997_942.txt
# ustawy%1997_943.txt
# ustawy%1997_944.txt
# ustawy%1997_945.txt
# ustawy%1997_96.txt
# ustawy%1997_97.txt
# ustawy%1998_1015.txt
# ustawy%1998_1019.txt
# ustawy%1998_1062.txt
# ustawy%1998_1063.txt
# ustawy%1998_1065.txt
# ustawy%1998_1076.txt
# ustawy%1998_1114.txt
# ustawy%1998_1115.txt
# ustawy%1998_1116.txt
# ustawy%1998_1118.txt
# ustawy%1998_1120.txt
# ustawy%1998_1122.txt
# ustawy%1998_1123.txt
# ustawy%1998_1125.txt
# ustawy%1998_204.txt
# ustawy%1998_375.txt
# ustawy%1998_471.txt
# ustawy%1998_472.txt
# ustawy%1998_576.txt
# ustawy%1998_577.txt
# ustawy%1998_593.txt
# ustawy%1998_594.txt
# ustawy%1998_602.txt
# ustawy%1998_604.txt
# ustawy%1998_610.txt
# ustawy%1998_632.txt
# ustawy%1998_669.txt
# ustawy%1998_681.txt
# ustawy%1998_683.txt
# ustawy%1998_716.txt
# ustawy%1998_717.txt
# ustawy%1998_759.txt
# ustawy%1998_931.txt
# ustawy%1998_937.txt
# ustawy%1998_938.txt
# ustawy%1999_1000.txt
# ustawy%1999_1001.txt
# ustawy%1999_1063.txt
# ustawy%1999_1065.txt
# ustawy%1999_1100.txt
# ustawy%1999_1101.txt
# ustawy%1999_1107.txt
# ustawy%1999_1151.txt
# ustawy%1999_1177.txt
# ustawy%1999_1227.txt
# ustawy%1999_1231.txt
# ustawy%1999_1232.txt
# ustawy%1999_1233.txt
# ustawy%1999_1234.txt
# ustawy%1999_1235.txt
# ustawy%1999_1236.txt
# ustawy%1999_1255.txt
# ustawy%1999_1256.txt
# ustawy%1999_1279.txt
# ustawy%1999_1280.txt
# ustawy%1999_1281.txt
# ustawy%1999_135.txt
# ustawy%1999_136.txt
# ustawy%1999_154.txt
# ustawy%1999_170.txt
# ustawy%1999_303.txt
# ustawy%1999_304.txt
# ustawy%1999_305.txt
# ustawy%1999_309.txt
# ustawy%1999_310.txt
# ustawy%1999_32.txt
# ustawy%1999_400.txt
# ustawy%1999_439.txt
# ustawy%1999_440.txt
# ustawy%1999_461.txt
# ustawy%1999_483.txt
# ustawy%1999_484.txt
# ustawy%1999_485.txt
# ustawy%1999_486.txt
# ustawy%1999_527.txt
# ustawy%1999_528.txt
# ustawy%1999_530.txt
# ustawy%1999_532.txt
# ustawy%1999_548.txt
# ustawy%1999_596.txt
# ustawy%1999_683.txt
# ustawy%1999_685.txt
# ustawy%1999_686.txt
# ustawy%1999_688.txt
# ustawy%1999_700.txt
# ustawy%1999_702.txt
# ustawy%1999_728.txt
# ustawy%1999_729.txt
# ustawy%1999_75.txt
# ustawy%1999_762.txt
# ustawy%1999_774.txt
# ustawy%1999_776.txt
# ustawy%1999_777.txt
# ustawy%1999_778.txt
# ustawy%1999_801.txt
# ustawy%1999_802.txt
# ustawy%1999_803.txt
# ustawy%1999_804.txt
# ustawy%1999_875.txt
# ustawy%1999_884.txt
# ustawy%1999_885.txt
# ustawy%1999_903.txt
# ustawy%1999_930.txt
# ustawy%1999_932.txt
# ustawy%1999_934.txt
# ustawy%1999_935.txt
# ustawy%1999_936.txt
# ustawy%1999_95.txt
# ustawy%1999_96.txt
# ustawy%1999_980.txt
# ustawy%1999_998.txt
# ustawy%2000_1008.txt
# ustawy%2000_1009.txt
# ustawy%2000_1010.txt
# ustawy%2000_1026.txt
# ustawy%2000_1027.txt
# ustawy%2000_1028.txt
# ustawy%2000_1040.txt
# ustawy%2000_1072.txt
# ustawy%2000_1098.txt
# ustawy%2000_1099.txt
# ustawy%2000_1100.txt
# ustawy%2000_1103.txt
# ustawy%2000_1104.txt
# ustawy%2000_1107.txt
# ustawy%2000_1118.txt
# ustawy%2000_1127.txt
# ustawy%2000_1156.txt
# ustawy%2000_116.txt
# ustawy%2000_1166.txt
# ustawy%2000_1167.txt
# ustawy%2000_117.txt
# ustawy%2000_118.txt
# ustawy%2000_1186.txt
# ustawy%2000_1188.txt
# ustawy%2000_1189.txt
# ustawy%2000_1190.txt
# ustawy%2000_1191.txt
# ustawy%2000_1192.txt
# ustawy%2000_1216.txt
# ustawy%2000_1249.txt
# ustawy%2000_1250.txt
# ustawy%2000_1251.txt
# ustawy%2000_1268.txt
# ustawy%2000_1310.txt
# ustawy%2000_1311.txt
# ustawy%2000_1312.txt
# ustawy%2000_1314.txt
# ustawy%2000_1315.txt
# ustawy%2000_1316.txt
# ustawy%2000_1318.txt
# ustawy%2000_1319.txt
# ustawy%2000_1320.txt
# ustawy%2000_1321.txt
# ustawy%2000_1322.txt
# ustawy%2000_1323.txt
# ustawy%2000_1324.txt
# ustawy%2000_136.txt
# ustawy%2000_177.txt
# ustawy%2000_178.txt
# ustawy%2000_179.txt
# ustawy%2000_180.txt
# ustawy%2000_230.txt
# ustawy%2000_238.txt
# ustawy%2000_239.txt
# ustawy%2000_269.txt
# ustawy%2000_273.txt
# ustawy%2000_28.txt
# ustawy%2000_354.txt
# ustawy%2000_357.txt
# ustawy%2000_358.txt
# ustawy%2000_381.txt
# ustawy%2000_382.txt
# ustawy%2000_383.txt
# ustawy%2000_439.txt
# ustawy%2000_440.txt
# ustawy%2000_443.txt
# ustawy%2000_484.txt
# ustawy%2000_485.txt
# ustawy%2000_486.txt
# ustawy%2000_488.txt
# ustawy%2000_489.txt
# ustawy%2000_5.txt
# ustawy%2000_545.txt
# ustawy%2000_546.txt
# ustawy%2000_547.txt
# ustawy%2000_548.txt
# ustawy%2000_549.txt
# ustawy%2000_551.txt
# ustawy%2000_553.txt
# ustawy%2000_555.txt
# ustawy%2000_579.txt
# ustawy%2000_580.txt
# ustawy%2000_581.txt
# ustawy%2000_6.txt
# ustawy%2000_633.txt
# ustawy%2000_634.txt
# ustawy%2000_635.txt
# ustawy%2000_636.txt
# ustawy%2000_637.txt
# ustawy%2000_638.txt
# ustawy%2000_693.txt
# ustawy%2000_695.txt
# ustawy%2000_696.txt
# ustawy%2000_697.txt
# ustawy%2000_698.txt
# ustawy%2000_699.txt
# ustawy%2000_700.txt
# ustawy%2000_701.txt
# ustawy%2000_702.txt
# ustawy%2000_703.txt
# ustawy%2000_704.txt
# ustawy%2000_787.txt
# ustawy%2000_805.txt
# ustawy%2000_817.txt
# ustawy%2000_818.txt
# ustawy%2000_819.txt
# ustawy%2000_820.txt
# ustawy%2000_839.txt
# ustawy%2000_85.txt
# ustawy%2000_856.txt
# ustawy%2000_857.txt
# ustawy%2000_867.txt
# ustawy%2000_958.txt
# ustawy%2000_959.txt
# ustawy%2000_985.txt
# ustawy%2000_986.txt
# ustawy%2000_991.txt
# ustawy%2000_992.txt
# ustawy%2001_1032.txt
# ustawy%2001_1050.txt
# ustawy%2001_1051.txt
# ustawy%2001_1065.txt
# ustawy%2001_1066.txt
# ustawy%2001_1067.txt
# ustawy%2001_1068.txt
# ustawy%2001_1069.txt
# ustawy%2001_1070.txt
# ustawy%2001_1071.txt
# ustawy%2001_1073.txt
# ustawy%2001_1074.txt
# ustawy%2001_1075.txt
# ustawy%2001_1080.txt
# ustawy%2001_1081.txt
# ustawy%2001_1082.txt
# ustawy%2001_1083.txt
# ustawy%2001_1084.txt
# ustawy%2001_1086.txt
# ustawy%2001_1087.txt
# ustawy%2001_1088.txt
# ustawy%2001_1089.txt
# ustawy%2001_1115.txt
# ustawy%2001_1116.txt
# ustawy%2001_1117.txt
# ustawy%2001_1118.txt
# ustawy%2001_1149.txt
# ustawy%2001_1150.txt
# ustawy%2001_1188.txt
# ustawy%2001_1189.txt
# ustawy%2001_1190.txt
# ustawy%2001_1193.txt
# ustawy%2001_1194.txt
# ustawy%2001_1195.txt
# ustawy%2001_1196.txt
# ustawy%2001_1197.txt
# ustawy%2001_1198.txt
# ustawy%2001_1207.txt
# ustawy%2001_1208.txt
# ustawy%2001_1209.txt
# ustawy%2001_1229.txt
# ustawy%2001_124.txt
# ustawy%2001_1319.txt
# ustawy%2001_1320.txt
# ustawy%2001_1321.txt
# ustawy%2001_1322.txt
# ustawy%2001_1323.txt
# ustawy%2001_1324.txt
# ustawy%2001_1325.txt
# ustawy%2001_1351.txt
# ustawy%2001_1352.txt
# ustawy%2001_1353.txt
# ustawy%2001_1354.txt
# ustawy%2001_1363.txt
# ustawy%2001_1364.txt
# ustawy%2001_1365.txt
# ustawy%2001_1366.txt
# ustawy%2001_1367.txt
# ustawy%2001_1368.txt
# ustawy%2001_1369.txt
# ustawy%2001_1370.txt
# ustawy%2001_1371.txt
# ustawy%2001_1378.txt
# ustawy%2001_1379.txt
# ustawy%2001_1380.txt
# ustawy%2001_1381.txt
# ustawy%2001_1382.txt
# ustawy%2001_1383.txt
# ustawy%2001_1384.txt
# ustawy%2001_1401.txt
# ustawy%2001_1402.txt
# ustawy%2001_1403.txt
# ustawy%2001_1404.txt
# ustawy%2001_1405.txt
# ustawy%2001_1406.txt
# ustawy%2001_1407.txt
# ustawy%2001_1408.txt
# ustawy%2001_1409.txt
# ustawy%2001_1438.txt
# ustawy%2001_1439.txt
# ustawy%2001_1440.txt
# ustawy%2001_1441.txt
# ustawy%2001_1442.txt
# ustawy%2001_1443.txt
# ustawy%2001_1444.txt
# ustawy%2001_1445.txt
# ustawy%2001_1446.txt
# ustawy%2001_1450.txt
# ustawy%2001_1451.txt
# ustawy%2001_1452.txt
# ustawy%2001_148.txt
# ustawy%2001_1545.txt
# ustawy%2001_1546.txt
# ustawy%2001_1643.txt
# ustawy%2001_1645.txt
# ustawy%2001_166.txt
# ustawy%2001_167.txt
# ustawy%2001_169.txt
# ustawy%2001_18.txt
# ustawy%2001_19.txt
# ustawy%2001_20.txt
# ustawy%2001_21.txt
# ustawy%2001_23.txt
# ustawy%2001_24.txt
# ustawy%2001_246.txt
# ustawy%2001_247.txt
# ustawy%2001_249.txt
# ustawy%2001_25.txt
# ustawy%2001_26.txt
# ustawy%2001_298.txt
# ustawy%2001_301.txt
# ustawy%2001_320.txt
# ustawy%2001_41.txt
# ustawy%2001_423.txt
# ustawy%2001_424.txt
# ustawy%2001_43.txt
# ustawy%2001_44.txt
# ustawy%2001_45.txt
# ustawy%2001_452.txt
# ustawy%2001_459.txt
# ustawy%2001_465.txt
# ustawy%2001_469.txt
# ustawy%2001_470.txt
# ustawy%2001_471.txt
# ustawy%2001_472.txt
# ustawy%2001_474.txt
# ustawy%2001_475.txt
# ustawy%2001_476.txt
# ustawy%2001_498.txt
# ustawy%2001_499.txt
# ustawy%2001_509.txt
# ustawy%2001_537.txt
# ustawy%2001_538.txt
# ustawy%2001_539.txt
# ustawy%2001_579.txt
# ustawy%2001_580.txt
# ustawy%2001_610.txt
# ustawy%2001_627.txt
# ustawy%2001_628.txt
# ustawy%2001_634.txt
# ustawy%2001_635.txt
# ustawy%2001_636.txt
# ustawy%2001_638.txt
# ustawy%2001_639.txt
# ustawy%2001_64.txt
# ustawy%2001_640.txt
# ustawy%2001_641.txt
# ustawy%2001_677.txt
# ustawy%2001_678.txt
# ustawy%2001_679.txt
# ustawy%2001_726.txt
# ustawy%2001_733.txt
# ustawy%2001_734.txt
# ustawy%2001_744.txt
# ustawy%2001_745.txt
# ustawy%2001_746.txt
# ustawy%2001_749.txt
# ustawy%2001_760.txt
# ustawy%2001_761.txt
# ustawy%2001_762.txt
# ustawy%2001_763.txt
# ustawy%2001_764.txt
# ustawy%2001_784.txt
# ustawy%2001_785.txt
# ustawy%2001_786.txt
# ustawy%2001_803.txt
# ustawy%2001_804.txt
# ustawy%2001_805.txt
# ustawy%2001_806.txt
# ustawy%2001_807.txt
# ustawy%2001_808.txt
# ustawy%2001_811.txt
# ustawy%2001_812.txt
# ustawy%2001_82.txt
# ustawy%2001_83.txt
# ustawy%2001_84.txt
# ustawy%2001_85.txt
# ustawy%2001_858.txt
# ustawy%2001_873.txt
# ustawy%2001_874.txt
# ustawy%2001_875.txt
# ustawy%2001_876.txt
# ustawy%2001_906.txt
# ustawy%2001_907.txt
# ustawy%2001_908.txt
# ustawy%2001_92.txt
# ustawy%2001_924.txt
# ustawy%2001_925.txt
# ustawy%2001_926.txt
# ustawy%2001_969.txt
# ustawy%2001_970.txt
# ustawy%2001_971.txt
# ustawy%2001_972.txt
# ustawy%2001_973.txt
# ustawy%2001_974.txt
# ustawy%2001_993.txt
# ustawy%2001_994.txt
# ustawy%2001_995.txt
# ustawy%2002_1067.txt
# ustawy%2002_1070.txt
# ustawy%2002_1083.txt
# ustawy%2002_1086.txt
# ustawy%2002_1089.txt
# ustawy%2002_110.txt
# ustawy%2002_1142.txt
# ustawy%2002_1182.txt
# ustawy%2002_1204.txt
# ustawy%2002_1267.txt
# ustawy%2002_1523.txt
# ustawy%2002_1526.txt
# ustawy%2002_1569.txt
# ustawy%2002_1662.txt
# ustawy%2002_1681.txt
# ustawy%2002_1685.txt
# ustawy%2002_1689.txt
# ustawy%2002_1731.txt
# ustawy%2002_1763.txt
# ustawy%2002_1800.txt
# ustawy%2002_1801.txt
# ustawy%2002_1802.txt
# ustawy%2002_1803.txt
# ustawy%2002_1920.txt
# ustawy%2002_1923.txt
# ustawy%2002_1937.txt
# ustawy%2002_1954.txt
# ustawy%2002_731.txt
# ustawy%2002_90.txt
# ustawy%2002_945.txt
# ustawy%2002_976.txt
# ustawy%2003_1029.txt
# ustawy%2003_1031.txt
# ustawy%2003_1039.txt
# ustawy%2003_1061.txt
# ustawy%2003_1065.txt
# ustawy%2003_1067.txt
# ustawy%2003_1068.txt
# ustawy%2003_1069.txt
# ustawy%2003_1122.txt
# ustawy%2003_1123.txt
# ustawy%2003_1176.txt
# ustawy%2003_1186.txt
# ustawy%2003_1189.txt
# ustawy%2003_1268.txt
# ustawy%2003_1300.txt
# ustawy%2003_1302.txt
# ustawy%2003_1303.txt
# ustawy%2003_1304.txt
# ustawy%2003_1324.txt
# ustawy%2003_1325.txt
# ustawy%2003_1450.txt
# ustawy%2003_1452.txt
# ustawy%2003_1453.txt
# ustawy%2003_1454.txt
# ustawy%2003_1507.txt
# ustawy%2003_1509.txt
# ustawy%2003_151.txt
# ustawy%2003_1510.txt
# ustawy%2003_1511.txt
# ustawy%2003_1512.txt
# ustawy%2003_1513.txt
# ustawy%2003_153.txt
# ustawy%2003_155.txt
# ustawy%2003_1569.txt
# ustawy%2003_1590.txt
# ustawy%2003_1591.txt
# ustawy%2003_1592.txt
# ustawy%2003_1610.txt
# ustawy%2003_1611.txt
# ustawy%2003_1612.txt
# ustawy%2003_1652.txt
# ustawy%2003_1661.txt
# ustawy%2003_1664.txt
# ustawy%2003_1692.txt
# ustawy%2003_1693.txt
# ustawy%2003_1697.txt
# ustawy%2003_1725.txt
# ustawy%2003_1750.txt
# ustawy%2003_1759.txt
# ustawy%2003_1786.txt
# ustawy%2003_1787.txt
# ustawy%2003_1834.txt
# ustawy%2003_1836.txt
# ustawy%2003_1837.txt
# ustawy%2003_1838.txt
# ustawy%2003_1839.txt
# ustawy%2003_1840.txt
# ustawy%2003_1849.txt
# ustawy%2003_1850.txt
# ustawy%2003_1851.txt
# ustawy%2003_1852.txt
# ustawy%2003_1853.txt
# ustawy%2003_1864.txt
# ustawy%2003_1865.txt
# ustawy%2003_1873.txt
# ustawy%2003_1884.txt
# ustawy%2003_1886.txt
# ustawy%2003_1934.txt
# ustawy%2003_1935.txt
# ustawy%2003_1936.txt
# ustawy%2003_1937.txt
# ustawy%2003_1939.txt
# ustawy%2003_1953.txt
# ustawy%2003_1956.txt
# ustawy%2003_1958.txt
# ustawy%2003_1966.txt
# ustawy%2003_2018.txt
# ustawy%2003_2019.txt
# ustawy%2003_2020.txt
# ustawy%2003_2037.txt
# ustawy%2003_2049.txt
# ustawy%2003_2050.txt
# ustawy%2003_2078.txt
# ustawy%2003_2079.txt
# ustawy%2003_2081.txt
# ustawy%2003_2124.txt
# ustawy%2003_2125.txt
# ustawy%2003_2217.txt
# ustawy%2003_2221.txt
# ustawy%2003_2255.txt
# ustawy%2003_2256.txt
# ustawy%2003_2258.txt
# ustawy%2003_2259.txt
# ustawy%2003_2262.txt
# ustawy%2003_2263.txt
# ustawy%2003_2271.txt
# ustawy%2003_2273.txt
# ustawy%2003_2274.txt
# ustawy%2003_2275.txt
# ustawy%2003_2276.txt
# ustawy%2003_2277.txt
# ustawy%2003_335.txt
# ustawy%2003_423.txt
# ustawy%2003_452.txt
# ustawy%2003_498.txt
# ustawy%2003_507.txt
# ustawy%2003_516.txt
# ustawy%2003_517.txt
# ustawy%2003_535.txt
# ustawy%2003_592.txt
# ustawy%2003_595.txt
# ustawy%2003_596.txt
# ustawy%2003_597.txt
# ustawy%2003_598.txt
# ustawy%2003_660.txt
# ustawy%2003_661.txt
# ustawy%2003_715.txt
# ustawy%2003_718.txt
# ustawy%2003_720.txt
# ustawy%2003_758.txt
# ustawy%2003_760.txt
# ustawy%2003_774.txt
# ustawy%2003_782.txt
# ustawy%2003_819.txt
# ustawy%2003_844.txt
# ustawy%2003_845.txt
# ustawy%2003_962.txt
# ustawy%2004_1001.txt
# ustawy%2004_1002.txt
# ustawy%2004_102.txt
# ustawy%2004_1055.txt
# ustawy%2004_1136.txt
# ustawy%2004_1137.txt
# ustawy%2004_1202.txt
# ustawy%2004_1203.txt
# ustawy%2004_1204.txt
# ustawy%2004_1205.txt
# ustawy%2004_1206.txt
# ustawy%2004_1208.txt
# ustawy%2004_1262.txt
# ustawy%2004_1263.txt
# ustawy%2004_1264.txt
# ustawy%2004_1265.txt
# ustawy%2004_1291.txt
# ustawy%2004_1375.txt
# ustawy%2004_1376.txt
# ustawy%2004_1377.txt
# ustawy%2004_1378.txt
# ustawy%2004_144.txt
# ustawy%2004_145.txt
# ustawy%2004_146.txt
# ustawy%2004_147.txt
# ustawy%2004_148.txt
# ustawy%2004_149.txt
# ustawy%2004_1532.txt
# ustawy%2004_1533.txt
# ustawy%2004_1534.txt
# ustawy%2004_1535.txt
# ustawy%2004_1536.txt
# ustawy%2004_1546.txt
# ustawy%2004_1547.txt
# ustawy%2004_1550.txt
# ustawy%2004_1551.txt
# ustawy%2004_1568.txt
# ustawy%2004_1593.txt
# ustawy%2004_1597.txt
# ustawy%2004_1598.txt
# ustawy%2004_1644.txt
# ustawy%2004_1645.txt
# ustawy%2004_1646.txt
# ustawy%2004_1647.txt
# ustawy%2004_1648.txt
# ustawy%2004_1649.txt
# ustawy%2004_1650.txt
# ustawy%2004_167.txt
# ustawy%2004_1693.txt
# ustawy%2004_1694.txt
# ustawy%2004_1695.txt
# ustawy%2004_1746.txt
# ustawy%2004_177.txt
# ustawy%2004_1800.txt
# ustawy%2004_1801.txt
# ustawy%2004_1805.txt
# ustawy%2004_1807.txt
# ustawy%2004_1808.txt
# ustawy%2004_1842.txt
# ustawy%2004_1843.txt
# ustawy%2004_1844.txt
# ustawy%2004_1845.txt
# ustawy%2004_1907.txt
# ustawy%2004_1922.txt
# ustawy%2004_1923.txt
# ustawy%2004_1924.txt
# ustawy%2004_1925.txt
# ustawy%2004_1954.txt
# ustawy%2004_1955.txt
# ustawy%2004_1956.txt
# ustawy%2004_1962.txt
# ustawy%2004_1963.txt
# ustawy%2004_1980.txt
# ustawy%2004_1981.txt
# ustawy%2004_1982.txt
# ustawy%2004_2065.txt
# ustawy%2004_2066.txt
# ustawy%2004_2067.txt
# ustawy%2004_2135.txt
# ustawy%2004_2155.txt
# ustawy%2004_2156.txt
# ustawy%2004_2157.txt
# ustawy%2004_2158.txt
# ustawy%2004_219.txt
# ustawy%2004_2249.txt
# ustawy%2004_225.txt
# ustawy%2004_226.txt
# ustawy%2004_2351.txt
# ustawy%2004_2352.txt
# ustawy%2004_2353.txt
# ustawy%2004_2354.txt
# ustawy%2004_2355.txt
# ustawy%2004_2356.txt
# ustawy%2004_2385.txt
# ustawy%2004_2386.txt
# ustawy%2004_2387.txt
# ustawy%2004_2388.txt
# ustawy%2004_2389.txt
# ustawy%2004_2390.txt
# ustawy%2004_2405.txt
# ustawy%2004_2406.txt
# ustawy%2004_2407.txt
# ustawy%2004_2414.txt
# ustawy%2004_2426.txt
# ustawy%2004_2455.txt
# ustawy%2004_2456.txt
# ustawy%2004_2507.txt
# ustawy%2004_2533.txt
# ustawy%2004_254.txt
# ustawy%2004_255.txt
# ustawy%2004_256.txt
# ustawy%2004_2580.txt
# ustawy%2004_2581.txt
# ustawy%2004_2598.txt
# ustawy%2004_2619.txt
# ustawy%2004_2647.txt
# ustawy%2004_2662.txt
# ustawy%2004_2698.txt
# ustawy%2004_2699.txt
# ustawy%2004_2700.txt
# ustawy%2004_2701.txt
# ustawy%2004_2702.txt
# ustawy%2004_2703.txt
# ustawy%2004_2708.txt
# ustawy%2004_2742.txt
# ustawy%2004_2755.txt
# ustawy%2004_2772.txt
# ustawy%2004_2773.txt
# ustawy%2004_2774.txt
# ustawy%2004_2775.txt
# ustawy%2004_2776.txt
# ustawy%2004_2777.txt
# ustawy%2004_2778.txt
# ustawy%2004_2779.txt
# ustawy%2004_2780.txt
# ustawy%2004_2781.txt
# ustawy%2004_2782.txt
# ustawy%2004_2783.txt
# ustawy%2004_2784.txt
# ustawy%2004_2785.txt
# ustawy%2004_2786.txt
# ustawy%2004_285.txt
# ustawy%2004_286.txt
# ustawy%2004_287.txt
# ustawy%2004_288.txt
# ustawy%2004_291.txt
# ustawy%2004_292.txt
# ustawy%2004_293.txt
# ustawy%2004_38.txt
# ustawy%2004_389.txt
# ustawy%2004_41.txt
# ustawy%2004_42.txt
# ustawy%2004_466.txt
# ustawy%2004_515.txt
# ustawy%2004_535.txt
# ustawy%2004_572.txt
# ustawy%2004_573.txt
# ustawy%2004_574.txt
# ustawy%2004_575.txt
# ustawy%2004_576.txt
# ustawy%2004_577.txt
# ustawy%2004_594.txt
# ustawy%2004_622.txt
# ustawy%2004_623.txt
# ustawy%2004_624.txt
# ustawy%2004_625.txt
# ustawy%2004_626.txt
# ustawy%2004_627.txt
# ustawy%2004_630.txt
# ustawy%2004_631.txt
# ustawy%2004_68.txt
# ustawy%2004_69.txt
# ustawy%2004_76.txt
# ustawy%2004_77.txt
# ustawy%2004_796.txt
# ustawy%2004_797.txt
# ustawy%2004_866.txt
# ustawy%2004_867.txt
# ustawy%2004_868.txt
# ustawy%2004_870.txt
# ustawy%2004_875.txt
# ustawy%2004_876.txt
# ustawy%2004_877.txt
# ustawy%2004_879.txt
# ustawy%2004_880.txt
# ustawy%2004_883.txt
# ustawy%2004_884.txt
# ustawy%2004_885.txt
# ustawy%2004_886.txt
# ustawy%2004_887.txt
# ustawy%2004_889.txt
# ustawy%2004_890.txt
# ustawy%2004_891.txt
# ustawy%2004_892.txt
# ustawy%2004_893.txt
# ustawy%2004_894.txt
# ustawy%2004_895.txt
# ustawy%2004_897.txt
# ustawy%2004_898.txt
# ustawy%2004_94.txt
# ustawy%2004_959.txt
# ustawy%2004_96.txt
# ustawy%2004_962.txt
# ustawy%2004_963.txt
# ustawy%2004_964.txt
# ustawy%2004_97.txt

# %% [markdown]
# ### Using the tagged corpus compute bigram statistic for the tokens containing: a. lemmatized, downcased word b. morphosyntactic category of the word (subst, fin, adj, etc.)

# %%
clarin_data['1993_599']
# Out:
# ['dzieje_(apostolskie):brev',
#  '.:interp',
#  'u:prep',
#  '.:interp',
#  'z:prep',
#  '1993:num',
#  'r:ign',
#  '.:interp',
#  'nr:subst',
#  '129:num',
#  ',:interp',
#  'poz:ign',
#  '.:interp',
#  '599:num',
#  'ustawa:subst',
#  'z:prep',
#  'dzień:subst',
#  '9:num',
#  'grudzień:subst',
#  '1993:num',
#  'r:ign',
#  '.:interp',
#  'o:prep',
#  'zmiana:subst',
#  'ustawa:subst',
#  'o:prep',
#  'podatek:subst',
#  'od:prep',
#  'towar:subst',
#  'i:conj',
#  'usługa:subst',
#  'oraz:conj',
#  'o:prep',
#  'podatek:subst',
#  'akcyzowy:adj',
#  'art:ign',
#  '.:interp',
#  '1:num',
#  '.:interp',
#  'w:prep',
#  'ustawa:subst',
#  'z:prep',
#  'dzień:subst',
#  '8:num',
#  'styczeń:subst',
#  '1993:num',
#  'r:ign',
#  '.:interp',
#  'o:prep',
#  'podatek:subst',
#  'od:prep',
#  'towar:subst',
#  'i:conj',
#  'usługa:subst',
#  'oraz:conj',
#  'o:prep',
#  'podatek:subst',
#  'akcyzowy:adj',
#  '(:interp',
#  'dzieje_(apostolskie):brev',
#  '.:interp',
#  'u:prep',
#  '.:interp',
#  'nr:subst',
#  '11:num',
#  ',:interp',
#  'poz:ign',
#  '.:interp',
#  '50:num',
#  'i:conj',
#  'nr:subst',
#  '28:num',
#  ',:interp',
#  'poz:ign',
#  '.:interp',
#  '127:num',
#  '):interp',
#  'wprowadzać:fin',
#  'się:qub',
#  'następujący:adj',
#  'zmiana:subst',
#  '::interp',
#  '1:num',
#  '):interp',
#  'w:prep',
#  'art:ign',
#  '.:interp',
#  '3:num',
#  '::interp',
#  'a:conj',
#  '):interp',
#  'dotychczasowy:adj',
#  'treść:subst',
#  'otrzymywać:fin',
#  'oznaczenie:subst',
#  'usta:subst',
#  '.:interp',
#  '1:num',
#  ',:interp',
#  'bit:brev',
#  '):interp',
#  'dodawać:fin',
#  'się:qub',
#  'usta:subst',
#  '.:interp',
#  '2:num',
#  'w:prep',
#  'brzmienie:subst',
#  '::interp',
#  '":interp',
#  '2:num',
#  '.:interp',
#  'rada:subst',
#  'minister:subst',
#  'może:qub',
#  'określać:inf',
#  ',:interp',
#  'w:prep',
#  'droga:subst',
#  'rozporządzenie:subst',
#  ',:interp',
#  'towar:subst',
#  'i:conj',
#  'usługa:subst',
#  ',:interp',
#  'z:prep',
#  'wyjątek:subst',
#  'wyrób:subst',
#  'akcyzowy:adj',
#  'i:conj',
#  'wyrób:subst',
#  'z:prep',
#  'metal:subst',
#  'szlachetny:subst',
#  ',:interp',
#  'do:prep',
#  'który:adj',
#  'nie:conj',
#  'stosować:fin',
#  'się:qub',
#  'przepis:subst',
#  'ustawa:subst',
#  '.:interp',
#  '":interp',
#  ';:interp',
#  '2:num',
#  '):interp',
#  'w:prep',
#  'art:ign',
#  '.:interp',
#  '4:num',
#  '::interp',
#  'a:conj',
#  '):interp',
#  'w:prep',
#  'pkt:subst',
#  '7:num',
#  'wyraz:subst',
#  '":interp',
#  'użytkowanie:subst',
#  'wynosić:fin',
#  '":interp',
#  'zastępować:fin',
#  'się:qub',
#  'wyraz:subst',
#  '":interp',
#  'używanie:subst',
#  'wynieść:praet',
#  '":interp',
#  ',:interp',
#  'bit:brev',
#  '):interp',
#  'w:prep',
#  'pkt:subst',
#  '10:num',
#  'kropka:subst',
#  'zastępować:fin',
#  'się:qub',
#  'średnik:subst',
#  'i:conj',
#  'dodawać:fin',
#  'wyraz:subst',
#  '":interp',
#  'w:prep',
#  'pozostały:adj',
#  'przypadek:subst',
#  'właściwy:adj',
#  'urząd:subst',
#  'skarbowy:adj',
#  'być:fin',
#  'drugi:subst',
#  'urząd:subst',
#  'skarbowy:adj',
#  'warszawa:subst',
#  '-:interp',
#  'śródmieście:subst',
#  '.:interp',
#  '":interp',
#  ';:interp',
#  '3:num',
#  '):interp',
#  'w:prep',
#  'art:ign',
#  '.:interp',
#  '6:num',
#  '::interp',
#  'a:conj',
#  '):interp',
#  'usta:subst',
#  '.:interp',
#  '4:num',
#  'otrzymywać:fin',
#  'brzmienie:subst',
#  '::interp',
#  '":interp',
#  '4:num',
#  '.:interp',
#  'jeżeli:comp',
#  'sprzedaż:subst',
#  'towar:subst',
#  'lub:conj',
#  'wykonanie:subst',
#  'usługa:subst',
#  'powinien:winien',
#  'być:inf',
#  'potwierdzić:ppas',
#  'faktura:subst',
#  'lub:conj',
#  'rachunek:subst',
#  'uprościć:ppas',
#  ',:interp',
#  'obowiązek:subst',
#  'podatkowy:adj',
#  'powstawać:fin',
#  'z:prep',
#  'chwila:subst',
#  'wystawić:ger',
#  'faktura:subst',
#  'lub:conj',
#  'rachunek:subst',
#  'uprościć:ppas',
#  ',:interp',
#  'nie:conj',
#  'późno:adv',
#  'jednak:conj',
#  'niż:conj',
#  'w:prep',
#  '7:num',
#  'dzień:subst',
#  'od:prep',
#  'dzień:subst',
#  'wydanie:subst',
#  'towar:subst',
#  'lub:conj',
#  'wykonanie:subst',
#  'usługa:subst',
#  '.:interp',
#  'wystawić:ger',
#  'faktura:subst',
#  'lub:conj',
#  'rachunek:subst',
#  'uprościć:ppas',
#  'następować:fin',
#  'nie:conj',
#  'późno:adv',
#  'niż:conj',
#  'w:prep',
#  'ostatni:subst',
#  'dzień:subst',
#  'miesiąc:subst',
#  ',:interp',
#  'w:prep',
#  'który:adj',
#  'wydać:imps',
#  'towar:subst',
#  'lub:conj',
#  'wykonać:imps',
#  'usługa:subst',
#  '.:interp',
#  '":interp',
#  ',:interp',
#  'bit:brev',
#  '):interp',
#  'w:prep',
#  'usta:subst',
#  '.:interp',
#  '5:num',
#  'wyraz:subst',
#  '":interp',
#  'rachunek:subst',
#  '(:interp',
#  'faktura:subst',
#  '):interp',
#  '":interp',
#  'zastępować:fin',
#  'się:qub',
#  'wyraz:subst',
#  '":interp',
#  'faktura:subst',
#  'i:conj',
#  'rachunek:subst',
#  'uprościć:ppas',
#  '":interp',
#  ',:interp',
#  'cent:brev',
#  '):interp',
#  'po:prep',
#  'usta:subst',
#  '.:interp',
#  '8:num',
#  'dodawać:fin',
#  'się:qub',
#  'usta:subst',
#  '.:interp',
#  '8a:ign',
#  'w:prep',
#  'brzmienie:subst',
#  '::interp',
#  '":interp',
#  '8a:ign',
#  '.:interp',
#  'przepis:subst',
#  'usta:subst',
#  '.:interp',
#  '8:num',
#  'stosować:fin',
#  'się:qub',
#  'również:qub',
#  'w:prep',
#  'przypadek:subst',
#  'eksport:subst',
#  'towar:subst',
#  ',:interp',
#  'jeżeli:comp',
#  '::interp',
#  '1:num',
#  '):interp',
#  'wywóz:subst',
#  'towar:subst',
#  'nastąpić:fin',
#  'w:prep',
#  'ciąg:subst',
#  'sześć:num',
#  'miesiąc:subst',
#  'od:prep',
#  'dzień:subst',
#  'otrzymać:ger',
#  'zaliczka:subst',
#  ',:interp',
#  '2:num',
#  '):interp',
#  'eksporter:subst',
#  'przedstawić:fin',
#  'w:prep',
#  'urząd:subst',
#  'skarbowy:adj',
#  'zabezpieczenie:subst',
#  'majątkowy:adj',
#  'kwota:subst',
#  'zwrot:subst',
#  'różnica:subst',
#  'podatek:subst',
#  ',:interp',
#  'o:prep',
#  'który:adj',
#  'mowa:subst',
#  'w:prep',
#  'art:ign',
#  '.:interp',
#  '21:num',
#  'usta:subst',
#  '.:interp',
#  '2:num',
#  '.:interp',
#  '":interp',
#  ';:interp',
#  '4:num',
#  '):interp',
#  'w:prep',
#  'art:ign',
#  '.:interp',
#  '7:num',
#  'w:prep',
#  'usta:subst',
#  '.:interp',
#  '1:num',
#  '::interp',
#  'a:conj',
#  '):interp',
#  'pkt:subst',
#  '4:num',
#  'otrzymywać:fin',
#  'brzmienie:subst',
#  '::interp',
#  '":interp',
#  '4:num',
#  '):interp',
#  'import:subst',
#  'towar:subst',
#  'zwolnić:ppas',
#  'od:prep',
#  'cło:subst',
#  'na:prep',
#  'podstawa:subst',
#  'art:ign',
#  '.:interp',
#  '12:num',
#  ',:interp',
#  '14:num',
#  'usta:subst',
#  '.:interp',
#  '1:num',
#  'pkt:subst',
#  '1:num',
#  '-:interp',
#  '5:num',
#  ',:interp',
#  '7:num',
#  '-:interp',
#  '36:num',
#  'i:conj',
#  '38:num',
#  ',:interp',
#  'art:ign',
#  '.:interp',
#  '15:num',
#  'oraz:conj',
#  'art:ign',
#  '.:interp',
#  '20:num',
#  'ustawa:subst',
#  'z:prep',
#  'dzień:subst',
#  '28:num',
#  'grudzień:subst',
#  '1989:num',
#  'r:ign',
#  '.:interp',
#  '-:interp',
#  'prawo:adv',
#  'celny:adj',
#  '(:interp',
#  'dzieje_(apostolskie):brev',
#  '.:interp',
#  'u:prep',
#  '.:interp',
#  'nr:subst',
#  '75:num',
#  ',:interp',
#  'poz:ign',
#  '.:interp',
#  '445:num',
#  ',:interp',
#  'z:prep',
#  '1991:num',
#  'r:ign',
#  '.:interp',
#  'nr:subst',
#  '60:num',
#  ',:interp',
#  'poz:ign',
#  '.:interp',
#  '253:num',
#  ',:interp',
#  'nr:subst',
#  '73:num',
#  ',:interp',
#  'poz:ign',
#  '.:interp',
#  '320:num',
#  'i:conj',
#  'nr:subst',
#  '100:num',
#  ',:interp',
#  'poz:ign',
#  '.:interp',
#  '442:num',
#  ',:interp',
#  'z:prep',
#  '1992:num',
#  'r:ign',
#  '.:interp',
#  'nr:subst',
#  '21:num',
#  ',:interp',
#  'poz:ign',
#  '.:interp',
#  '85:num',
#  'oraz:conj',
#  'z:prep',
#  '1993:num',
#  'r:ign',
#  '.:interp',
#  'nr:subst',
#  '60:num',
#  ',:interp',
#  'poz:ign',
#  '.:interp',
#  '279:num',
#  'i:conj',
#  'nr:subst',
#  '129:num',
#  ',:interp',
#  'poz:ign',
#  '.:interp',
#  '598:num',
#  '):interp',
#  ',:interp',
#  '":interp',
#  ',:interp',
#  'bit:brev',
#  '):interp',
#  'w:prep',
#  'pkt:subst',
#  '6:num',
#  'wyraz:subst',
#  'w:prep',
#  'nawias:subst',
#  'zastępować:fin',
#  'się:qub',
#  'wyraz:subst',
#  '":interp',
#  'dzieje_(apostolskie):brev',
#  '.:interp',
#  'u:prep',
#  '.:interp',
#  'z:prep',
#  '1993:num',
#  'r:ign',
#  '.:interp',
#  'nr:subst',
#  '90:num',
#  ',:interp',
#  'poz:ign',
#  '.:interp',
#  '416:num',
#  '":interp',
#  ';:interp',
#  '5:num',
#  '):interp',
#  'w:prep',
#  'art:ign',
#  '.:interp',
#  '9:num',
#  '::interp',
#  'a:conj',
#  '):interp',
#  'w:prep',
#  'usta:subst',
#  '.:interp',
#  '1:num',
#  'skreślać:fin',
#  'się:qub',
#  'wyraz:subst',
#  '":interp',
#  'nie:conj',
#  'późno:adv',
#  'niż:conj',
#  'na:prep',
#  '30:num',
#  'dzień:subst',
#  '":interp',
#  ',:interp',
#  'bit:brev',
#  '):interp',
#  'po:prep',
#  'usta:subst',
#  '.:interp',
#  '5:num',
#  'dodawać:fin',
#  'się:qub',
#  'usta:subst',
#  '.:interp',
#  '5a:ign',
#  'w:prep',
#  'brzmienie:subst',
#  '::interp',
#  '":interp',
#  '5a:ign',
#  '.:interp',
#  'w:prep',
#  'przypadek:subst',
#  'gdy:adv',
#  'zaprzestanie:subst',
#  'wykonanie:subst',
#  'czynność:subst',
#  'podlegać:pact',
#  'opodatkowanie:subst',
#  'nie:conj',
#  'zostać:praet',
#  'zgłosić:ppas',
#  'zgodnie:adv',
#  'z:prep',
#  'usta:subst',
#  '.:interp',
#  '4:num',
#  'i:conj',
#  '5:num',
#  ',:interp',
#  'urząd:subst',
#  'skarbowy:adj',
#  ',:interp',
#  'który:adj',
#  'dokonać:praet',
#  'rejestracja:subst',
#  ',:interp',
#  'wykreślać:fin',
#  'z:prep',
#  'urząd:subst',
#  'podatnik:subst',
#  'z:prep',
#  'rejestr:subst',
#  ',:interp',
#  'a:conj',
#  'w:prep',
#  'przypadek:subst',
#  'określony:adj',
#  'w:prep',
#  'usta:subst',
#  '.:interp',
#  '5:num',
#  'następować:fin',
#  'również:qub',
#  'unieważnienie:subst',
#  'numer:subst',
#  'identyfikacyjny:adj',
#  '.:interp',
#  '":interp',
#  ',:interp',
#  'cent:brev',
#  '):interp',
#  'w:prep',
#  'usta:subst',
#  '.:interp',
#  '8:num',
#  'wyraz:subst',
#  '":interp',
#  'rachunek:subst',
#  '(:interp',
#  'faktura:subst',
#  '):interp',
#  '":interp',
#  'zastępować:fin',
#  'się:qub',
#  'wyraz:subst',
#  '":interp',
#  'faktura:subst',
#  ',:interp',
#  'rachunek:subst',
#  'uprościć:ppas',
#  '":interp',
#  ';:interp',
#  '6:num',
#  '):interp',
#  'w:prep',
#  'art:ign',
#  '.:interp',
#  '10:num',
#  '::interp',
#  'a:conj',
#  '):interp',
#  'po:prep',
#  'usta:subst',
#  '.:interp',
#  '2:num',
#  'dodawać:fin',
#  'się:qub',
#  'usta:subst',
#  '.:interp',
#  '2a:ign',
#  'w:prep',
#  'brzmienie:subst',
#  '::interp',
#  '":interp',
#  '2a:ign',
#  '.:interp',
#  'przepis:subst',
#  'usta:subst',
#  '.:interp',
#  '2:num',
#  'stosować:fin',
#  'się:qub',
#  'odpowiednio:adv',
#  'do:prep',
#  'kwota:subst',
#  'zwrot:subst',
#  'różnica:subst',
#  'podatek:subst',
#  'wynikać:pact',
#  'z:prep',
#  'deklaracja:subst',
#  'podatkowy:adj',
#  '.:interp',
#  '":interp',
#  ',:interp',
#  'bit:brev',
#  '):interp',
#  'usta:subst',
#  '.:interp',
#  '3:num',
#  'otrzymywać:fin',
#  'brzmienie:subst',
#  '::interp',
#  '":interp',
#  '3:num',
#  '.:interp',
#  'przepis:subst',
#  'usta:subst',
#  '.:interp',
#  '1:num',
#  'nie:conj',
#  'stosować:fin',
#  'się:qub',
#  'do:prep',
#  'podatnik:subst',
#  'zwolnić:ppas',
#  'od:prep',
#  'podatek:subst',
#  'od:prep',
#  'towar:subst',
#  'i:conj',
#  'usługa:subst',
#  'na:prep',
#  'podstawa:subst',
#  'art:ign',
#  '.:interp',
#  '14:num',
#  'oraz:conj',
#  'podmiot:subst',
#  'wykonywać:pact',
#  'wyłącznie:adv',
#  'czynność:subst',
#  'zwolnić:ppas',
#  'od:prep',
#  'podatek:subst',
#  'na:prep',
#  'podstawa:subst',
#  'art:ign',
#  '.:interp',
#  '7:num',
#  'usta:subst',
#  '.:interp',
#  '1:num',
#  'lub:conj',
#  'na:prep',
#  'podstawa:subst',
#  'przepis:subst',
#  'wydać:ppas',
#  'na:prep',
#  'podstawa:subst',
#  'art:ign',
#  '.:interp',
#  '47:num',
#  ',:interp',
#  'chyba:qub',
#  'że:comp',
#  'przysługiwać:fin',
#  'im:comp',
#  'zwrot:subst',
#  'różnica:subst',
#  'podatek:subst',
#  'lub:conj',
#  'zwrot:subst',
#  'podatek:subst',
#  'naliczyć:ppas',
#  'zgodnie:adv',
#  'z:prep',
#  'art:ign',
#  '.:interp',
#  '21:num',
#  'lub:conj',
#  '23:num',
#  'pkt:subst',
#  '2:num',
#  '-:interp',
#  '4:num',
#  '.:interp',
#  '":interp',
#  ';:interp',
#  '7:num',
#  '):interp',
#  'art:ign',
#  '.:interp',
#  '14:num',
#  'otrzymywać:fin',
#  'brzmienie:subst',
#  '::interp',
#  '":interp',
#  'art:ign',
#  '.:interp',
#  '14:num',
#  '.:interp',
#  '1:num',
#  '.:interp',
#  'zwalniać:fin',
#  'się:qub',
#  'od:prep',
#  'podatek:subst',
#  'podatnik:subst',
#  '::interp',
#  '1:num',
#  '):interp',
#  'u:prep',
#  'który:adj',
#  'wartość:subst',
#  'sprzedaż:subst',
#  'towar:subst',
#  'w:prep',
#  'rozumienie:subst',
#  'art:ign',
#  '.:interp',
#  '2:num',
#  'usta:subst',
#  '.:interp',
#  '1:num',
#  'i:conj',
#  '3:num',
#  ',:interp',
#  'a:conj',
#  'także:qub',
#  'wartość:subst',
#  'eksport:subst',
#  'towar:subst',
#  'lub:conj',
#  'usługa:subst',
#  'nie:conj',
#  'przekroczyć:praet',
#  'łącznie:adv',
#  'w:prep',
#  'poprzedni:adj',
#  'rok:subst',
#  'podatkowy:adj',
#  '1:num',
#  ',:interp',
#  '2:num',
#  'miliard:brev',
#  'złoty:brev',
#  ',:interp',
#  '2:num',
#  '):interp',
#  'opłacać:pact',
#  'podatek:subst',
#  'dochodowy:adj',
#  'w:prep',
#  'forma:subst',
#  'kart:subst',
#  'podatkowy:adj',
#  ',:interp',
#  'w:prep',
#  'zakres:subst',
#  'działalność:subst',
#  'objąć:ppas',
#  'ten:adj',
#  'forma:subst',
#  'opodatkowanie:subst',
#  ',:interp',
#  'z:prep',
#  'uwzględnienie:subst',
#  'art:ign',
#  '.:interp',
#  '18:num',
#  'usta:subst',
#  '.:interp',
#  '3:num',
#  '.:interp',
#  '2:num',
#  '.:interp',
#  'podatnik:subst',
#  ',:interp',
#  'o:prep',
#  'który:adj',
#  'mowa:subst',
#  'w:prep',
#  'usta:subst',
#  '.:interp',
#  '1:num',
#  ',:interp',
#  'móc:fin',
#  'zrezygnować:inf',
#  'z:prep',
#  'zwolnienie:subst',
#  'określony:adj',
#  'w:prep',
#  'usta:subst',
#  '.:interp',
#  '1:num',
#  ',:interp',
#  'pod:prep',
#  'warunek:subst',
#  'zawiadomienie:subst',
#  'o:prep',
#  'tym:conj',
#  'zamiar:subst',
#  'właściwy:adj',
#  'urząd:subst',
#  'skarbowy:adj',
#  'przed:prep',
#  'początek:subst',
#  'miesiąc:subst',
#  ',:interp',
#  'w:prep',
#  'który:adj',
#  'rezygnować:fin',
#  'z:prep',
#  'zwolnienie:subst',
#  '.:interp',
#  'rezygnacja:subst',
#  'obowiązywać:fin',
#  'do:prep',
#  'koniec:subst',
#  'rok:subst',
#  'podatkowy:adj',
#  '.:interp',
#  '3:num',
#  '.:interp',
#  'jeżeli:comp',
#  'wartość:subst',
#  'sprzedaż:subst',
#  'towar:subst',
#  'u:prep',
#  'podatnik:subst',
#  'zwolnić:ppas',
#  'od:prep',
#  'podatek:subst',
#  'na:prep',
#  'podstawa:subst',
#  'usta:subst',
#  '.:interp',
#  '1:num',
#  'pkt:subst',
#  '1:num',
#  'przekroczyć:fin',
#  'kwota:subst',
#  '1:num',
#  ',:interp',
#  '2:num',
#  'miliard:brev',
#  'złoty:brev',
#  ',:interp',
#  'zwolnienie:subst',
#  'tracić:fin',
#  'moc:subst',
#  'w:prep',
#  'moment:subst',
#  'przekroczenie:subst',
#  'ten:adj',
#  'kwota:subst',
#  '.:interp',
#  'obowiązek:subst',
#  'podatkowy:adj',
#  'powstawać:fin',
#  'z:prep',
#  'chwila:subst',
#  'przekroczenie:subst',
#  'ten:adj',
#  'kwota:subst',
#  ',:interp',
#  'a:conj',
#  'opodatkowanie:subst',
#  'podlegać:fin',
#  'nadwyżka:subst',
#  'ponad:qub',
#  'ten:adj',
#  'kwota:subst',
#  '.:interp',
#  'za:qub',
#  'zgoda:subst',
#  'właściwy:adj',
#  'urząd:subst',
#  'skarbowy:adj',
#  'podatnik:subst',
#  'może:qub',
#  'zmniejszyć:inf',
#  'podatek:subst',
#  'należny:adj',
#  'o:prep',
#  'podatek:subst',
#  'naliczyć:ppas',
#  ',:interp',
#  'wynikać:pact',
#  'z:prep',
#  'rachunek:subst',
#  'uprościć:ppas',
#  'dokumentować:pact',
#  'zakup:subst',
#  'dokonany:adj',
#  'przed:prep',
#  'dzień:subst',
#  'utrata:subst',
#  'zwolnienie:subst',
#  ',:interp',
#  'pod:prep',
#  'warunek:subst',
#  'sporządzić:ger',
#  'spis:subst',
#  'z:prep',
#  'natura:subst',
#  'zapas:subst',
#  'ten:adj',
#  'towar:subst',
#  ...]

# %%
bigrams_clarin = []
for _, content in clarin_data.items():
    bigrams_clarin.extend(create_ngram(content))

# %%
bigrams_clarin_clean = []
for item in bigrams_clarin:
    if item[0].split(':')[0].isalpha() and item[1].split(':')[0].isalpha():
        bigrams_clarin_clean.append(item)

# %%
bigrams_clarin_clean_counter = Counter(bigrams_clarin_clean)
bigrams_clarin_clean_counter.most_common(10)
# Out:
# [(('w:prep', 'art:ign'), 32044),
#  (('o:prep', 'który:adj'), 28656),
#  (('który:adj', 'mowa:subst'), 28538),
#  (('mowa:subst', 'w:prep'), 28473),
#  (('w:prep', 'usta:subst'), 23557),
#  (('z:prep', 'dzień:subst'), 11360),
#  (('otrzymywać:fin', 'brzmienie:subst'), 10536),
#  (('określony:adj', 'w:prep'), 10240),
#  (('do:prep', 'sprawa:subst'), 8718),
#  (('ustawa:subst', 'z:prep'), 8624)]

# %%
tokens_clarin_global = []

for _, content in clarin_data.items():
    for word in content:
        if word.split(':')[0].isalpha():
            tokens_clarin_global.append(word)

# %%
tokens_clarin_global_counter = Counter(tokens_clarin_global)
tokens_clarin_global_counter.most_common(10)
# Out:
# [('w:prep', 202949),
#  ('i:conj', 90044),
#  ('z:prep', 87991),
#  ('art:ign', 83805),
#  ('o:prep', 64807),
#  ('do:prep', 60768),
#  ('usta:subst', 53641),
#  ('na:prep', 50657),
#  ('który:adj', 49382),
#  ('się:qub', 45887)]

# %% [markdown]
# ### Compute the same statistics as for the non-lemmatized words (i.e. PMI) and print top-10 entries with at least 5 occurrences.

# %%
number_of_tokens_clarin = sum(tokens_clarin_global_counter.values())
number_of_bigrams_clarin = sum(bigrams_clarin_clean_counter.values())

# %%
bigrams_filtered_clarin = defaultdict(int)

for k, v in bigrams_clarin_clean_counter.items():
    if v >= 5:
        bigrams_filtered_clarin[k] = v

# %%
pmi_filtered_clarin = defaultdict(float)

for bigram, value in bigrams_filtered_clarin.items():
    pmi_filtered_clarin[bigram] = np.log2( (value/number_of_bigrams_clarin) / ((tokens_clarin_global_counter[bigram[0]]/number_of_tokens_clarin) * (tokens_clarin_global_counter[bigram[1]]/number_of_tokens_clarin) ))
pmi_filtered_clarin_sorted = sorted(pmi_filtered_clarin.items(), key=lambda x:x[1], reverse = True)

# %%
pmi_filtered_clarin_sorted[:10]
# Out:
# [(('teryto:ign', 'rialnego:ign'), 19.823458847837117),
#  (('młynek:subst', 'młotkowy:adj'), 19.823458847837117),
#  (('grzegorz:subst', 'schetyna:ign'), 19.823458847837117),
#  (('pasta:subst', 'emulsyjny:adj'), 19.560424442003324),
#  (('odpowiedzieć:fin', 'dzialności:ign'), 19.560424442003324),
#  (('łańcuchowa:subst', 'rozszczepienie:subst'), 19.560424442003324),
#  (('chrom:subst', 'sześciowartościowy:adj'), 19.560424442003324),
#  (('adam:subst', 'mickiewicz:subst'), 19.560424442003324),
#  (('piotrek:subst', 'trybunalski:adj'), 19.338032020666876),
#  (('młyn:subst', 'kulowy:adj'), 19.338032020666876)]

# %% [markdown]
# ### Compute trigram counts for both corpora and perform the same filtering.

# %% [markdown]
# #### Spacy

# %%
trigrams_global = []

for _, content in tokenized_bills.items():   
    trigrams_global.extend(create_ngram(content, 3))

# %%
trigrams_global_count = Counter(trigrams_global)
trigrams_global_count.most_common(10)
# Out:
# [((',', 'poz', '.'), 43166),
#  (('-', '-', '-'), 34646),
#  (('w', 'art', '.'), 32033),
#  (('w', 'ust', '.'), 23520),
#  (('ust', '.', '1'), 23324),
#  (('.', 'art', '.'), 22917),
#  (('r', '.', 'nr'), 17856),
#  (('_', '_', '_'), 16213),
#  (('.', '1', '.'), 15609),
#  (('.', '2', '.'), 15279)]

# %%
trigrams_global_clean = defaultdict(int)

for key, value in trigrams_global_count.items():
    if key[0].isalpha() and key[1].isalpha() and key[2].isalpha():
        trigrams_global_clean[key] = value

# %%
number_of_trigrams = sum(trigrams_global_clean.values())
number_of_words_trigrams = number_of_words

# %%
trigrams_filtered = defaultdict(int)

for k, v in trigrams_global_clean.items():
    if v >= 5:
        trigrams_filtered[k] = v

# %%
trigrams_filtered
# Out:
# defaultdict(int,
#             {('ustawa', 'z', 'dnia'): 1190,
#              ('o', 'zmianie', 'ustawy'): 849,
#              ('zmianie', 'ustawy', 'o'): 642,
#              ('ustawy', 'o', 'podatku'): 135,
#              ('o', 'podatku', 'od'): 124,
#              ('podatku', 'od', 'towarów'): 226,
#              ('od', 'towarów', 'i'): 257,
#              ('towarów', 'i', 'usług'): 445,
#              ('i', 'usług', 'oraz'): 98,
#              ('usług', 'oraz', 'o'): 57,
#              ('oraz', 'o', 'podatku'): 53,
#              ('o', 'podatku', 'akcyzowym'): 71,
#              ('podatku', 'akcyzowym', 'art'): 15,
#              ('w', 'ustawie', 'z'): 3645,
#              ('ustawie', 'z', 'dnia'): 3649,
#              ('wprowadza', 'się', 'następujące'): 1804,
#              ('się', 'następujące', 'zmiany'): 1806,
#              ('dotychczasowa', 'treść', 'otrzymuje'): 37,
#              ('treść', 'otrzymuje', 'oznaczenie'): 37,
#              ('otrzymuje', 'oznaczenie', 'ust'): 16,
#              ('dodaje', 'się', 'ust'): 2766,
#              ('rada', 'ministrów', 'może'): 111,
#              ('ministrów', 'może', 'określać'): 5,
#              ('w', 'drodze', 'rozporządzenia'): 4691,
#              ('towary', 'i', 'usługi'): 13,
#              ('z', 'wyjątkiem', 'wyrobów'): 19,
#              ('wyjątkiem', 'wyrobów', 'akcyzowych'): 14,
#              ('wyrobów', 'akcyzowych', 'i'): 5,
#              ('i', 'wyrobów', 'z'): 8,
#              ('wyrobów', 'z', 'metali'): 14,
#              ('z', 'metali', 'szlachetnych'): 20,
#              ('do', 'których', 'nie'): 32,
#              ('których', 'nie', 'stosuje'): 22,
#              ('nie', 'stosuje', 'się'): 1406,
#              ('stosuje', 'się', 'przepisów'): 173,
#              ('się', 'przepisów', 'ustawy'): 44,
#              ('zastępuje', 'się', 'wyrazami'): 2940,
#              ('kropkę', 'zastępuje', 'się'): 643,
#              ('zastępuje', 'się', 'średnikiem'): 174,
#              ('się', 'średnikiem', 'i'): 169,
#              ('średnikiem', 'i', 'dodaje'): 169,
#              ('i', 'dodaje', 'wyrazy'): 92,
#              ('w', 'pozostałych', 'przypadkach'): 45,
#              ('lub', 'wykonanie', 'usługi'): 5,
#              ('obowiązek', 'podatkowy', 'powstaje'): 19,
#              ('podatkowy', 'powstaje', 'z'): 14,
#              ('powstaje', 'z', 'chwilą'): 27,
#              ('faktury', 'lub', 'rachunku'): 8,
#              ('nie', 'później', 'jednak'): 138,
#              ('później', 'jednak', 'niż'): 137,
#              ('jednak', 'niż', 'w'): 87,
#              ('dniu', 'od', 'dnia'): 11,
#              ('od', 'dnia', 'wydania'): 95,
#              ('towaru', 'lub', 'wykonania'): 5,
#              ('lub', 'wykonania', 'usługi'): 6,
#              ('następuje', 'nie', 'później'): 13,
#              ('nie', 'później', 'niż'): 673,
#              ('później', 'niż', 'w'): 358,
#              ('niż', 'w', 'ostatnim'): 7,
#              ('w', 'ostatnim', 'dniu'): 48,
#              ('ostatnim', 'dniu', 'miesiąca'): 10,
#              ('w', 'którym', 'wydano'): 10,
#              ('stosuje', 'się', 'również'): 196,
#              ('się', 'również', 'w'): 44,
#              ('również', 'w', 'przypadku'): 75,
#              ('w', 'przypadku', 'eksportu'): 7,
#              ('w', 'ciągu', 'sześciu'): 15,
#              ('ciągu', 'sześciu', 'miesięcy'): 14,
#              ('sześciu', 'miesięcy', 'od'): 64,
#              ('miesięcy', 'od', 'dnia'): 1074,
#              ('od', 'dnia', 'otrzymania'): 289,
#              ('w', 'urzędzie', 'skarbowym'): 19,
#              ('zwrotu', 'różnicy', 'podatku'): 17,
#              ('o', 'której', 'mowa'): 5511,
#              ('której', 'mowa', 'w'): 5488,
#              ('mowa', 'w', 'art'): 12311,
#              ('towarów', 'zwolnionych', 'od'): 9,
#              ('zwolnionych', 'od', 'cła'): 19,
#              ('od', 'cła', 'na'): 18,
#              ('cła', 'na', 'podstawie'): 18,
#              ('na', 'podstawie', 'art'): 1496,
#              ('ustawy', 'z', 'dnia'): 3053,
#              ('skreśla', 'się', 'wyrazy'): 752,
#              ('później', 'niż', 'na'): 74,
#              ('w', 'przypadku', 'gdy'): 819,
#              ('czynności', 'podlegających', 'opodatkowaniu'): 18,
#              ('zgłoszone', 'zgodnie', 'z'): 5,
#              ('zgodnie', 'z', 'ust'): 194,
#              ('a', 'w', 'przypadkach'): 33,
#              ('w', 'przypadkach', 'określonych'): 215,
#              ('przypadkach', 'określonych', 'w'): 206,
#              ('określonych', 'w', 'ust'): 482,
#              ('stosuje', 'się', 'odpowiednio'): 3091,
#              ('się', 'odpowiednio', 'do'): 632,
#              ('podatku', 'wynikającej', 'z'): 5,
#              ('wynikającej', 'z', 'deklaracji'): 5,
#              ('z', 'deklaracji', 'podatkowej'): 5,
#              ('stosuje', 'się', 'do'): 784,
#              ('się', 'do', 'podatników'): 9,
#              ('zwolnionych', 'od', 'podatku'): 17,
#              ('od', 'podatku', 'od'): 25,
#              ('usług', 'na', 'podstawie'): 6,
#              ('zwolnione', 'od', 'podatku'): 10,
#              ('od', 'podatku', 'na'): 30,
#              ('podatku', 'na', 'podstawie'): 28,
#              ('lub', 'na', 'podstawie'): 35,
#              ('na', 'podstawie', 'przepisów'): 862,
#              ('podstawie', 'przepisów', 'wydanych'): 9,
#              ('przepisów', 'wydanych', 'na'): 48,
#              ('wydanych', 'na', 'podstawie'): 503,
#              ('zwrot', 'różnicy', 'podatku'): 10,
#              ('zgodnie', 'z', 'art'): 634,
#              ('zwalnia', 'się', 'od'): 58,
#              ('się', 'od', 'podatku'): 26,
#              ('których', 'wartość', 'sprzedaży'): 11,
#              ('wartość', 'sprzedaży', 'towarów'): 10,
#              ('w', 'rozumieniu', 'art'): 326,
#              ('a', 'także', 'wartość'): 6,
#              ('towarów', 'lub', 'usług'): 29,
#              ('w', 'poprzednim', 'roku'): 77,
#              ('poprzednim', 'roku', 'podatkowym'): 19,
#              ('podatek', 'dochodowy', 'w'): 17,
#              ('dochodowy', 'w', 'formie'): 10,
#              ('w', 'formie', 'karty'): 79,
#              ('formie', 'karty', 'podatkowej'): 77,
#              ('w', 'zakresie', 'działalności'): 57,
#              ('zakresie', 'działalności', 'objętej'): 8,
#              ('z', 'uwzględnieniem', 'art'): 72,
#              ('o', 'których', 'mowa'): 13857,
#              ('których', 'mowa', 'w'): 13807,
#              ('mowa', 'w', 'ust'): 13474,
#              ('ze', 'zwolnienia', 'określonego'): 6,
#              ('zwolnienia', 'określonego', 'w'): 7,
#              ('określonego', 'w', 'ust'): 184,
#              ('zawiadomienia', 'o', 'tym'): 16,
#              ('właściwego', 'urzędu', 'skarbowego'): 29,
#              ('do', 'końca', 'roku'): 37,
#              ('końca', 'roku', 'podatkowego'): 13,
#              ('na', 'podstawie', 'ust'): 236,
#              ('ponad', 'tę', 'kwotę'): 8,
#              ('za', 'zgodą', 'właściwego'): 12,
#              ('zgodą', 'właściwego', 'urzędu'): 5,
#              ('o', 'podatek', 'naliczony'): 10,
#              ('dokonane', 'przed', 'dniem'): 13,
#              ('sporządzenia', 'spisu', 'z'): 6,
#              ('spisu', 'z', 'natury'): 19,
#              ('w', 'przypadku', 'podatników'): 20,
#              ('określoną', 'w', 'ust'): 43,
#              ('wartość', 'sprzedanych', 'towarów'): 10,
#              ('w', 'rozumieniu', 'przepisów'): 669,
#              ('rozumieniu', 'przepisów', 'o'): 356,
#              ('przepisów', 'o', 'zatrudnieniu'): 18,
#              ('o', 'zatrudnieniu', 'i'): 82,
#              ('i', 'rehabilitacji', 'zawodowej'): 11,
#              ('rehabilitacji', 'zawodowej', 'osób'): 11,
#              ('zawodowej', 'osób', 'niepełnosprawnych'): 13,
#              ('zwolnienie', 'od', 'podatku'): 7,
#              ('bez', 'względu', 'na'): 227,
#              ('względu', 'na', 'wartość'): 9,
#              ('pod', 'warunkiem', 'złożenia'): 9,
#              ('złożenia', 'przez', 'podatnika'): 5,
#              ('we', 'właściwym', 'urzędzie'): 15,
#              ('właściwym', 'urzędzie', 'skarbowym'): 8,
#              ('czynności', 'określonych', 'w'): 38,
#              ('określonych', 'w', 'art'): 1239,
#              ('w', 'ciągu', 'roku'): 128,
#              ('ciągu', 'roku', 'podatkowego'): 17,
#              ('w', 'proporcji', 'do'): 8,
#              ('wymienionej', 'w', 'ust'): 44,
#              ('określona', 'zgodnie', 'z'): 7,
#              ('określoną', 'zgodnie', 'z'): 11,
#              ('określeni', 'w', 'ust'): 7,
#              ('a', 'w', 'wyniku'): 5,
#              ('w', 'wyniku', 'tych'): 8,
#              ('od', 'początku', 'roku'): 63,
#              ('początku', 'roku', 'podatkowego'): 14,
#              ('podwyższeniu', 'w', 'stopniu'): 10,
#              ('w', 'stopniu', 'odpowiadającym'): 22,
#              ('stopniu', 'odpowiadającym', 'wskaźnikowi'): 12,
#              ('i', 'usług', 'w'): 24,
#              ('usług', 'w', 'okresie'): 5,
#              ('w', 'okresie', 'pierwszych'): 18,
#              ('okresie', 'pierwszych', 'trzech'): 6,
#              ('pierwszych', 'trzech', 'kwartałów'): 7,
#              ('trzech', 'kwartałów', 'roku'): 6,
#              ('kwartałów', 'roku', 'poprzedzającego'): 5,
#              ('roku', 'poprzedzającego', 'rok'): 120,
#              ('rok', 'kalendarzowy', 'w'): 6,
#              ('w', 'stosunku', 'do'): 1182,
#              ('stosunku', 'do', 'tego'): 11,
#              ('do', 'tego', 'samego'): 42,
#              ('tego', 'samego', 'okresu'): 6,
#              ('samego', 'okresu', 'roku'): 5,
#              ('okresu', 'roku', 'ubiegłego'): 7,
#              ('wyroby', 'z', 'metali'): 6,
#              ('lub', 'z', 'udziałem'): 7,
#              ('z', 'udziałem', 'tych'): 12,
#              ('udziałem', 'tych', 'metali'): 5,
#              ('wymienionych', 'w', 'załączniku'): 55,
#              ('w', 'załączniku', 'nr'): 300,
#              ('usługi', 'w', 'zakresie'): 106,
#              ('w', 'zakresie', 'doradztwa'): 6,
#              ('minister', 'finansów', 'określi'): 61,
#              ('listę', 'towarów', 'i'): 6,
#              ('podstawie', 'przepisów', 'o'): 301,
#              ('przepisów', 'o', 'statystyce'): 10,
#              ('o', 'statystyce', 'państwowej'): 6,
#              ('minister', 'finansów', 'w'): 43,
#              ('finansów', 'w', 'porozumieniu'): 45,
#              ('w', 'porozumieniu', 'z'): 1654,
#              ('porozumieniu', 'z', 'prezesem'): 40,
#              ('z', 'prezesem', 'głównego'): 14,
#              ('prezesem', 'głównego', 'urzędu'): 20,
#              ('głównego', 'urzędu', 'statystycznego'): 232,
#              ('listopada', 'roku', 'poprzedzającego'): 13,
#              ('poprzedzającego', 'rok', 'podatkowy'): 58,
#              ('w', 'drodze', 'obwieszczenia'): 117,
#              ('z', 'uwzględnieniem', 'zasady'): 18,
#              ('określonej', 'w', 'ust'): 88,
#              ('w', 'zdaniu', 'drugim'): 67,
#              ('zdaniu', 'drugim', 'po'): 15,
#              ('drugim', 'po', 'wyrazie'): 10,
#              ('dodaje', 'się', 'wyraz'): 109,
#              ('podstawą', 'opodatkowania', 'w'): 8,
#              ('opodatkowania', 'w', 'imporcie'): 6,
#              ('w', 'imporcie', 'towarów'): 7,
#              ('towarów', 'jest', 'wartość'): 5,
#              ('jest', 'wartość', 'celna'): 37,
#              ('wartość', 'celna', 'powiększona'): 13,
#              ('celna', 'powiększona', 'o'): 13,
#              ('powiększona', 'o', 'należne'): 12,
#              ('o', 'należne', 'cło'): 16,
#              ('należne', 'cło', 'i'): 6,
#              ('cło', 'i', 'podatek'): 8,
#              ('jeżeli', 'przedmiotem', 'importu'): 5,
#              ('są', 'towary', 'opodatkowane'): 5,
#              ('towary', 'opodatkowane', 'podatkiem'): 5,
#              ('opodatkowane', 'podatkiem', 'akcyzowym'): 6,
#              ('zastępuje', 'się', 'wyrazem'): 713,
#              ('obniżenie', 'kwoty', 'podatku'): 5,
#              ('kwoty', 'podatku', 'należnego'): 13,
#              ('w', 'rozliczeniu', 'za'): 10,
#              ('rozliczeniu', 'za', 'miesiąc'): 8,
#              ('w', 'którym', 'podatnik'): 16,
#              ('w', 'przypadku', 'określonym'): 81,
#              ('przypadku', 'określonym', 'w'): 80,
#              ('określonym', 'w', 'art'): 383,
#              ('dokument', 'odprawy', 'celnej'): 6,
#              ('w', 'miesiącu', 'następnym'): 5,
#              ('skreśla', 'się', 'i'): 5,
#              ('niż', 'w', 'ciągu'): 141,
#              ('od', 'końca', 'miesiąca'): 5,
#              ('w', 'przypadku', 'nabycia'): 35,
#              ('sprzedaży', 'towarów', 'opodatkowanych'): 5,
#              ('się', 'na', 'podstawie'): 277,
#              ('w', 'okresie', 'krótszym'): 7,
#              ('okresie', 'krótszym', 'niż'): 6,
#              ('niż', 'sześć', 'miesięcy'): 18,
#              ('po', 'upływie', 'sześciu'): 16,
#              ('upływie', 'sześciu', 'miesięcy'): 15,
#              ('miesięcy', 'od', 'rozpoczęcia'): 6,
#              ('określona', 'w', 'art'): 34,
#              ('może', 'na', 'czas'): 8,
#              ('na', 'czas', 'nie'): 135,
#              ('czas', 'nie', 'dłuższy'): 46,
#              ('nie', 'dłuższy', 'niż'): 327,
#              ('dłuższy', 'niż', 'trzy'): 15,
#              ('niż', 'trzy', 'miesiące'): 20,
#              ('do', 'wysokości', 'tej'): 5,
#              ('wysokości', 'tej', 'kwoty'): 5,
#              ('na', 'rachunek', 'bankowy'): 53,
#              ('dni', 'od', 'dnia'): 2070,
#              ('od', 'dnia', 'złożenia'): 191,
#              ('jeżeli', 'w', 'przypadku'): 6,
#              ('określonym', 'w', 'ust'): 230,
#              ('w', 'dwóch', 'równych'): 7,
#              ('równych', 'ratach', 'w'): 6,
#              ('w', 'ciągu', 'dwóch'): 41,
#              ('ciągu', 'dwóch', 'miesięcy'): 18,
#              ('miesięcy', 'następujących', 'po'): 6,
#              ('następujących', 'po', 'miesiącu'): 5,
#              ('w', 'którym', 'wystąpiła'): 6,
#              ('powinno', 'być', 'złożone'): 14,
#              ('złożone', 'w', 'terminie'): 6,
#              ('w', 'terminie', 'do'): 679,
#              ('dnia', 'miesiąca', 'następującego'): 88,
#              ('miesiąca', 'następującego', 'po'): 145,
#              ('następującego', 'po', 'miesiącu'): 99,
#              ('skreśla', 'się', 'art'): 468,
#              ('i', 'usług', 'lub'): 10,
#              ('do', 'obniżenia', 'podatku'): 8,
#              ('obniżenia', 'podatku', 'należnego'): 7,
#              ('o', 'którym', 'mowa'): 9169,
#              ('którym', 'mowa', 'w'): 9147,
#              ('przypadki', 'i', 'warunki'): 6,
#              ('wymienionych', 'w', 'art'): 443,
#              ('całkowicie', 'lub', 'częściowo'): 29,
#              ('zwolnionym', 'od', 'podatku'): 5,
#              ('może', 'określić', 'inne'): 9,
#              ('inne', 'niż', 'wymienione'): 53,
#              ('niż', 'wymienione', 'w'): 197,
#              ('wymienione', 'w', 'art'): 255,
#              ('nabycia', 'towarów', 'lub'): 8,
#              ('może', 'określić', 'przypadki'): 7,
#              ('lub', 'usług', 'oraz'): 6,
#              ('oraz', 'określić', 'zasady'): 5,
#              ('zastępuje', 'się', 'przecinkiem'): 596,
#              ('dodaje', 'się', 'pkt'): 1322,
#              ('z', 'wyjątkiem', 'przypadku'): 27,
#              ('przypadku', 'określonego', 'w'): 10,
#              ('określonego', 'w', 'art'): 243,
#              ('niezgodnie', 'z', 'art'): 9,
#              ('nastąpiło', 'w', 'wyniku'): 11,
#              ('wydatków', 'związanych', 'z'): 48,
#              ('które', 'nie', 'zostały'): 46,
#              ('nie', 'zostały', 'zaliczone'): 19,
#              ('zostały', 'zaliczone', 'do'): 22,
#              ('zaliczone', 'do', 'kosztów'): 27,
#              ('do', 'kosztów', 'uzyskania'): 87,
#              ('kosztów', 'uzyskania', 'przychodów'): 114,
#              ('uzyskania', 'przychodów', 'z'): 8,
#              ('przepisów', 'o', 'podatku'): 56,
#              ('o', 'podatku', 'dochodowym'): 283,
#              ('spółek', 'prawa', 'handlowego'): 22,
#              ('organ', 'podatkowy', 'określa'): 11,
#              ('sprzedaży', 'w', 'drodze'): 5,
#              ('w', 'drodze', 'oszacowania'): 18,
#              ('przy', 'zastosowaniu', 'stawki'): 5,
#              ('z', 'tym', 'że'): 569,
#              ('w', 'ten', 'sposób'): 65,
#              ('ulega', 'podwyższeniu', 'o'): 11,
#              ('w', 'wyniku', 'czego'): 7,
#              ('zwiększa', 'się', 'o'): 17,
#              ('się', 'o', 'kwotę'): 29,
#              ('dodaje', 'się', 'zdanie'): 159,
#              ('się', 'zdanie', 'drugie'): 184,
#              ('zdanie', 'drugie', 'w'): 126,
#              ('drugie', 'w', 'brzmieniu'): 126,
#              ('towary', 'przeznaczone', 'do'): 8,
#              ('dodaje', 'się', 'wyrazy'): 1428,
#              ('a', 'po', 'wyrazach'): 22,
#              ('czynności', 'wymienionych', 'w'): 22,
#              ('zdanie', 'pierwsze', 'otrzymuje'): 69,
#              ('pierwsze', 'otrzymuje', 'brzmienie'): 70,
#              ('wyrobów', 'akcyzowych', 'wymienionych'): 5,
#              ('akcyzowych', 'wymienionych', 'w'): 5,
#              ('dopuszczalnych', 'ubytków', 'wyrobów'): 11,
#              ('ubytków', 'wyrobów', 'akcyzowych'): 20,
#              ('urzędów', 'kontroli', 'skarbowej'): 10,
#              ('z', 'uwzględnieniem', 'warunków'): 21,
#              ('opodatkowania', 'akcyzą', 'jest'): 10,
#              ('jest', 'ich', 'wartość'): 10,
#              ('powiększona', 'o', 'cło'): 8,
#              ('także', 'w', 'przypadku'): 53,
#              ('na', 'podstawie', 'odrębnych'): 506,
#              ('podstawie', 'odrębnych', 'przepisów'): 451,
#              ('w', 'całości', 'lub'): 320,
#              ('całości', 'lub', 'w'): 275,
#              ('lub', 'w', 'części'): 256,
#              ('zwolnione', 'od', 'cła'): 59,
#              ('stosuje', 'się', 'stawkę'): 13,
#              ('minister', 'finansów', 'może'): 52,
#              ('finansów', 'może', 'określić'): 20,
#              ('osoby', 'lub', 'jednostki'): 10,
#              ('jednostki', 'inne', 'niż'): 7,
#              ('producent', 'lub', 'importer'): 29,
#              ('do', 'podstawy', 'opodatkowania'): 5,
#              ('określonej', 'w', 'art'): 218,
#              ('na', 'rzecz', 'osób'): 46,
#              ('osób', 'zagranicznych', 'w'): 6,
#              ('zagranicznych', 'w', 'rozumieniu'): 12,
#              ('rozumieniu', 'przepisów', 'prawa'): 61,
#              ('przepisów', 'prawa', 'dewizowego'): 14,
#              ('będących', 'podatnikami', 'podatku'): 8,
#              ('podatnikami', 'podatku', 'od'): 19,
#              ('na', 'polski', 'obszar'): 268,
#              ('polski', 'obszar', 'celny'): 325,
#              ('obszar', 'celny', 'na'): 9,
#              ('na', 'czas', 'oznaczony'): 200,
#              ('jeżeli', 'towary', 'te'): 8,
#              ('zgodnie', 'z', 'warunkami'): 39,
#              ('z', 'warunkami', 'określonymi'): 54,
#              ('warunkami', 'określonymi', 'w'): 57,
#              ('określonymi', 'w', 'przepisach'): 27,
#              ('lat', 'od', 'dnia'): 365,
#              ('od', 'dnia', 'ogłoszenia'): 956,
#              ('dnia', 'ogłoszenia', 'ustawy'): 26,
#              ('właściwy', 'urząd', 'skarbowy'): 21,
#              ('urząd', 'skarbowy', 'o'): 11,
#              ('o', 'łącznej', 'kwocie'): 6,
#              ('ustalonej', 'w', 'wyniku'): 5,
#              ('miesięcy', 'licząc', 'od'): 7,
#              ('licząc', 'od', 'dnia'): 181,
#              ('od', 'dnia', 'wejścia'): 741,
#              ('dnia', 'wejścia', 'ustawy'): 25,
#              ('wejścia', 'ustawy', 'w'): 45,
#              ('ustawy', 'w', 'życie'): 50,
#              ('zastępuje', 'się', 'liczbą'): 17,
#              ('w', 'drodze', 'zarządzenia'): 376,
#              ('na', 'okres', 'do'): 82,
#              ('niż', 'określone', 'w'): 223,
#              ('określone', 'w', 'ust'): 411,
#              ('oraz', 'w', 'art'): 407,
#              ('na', 'okres', 'nie'): 161,
#              ('okres', 'nie', 'dłuższy'): 186,
#              ('do', 'których', 'stosuje'): 45,
#              ('których', 'stosuje', 'się'): 53,
#              ('na', 'równi', 'z'): 50,
#              ('w', 'przypadku', 'wprowadzenia'): 11,
#              ('się', 'ministra', 'finansów'): 17,
#              ('ministra', 'finansów', 'w'): 13,
#              ('urzędu', 'statystycznego', 'do'): 9,
#              ('do', 'ustawy', 'z'): 66,
#              ('na', 'cele', 'inne'): 8,
#              ('cele', 'inne', 'niż'): 8,
#              ('brzmienie', 'określone', 'w'): 38,
#              ('określone', 'w', 'załącznikach'): 8,
#              ('w', 'załącznikach', 'nr'): 39,
#              ('do', 'niniejszej', 'ustawy'): 52,
#              ('w', 'okresie', 'od'): 206,
#              ('okresie', 'od', 'dnia'): 170,
#              ('dnia', 'wejścia', 'w'): 930,
#              ('wejścia', 'w', 'życie'): 2354,
#              ('w', 'życie', 'ustawy'): 1233,
#              ('życie', 'ustawy', 'do'): 25,
#              ('w', 'brzmieniu', 'nadanym'): 427,
#              ('brzmieniu', 'nadanym', 'niniejszą'): 414,
#              ('nadanym', 'niniejszą', 'ustawą'): 415,
#              ('się', 'do', 'wyrobów'): 7,
#              ('minister', 'finansów', 'ogłosi'): 12,
#              ('finansów', 'ogłosi', 'w'): 11,
#              ('ogłosi', 'w', 'dzienniku'): 84,
#              ('w', 'dzienniku', 'ustaw'): 119,
#              ('dzienniku', 'ustaw', 'rzeczypospolitej'): 108,
#              ('ustaw', 'rzeczypospolitej', 'polskiej'): 113,
#              ('rzeczypospolitej', 'polskiej', 'jednolity'): 68,
#              ('polskiej', 'jednolity', 'tekst'): 69,
#              ('jednolity', 'tekst', 'ustawy'): 77,
#              ('tekst', 'ustawy', 'o'): 24,
#              ('z', 'uwzględnieniem', 'zmian'): 95,
#              ('uwzględnieniem', 'zmian', 'wynikających'): 88,
#              ('zmian', 'wynikających', 'z'): 92,
#              ('wynikających', 'z', 'przepisów'): 157,
#              ('z', 'przepisów', 'ogłoszonych'): 80,
#              ('przepisów', 'ogłoszonych', 'przed'): 80,
#              ('ogłoszonych', 'przed', 'dniem'): 82,
#              ('przed', 'dniem', 'wydania'): 90,
#              ('dniem', 'wydania', 'jednolitego'): 71,
#              ('wydania', 'jednolitego', 'tekstu'): 71,
#              ('ustawa', 'wchodzi', 'w'): 1185,
#              ('wchodzi', 'w', 'życie'): 1423,
#              ('w', 'życie', 'z'): 832,
#              ('życie', 'z', 'dniem'): 820,
#              ('załączniki', 'do', 'ustawy'): 15,
#              ('podatku', 'w', 'wysokości'): 8,
#              ('towaru', 'lub', 'usługi'): 20,
#              ('związane', 'z', 'gospodarką'): 5,
#              ('urządzenia', 'i', 'narzędzia'): 5,
#              ('związane', 'z', 'ochroną'): 20,
#              ('z', 'ochroną', 'zdrowia'): 5,
#              ('z', 'tworzyw', 'sztucznych'): 15,
#              ('i', 'wyrobów', 'tytoniowych'): 20,
#              ('dla', 'dzieci', 'do'): 10,
#              ('o', 'długości', 'do'): 7,
#              ('związane', 'z', 'utrzymaniem'): 12,
#              ('z', 'utrzymaniem', 'i'): 7,
#              ('związane', 'z', 'budową'): 14,
#              ('sprzedaży', 'napojów', 'alkoholowych'): 9,
#              ('napojów', 'alkoholowych', 'o'): 5,
#              ('zawartości', 'alkoholu', 'powyżej'): 9,
#              ('w', 'stanie', 'nie'): 9,
#              ('usług', 'świadczonych', 'w'): 7,
#              ('turystyki', 'i', 'wypoczynku'): 10,
#              ('usług', 'świadczonych', 'przez'): 16,
#              ('osoby', 'fizyczne', 'nie'): 5,
#              ('maszyn', 'i', 'urządzeń'): 31,
#              ('i', 'roboty', 'budowlane'): 7,
#              ('oświaty', 'i', 'wychowania'): 231,
#              ('kultury', 'i', 'sztuki'): 111,
#              ('ochrony', 'zdrowia', 'i'): 18,
#              ('zdrowia', 'i', 'opieki'): 315,
#              ('i', 'opieki', 'społecznej'): 318,
#              ('o', 'zmianie', 'niektórych'): 268,
#              ('zmianie', 'niektórych', 'ustaw'): 213,
#              ('o', 'zaopatrzeniu', 'inwalidów'): 26,
#              ('zaopatrzeniu', 'inwalidów', 'wojennych'): 26,
#              ('inwalidów', 'wojennych', 'i'): 29,
#              ('wojennych', 'i', 'wojskowych'): 29,
#              ('i', 'wojskowych', 'oraz'): 26,
#              ('wojskowych', 'oraz', 'ich'): 24,
#              ('oraz', 'ich', 'rodzin'): 97,
#              ('podstawę', 'wymiaru', 'renty'): 10,
#              ('wymiaru', 'renty', 'inwalidzkiej'): 8,
#              ('ustala', 'się', 'od'): 13,
#              ('przepisów', 'o', 'zaopatrzeniu'): 41,
#              ('o', 'zaopatrzeniu', 'emerytalnym'): 142,
#              ('zaopatrzeniu', 'emerytalnym', 'pracowników'): 66,
#              ('emerytalnym', 'pracowników', 'i'): 56,
#              ('pracowników', 'i', 'ich'): 63,
#              ('i', 'ich', 'rodzin'): 94,
#              ('podstawy', 'wymiaru', 'renty'): 11,
#              ('następuje', 'od', 'miesiąca'): 5,
#              ('w', 'którym', 'jest'): 49,
#              ('którym', 'jest', 'przeprowadzana'): 12,
#              ('jest', 'przeprowadzana', 'waloryzacja'): 15,
#              ('w', 'myśl', 'ust'): 15,
#              ('określoną', 'w', 'art'): 51,
#              ('przysługuje', 'dodatek', 'do'): 9,
#              ('dodatek', 'do', 'emerytury'): 5,
#              ('do', 'emerytury', 'lub'): 98,
#              ('emerytury', 'lub', 'renty'): 187,
#              ('renty', 'w', 'wysokości'): 6,
#              ('przeciętnego', 'wynagrodzenia', 'w'): 46,
#              ('wynagrodzenia', 'w', 'kwartale'): 16,
#              ('w', 'kwartale', 'kalendarzowym'): 21,
#              ('kwartale', 'kalendarzowym', 'poprzedzającym'): 17,
#              ('kalendarzowym', 'poprzedzającym', 'termin'): 23,
#              ('poprzedzającym', 'termin', 'waloryzacji'): 16,
#              ('z', 'innego', 'tytułu'): 28,
#              ('o', 'kombatantach', 'oraz'): 41,
#              ('kombatantach', 'oraz', 'niektórych'): 41,
#              ('oraz', 'niektórych', 'osobach'): 41,
#              ('niektórych', 'osobach', 'będących'): 41,
#              ('osobach', 'będących', 'ofiarami'): 41,
#              ('będących', 'ofiarami', 'represji'): 42,
#              ('ofiarami', 'represji', 'wojennych'): 42,
#              ('represji', 'wojennych', 'i'): 42,
#              ('wojennych', 'i', 'okresu'): 42,
#              ('i', 'okresu', 'powojennego'): 47,
#              ('kombatantom', 'i', 'innym'): 6,
#              ('i', 'innym', 'osobom'): 21,
#              ('innym', 'osobom', 'uprawnionym'): 9,
#              ('emeryturę', 'lub', 'rentę'): 60,
#              ('o', 'rewaloryzacji', 'emerytur'): 22,
#              ('rewaloryzacji', 'emerytur', 'i'): 23,
#              ('emerytur', 'i', 'rent'): 132,
#              ('o', 'zasadach', 'ustalania'): 20,
#              ('zasadach', 'ustalania', 'emerytur'): 20,
#              ('ustalania', 'emerytur', 'i'): 20,
#              ('i', 'rent', 'oraz'): 26,
#              ('rent', 'oraz', 'o'): 21,
#              ('oraz', 'o', 'zmianie'): 282,
#              ('w', 'razie', 'zbiegu'): 44,
#              ('opłacania', 'składek', 'na'): 41,
#              ('składek', 'na', 'fundusz'): 41,
#              ('ubezpieczenia', 'społecznego', 'rolników'): 13,
#              ('jeżeli', 'okresy', 'składkowe'): 7,
#              ('okresy', 'składkowe', 'i'): 14,
#              ('składkowe', 'i', 'nieskładkowe'): 14,
#              ('w', 'myśl', 'art'): 38,
#              ('w', 'celu', 'nabycia'): 7,
#              ('nabycia', 'prawa', 'do'): 62,
#              ('prawa', 'do', 'świadczenia'): 19,
#              ('lub', 'renty', 'z'): 21,
#              ('z', 'ubezpieczenia', 'społecznego'): 86,
#              ('okres', 'opłacania', 'składek'): 6,
#              ('przyznaje', 'się', 'na'): 19,
#              ('się', 'na', 'wniosek'): 73,
#              ('na', 'wniosek', 'zainteresowanego'): 69,
#              ('bez', 'uwzględnienia', 'dodatków'): 5,
#              ('renty', 'inwalidzkiej', 'dla'): 5,
#              ('i', 'lub', 'ii'): 30,
#              ('lub', 'ii', 'grupy'): 18,
#              ('w', 'przypadku', 'renty'): 5,
#              ('emerytury', 'i', 'renty'): 76,
#              ('przy', 'zastosowaniu', 'wskaźnika'): 15,
#              ('prezes', 'zakładu', 'ubezpieczeń'): 16,
#              ('zakładu', 'ubezpieczeń', 'społecznych'): 182,
#              ('ubezpieczeń', 'społecznych', 'ogłasza'): 9,
#              ('społecznych', 'ogłasza', 'w'): 9,
#              ('ogłasza', 'w', 'dzienniku'): 54,
#              ('w', 'dzienniku', 'urzędowym'): 341,
#              ('dzienniku', 'urzędowym', 'rzeczypospolitej'): 253,
#              ('urzędowym', 'rzeczypospolitej', 'polskiej'): 253,
#              ('dnia', 'drugiego', 'miesiąca'): 7,
#              ('drugiego', 'miesiąca', 'każdego'): 6,
#              ('miesiąca', 'każdego', 'kwartału'): 11,
#              ('wynagrodzenia', 'stanowiącego', 'podstawę'): 6,
#              ('przeciętnego', 'wynagrodzenia', 'za'): 9,
#              ('wynagrodzenia', 'za', 'kwartał'): 8,
#              ('za', 'kwartał', 'kalendarzowy'): 8,
#              ('ostatnio', 'ogłoszonego', 'przez'): 9,
#              ('ogłoszonego', 'przez', 'prezesa'): 14,
#              ('przez', 'prezesa', 'głównego'): 103,
#              ('prezesa', 'głównego', 'urzędu'): 159,
#              ('w', 'razie', 'osiągania'): 11,
#              ('wynagrodzenia', 'lub', 'dochodu'): 6,
#              ('w', 'kwocie', 'przekraczającej'): 7,
#              ('kwoty', 'przeciętnego', 'wynagrodzenia'): 8,
#              ('nie', 'wyższej', 'jednak'): 11,
#              ('wyższej', 'jednak', 'niż'): 10,
#              ('i', 'i', 'ii'): 29,
#              ('ulega', 'zmniejszeniu', 'o'): 9,
#              ('zmniejszeniu', 'o', 'kwotę'): 5,
#              ('o', 'kwotę', 'przekroczenia'): 5,
#              ('nie', 'większą', 'niż'): 23,
#              ('większą', 'niż', 'określona'): 5,
#              ('niż', 'określona', 'w'): 58,
#              ('nie', 'więcej', 'niż'): 207,
#              ('kwoty', 'określonej', 'w'): 25,
#              ('do', 'czasu', 'przeprowadzenia'): 7,
#              ('ustawy', 'o', 'kombatantach'): 5,
#              ('jednak', 'nie', 'dłużej'): 71,
#              ('nie', 'dłużej', 'niż'): 186,
#              ('dłużej', 'niż', 'do'): 57,
#              ('niż', 'do', 'dnia'): 241,
#              ('z', 'dniem', 'ogłoszenia'): 242,
#              ('ustaw', 'regulujących', 'zasady'): 8,
#              ('i', 'niektórych', 'innych'): 13,
#              ('niektórych', 'innych', 'ustaw'): 136,
#              ('niektórych', 'ustaw', 'art'): 37,
#              ('podatku', 'dochodowym', 'od'): 281,
#              ('dochodowym', 'od', 'osób'): 268,
#              ('od', 'osób', 'fizycznych'): 303,
#              ('przez', 'cały', 'rok'): 8,
#              ('cały', 'rok', 'podatkowy'): 6,
#              ('względu', 'na', 'wiek'): 24,
#              ('które', 'zgodnie', 'z'): 28,
#              ('zgodnie', 'z', 'odrębnymi'): 120,
#              ('z', 'odrębnymi', 'przepisami'): 119,
#              ('może', 'być', 'ustalony'): 8,
#              ('na', 'wniosek', 'wyrażony'): 5,
#              ('w', 'podwójnej', 'wysokości'): 10,
#              ('podwójnej', 'wysokości', 'podatku'): 5,
#              ('wysokości', 'podatku', 'obliczonego'): 5,
#              ('podatku', 'obliczonego', 'od'): 8,
#              ('obliczonego', 'od', 'połowy'): 5,
#              ('skreśla', 'się', 'ust'): 502,
#              ('się', 'przecinkiem', 'i'): 496,
#              ('przecinkiem', 'i', 'dodaje'): 488,
#              ('chociażby', 'jeden', 'z'): 10,
#              ('jeden', 'z', 'małżonków'): 6,
#              ('w', 'sposób', 'zryczałtowany'): 7,
#              ('z', 'wyjątkiem', 'dochodów'): 14,
#              ('opodatkowaniu', 'podatkiem', 'dochodowym'): 28,
#              ('dochodów', 'wymienionych', 'w'): 5,
#              ('z', 'więcej', 'niż'): 11,
#              ('więcej', 'niż', 'jednego'): 59,
#              ('w', 'danym', 'roku'): 205,
#              ('danym', 'roku', 'podatkowym'): 12,
#              ('z', 'zastrzeżeniem', 'art'): 666,
#              ('ze', 'źródła', 'przychodów'): 9,
#              ('w', 'roku', 'podatkowym'): 190,
#              ('ze', 'sprzedaży', 'rzeczy'): 7,
#              ('rzeczy', 'i', 'praw'): 25,
#              ('i', 'praw', 'majątkowych'): 32,
#              ('ze', 'źródeł', 'przychodów'): 5,
#              ('z', 'których', 'dochody'): 6,
#              ('są', 'wolne', 'od'): 27,
#              ('wolne', 'od', 'podatku'): 5,
#              ('od', 'podatku', 'dochodowego'): 56,
#              ('w', 'równych', 'częściach'): 17,
#              ('z', 'tego', 'źródła'): 13,
#              ('kolejno', 'po', 'sobie'): 8,
#              ('po', 'sobie', 'następujących'): 7,
#              ('przypadku', 'gdy', 'podatnik'): 9,
#              ('jest', 'w', 'sposób'): 12,
#              ('w', 'sposób', 'określony'): 302,
#              ('sposób', 'określony', 'w'): 278,
#              ('określony', 'w', 'art'): 226,
#              ('odlicza', 'się', 'od'): 13,
#              ('z', 'tego', 'samego'): 7,
#              ('i', 'dodaje', 'się'): 691,
#              ('według', 'cen', 'rynkowych'): 5,
#              ('cen', 'rynkowych', 'stosowanych'): 10,
#              ('rynkowych', 'stosowanych', 'w'): 8,
#              ('stosowanych', 'w', 'danej'): 8,
#              ('w', 'danej', 'miejscowości'): 25,
#              ('danej', 'miejscowości', 'w'): 9,
#              ('przychody', 'ze', 'sprzedaży'): 20,
#              ('całości', 'lub', 'części'): 77,
#              ('z', 'wykonywaną', 'działalnością'): 8,
#              ('z', 'wyjątkiem', 'gdy'): 10,
#              ('wydatków', 'poniesionych', 'przez'): 15,
#              ('przez', 'podatnika', 'na'): 20,
#              ('wytworzenie', 'we', 'własnym'): 13,
#              ('we', 'własnym', 'zakresie'): 61,
#              ('własnym', 'zakresie', 'środków'): 5,
#              ('zakresie', 'środków', 'trwałych'): 5,
#              ('środków', 'trwałych', 'lub'): 59,
#              ('trwałych', 'lub', 'wartości'): 55,
#              ('lub', 'wartości', 'niematerialnych'): 57,
#              ('wartości', 'niematerialnych', 'i'): 238,
#              ('niematerialnych', 'i', 'prawnych'): 243,
#              ('których', 'zgodnie', 'z'): 9,
#              ('dokonuje', 'się', 'odpisów'): 10,
#              ('się', 'odpisów', 'amortyzacyjnych'): 10,
#              ('skreśla', 'się', 'wyraz'): 133,
#              ('podatków', 'i', 'opłat'): 31,
#              ('w', 'związku', 'ze'): 133,
#              ('i', 'innych', 'należności'): 54,
#              ('różnicy', 'podatku', 'od'): 9,
#              ('w', 'rozumieniu', 'odrębnych'): 24,
#              ('rozumieniu', 'odrębnych', 'przepisów'): 24,
#              ('i', 'praw', 'pokrewnych'): 13,
#              ('praw', 'pokrewnych', 'w'): 5,
#              ('pokrewnych', 'w', 'rozumieniu'): 5,
#              ('obligacji', 'skarbu', 'państwa'): 12,
#              ('skarbu', 'państwa', 'oraz'): 83,
#              ('i', 'środków', 'na'): 5,
#              ('środków', 'na', 'rachunkach'): 8,
#              ('na', 'rachunkach', 'bankowych'): 38,
#              ('w', 'związku', 'z'): 1277,
#              ('związku', 'z', 'prowadzoną'): 22,
#              ('działalnością', 'gospodarczą', 'lub'): 8,
#              ('związku', 'z', 'wykonywaniem'): 136,
#              ('rodzin', 'zastępczych', 'oraz'): 5,
#              ('pomoc', 'pieniężna', 'na'): 5,
#              ('nabycie', 'nastąpiło', 'w'): 5,
#              ('nastąpiło', 'w', 'drodze'): 10,
#              ('w', 'drodze', 'spadku'): 26,
#              ('drodze', 'spadku', 'lub'): 11,
#              ('spadku', 'lub', 'darowizny'): 15,
#              ('i', 'wpłat', 'na'): 6,
#              ('i', 'wpłaty', 'na'): 7,
#              ('w', 'ciężar', 'kosztów'): 12,
#              ('określają', 'odrębne', 'ustawy'): 12,
#              ('dodaje', 'się', 'przecinek'): 113,
#              ('się', 'przecinek', 'i'): 148,
#              ('przecinek', 'i', 'wyrazy'): 77,
#              ('świadectw', 'udziałowych', 'narodowych'): 7,
#              ('udziałowych', 'narodowych', 'funduszy'): 7,
#              ('narodowych', 'funduszy', 'inwestycyjnych'): 16,
#              ('funduszy', 'inwestycyjnych', 'oraz'): 11,
#              ('podstawę', 'dokonywania', 'odpisów'): 5,
#              ('dokonywania', 'odpisów', 'amortyzacyjnych'): 18,
#              ('tym', 'że', 'jest'): 5,
#              ('kosztem', 'uzyskania', 'przychodów'): 30,
#              ('zwolniony', 'jest', 'od'): 5,
#              ('w', 'celu', 'wytworzenia'): 10,
#              ('towarów', 'lub', 'świadczenia'): 9,
#              ('lub', 'świadczenia', 'usług'): 16,
#              ('w', 'tej', 'części'): 15,
#              ('której', 'zgodnie', 'z'): 15,
#              ('zgodnie', 'z', 'przepisami'): 557,
#              ('z', 'przepisami', 'o'): 136,
#              ('przepisami', 'o', 'podatku'): 6,
#              ('podatnikowi', 'nie', 'przysługuje'): 5,
#              ('nie', 'przysługuje', 'obniżenie'): 5,
#              ('przysługuje', 'obniżenie', 'kwoty'): 5,
#              ('naliczony', 'podatek', 'od'): 5,
#              ('podatek', 'od', 'towarów'): 21,
#              ('i', 'usług', 'nie'): 6,
#              ('podatek', 'należny', 'w'): 6,
#              ('należny', 'w', 'przypadku'): 5,
#              ('przez', 'podatnika', 'towarów'): 5,
#              ('i', 'świadczenia', 'usług'): 6,
#              ('świadczenia', 'usług', 'na'): 11,
#              ('usług', 'na', 'potrzeby'): 5,
#              ('na', 'potrzeby', 'reprezentacji'): 7,
#              ('potrzeby', 'reprezentacji', 'i'): 5,
#              ('reprezentacji', 'i', 'reklamy'): 5,
#              ('podatnikowi', 'w', 'jakiejkolwiek'): 12,
#              ('w', 'jakiejkolwiek', 'formie'): 32,
#              ('zaliczonych', 'do', 'kosztów'): 8,
#              ('z', 'zastrzeżeniem', 'pkt'): 79,
#              ('z', 'tytułu', 'używania'): 8,
#              ('do', 'ewidencji', 'środków'): 10,
#              ('ewidencji', 'środków', 'trwałych'): 20,
#              ('w', 'tym', 'także'): 124,
#              ('prowadzącej', 'działalność', 'gospodarczą'): 13,
#              ('w', 'części', 'przekraczającej'): 14,
#              ('kwotę', 'wynikającą', 'z'): 7,
#              ('określonej', 'w', 'odrębnych'): 12,
#              ('w', 'odrębnych', 'przepisach'): 432,
#              ('przepisach', 'obowiązujących', 'w'): 7,
#              ('obowiązujących', 'w', 'przedsiębiorstwach'): 9,
#              ('w', 'przedsiębiorstwach', 'państwowych'): 14,
#              ('w', 'celu', 'ustalenia'): 127,
#              ('podatnik', 'jest', 'obowiązany'): 60,
#              ('jest', 'obowiązany', 'do'): 382,
#              ('obowiązany', 'do', 'prowadzenia'): 15,
#              ('do', 'prowadzenia', 'ewidencji'): 31,
#              ('ewidencji', 'przebiegu', 'pojazdu'): 6,
#              ('na', 'końcu', 'dodaje'): 120,
#              ('końcu', 'dodaje', 'się'): 120,
#              ('likwidacji', 'działalności', 'gospodarczej'): 5,
#              ('uważa', 'się', 'datę'): 8,
#              ('mowa', 'w', 'zdaniu'): 52,
#              ('w', 'zdaniu', 'poprzednim'): 9,
#              ('prowadzona', 'jest', 'działalność'): 18,
#              ('zmiana', 'umowy', 'spółki'): 5,
#              ('nie', 'mającej', 'osobowości'): 22,
#              ('mającej', 'osobowości', 'prawnej'): 22,
#              ('wpływ', 'na', 'ustalenie'): 5,
#              ('organ', 'podatkowy', 'może'): 26,
#              ('może', 'określić', 'wysokość'): 5,
#              ('na', 'podstawie', 'przeciętnych'): 5,
#              ('podstawie', 'przeciętnych', 'cen'): 5,
#              ('przeciętnych', 'cen', 'stosowanych'): 6,
#              ('cen', 'stosowanych', 'w'): 5,
#              ('wynikające', 'ze', 'stosunku'): 13,
#              ('ze', 'stosunku', 'pracy'): 55,
#              ('z', 'wymienionych', 'osób'): 6,
#              ('przez', 'pojęcie', 'powiązań'): 6,
#              ('do', 'drugiego', 'stopnia'): 37,
#              ('ustalony', 'zgodnie', 'z'): 11,
#              ('o', 'państwowej', 'straży'): 28,
#              ('państwowej', 'straży', 'pożarnej'): 483,
#              ('jednostek', 'ochrony', 'przeciwpożarowej'): 12,
#              ('ochrony', 'przeciwpożarowej', 'w'): 7,
#              ('przepisów', 'o', 'ochronie'): 153,
#              ('o', 'ochronie', 'przeciwpożarowej'): 30,
#              ('dokonanych', 'w', 'roku'): 11,
#              ('nienależnie', 'pobranych', 'emerytur'): 5,
#              ('zasiłków', 'z', 'ubezpieczenia'): 13,
#              ('jeżeli', 'nie', 'zostały'): 31,
#              ('nie', 'zostały', 'one'): 16,
#              ('przez', 'organ', 'rentowy'): 18,
#              ('lokalu', 'lub', 'budynku'): 12,
#              ('lub', 'budynku', 'mieszkalnego'): 5,
#              ('wydatków', 'ponoszonych', 'przez'): 6,
#              ('dzieci', 'własnych', 'i'): 8,
#              ('własnych', 'i', 'przysposobionych'): 8,
#              ('niepublicznych', 'o', 'uprawnieniach'): 7,
#              ('o', 'uprawnieniach', 'szkół'): 15,
#              ('uprawnieniach', 'szkół', 'publicznych'): 15,
#              ('wynagrodzenia', 'w', 'gospodarce'): 26,
#              ('w', 'gospodarce', 'narodowej'): 63,
#              ('gospodarce', 'narodowej', 'w'): 15,
#              ('na', 'każde', 'dziecko'): 21,
#              ('kwota', 'odliczeń', 'z'): 5,
#              ('z', 'tytułu', 'wydatków'): 9,
#              ('poniesionych', 'na', 'cele'): 10,
#              ('na', 'cele', 'określone'): 78,
#              ('cele', 'określone', 'w'): 86,
#              ('nie', 'może', 'w'): 20,
#              ('może', 'w', 'każdym'): 35,
#              ('w', 'każdym', 'roku'): 44,
#              ('każdym', 'roku', 'podatkowym'): 5,
#              ('kwoty', 'stanowiącej', 'górną'): 7,
#              ('stanowiącej', 'górną', 'granicę'): 7,
#              ('górną', 'granicę', 'pierwszego'): 12,
#              ('granicę', 'pierwszego', 'przedziału'): 9,
#              ('w', 'tym', 'roku'): 28,
#              ('może', 'być', 'dokonane'): 41,
#              ('wynosi', 'co', 'najmniej'): 56,
#              ('wysokość', 'wydatków', 'na'): 13,
#              ('wydatków', 'na', 'cele'): 24,
#              ('ustala', 'się', 'na'): 126,
#              ('na', 'podstawie', 'dokumentów'): 36,
#              ('podstawie', 'dokumentów', 'stwierdzających'): 11,
#              ('dokumentów', 'stwierdzających', 'ich'): 11,
#              ('stwierdzających', 'ich', 'poniesienie'): 12,
#              ('na', 'cele', 'wymienione'): 19,
#              ('cele', 'wymienione', 'w'): 19,
#              ('wymienione', 'w', 'ust'): 224,
#              ('i', 'w', 'pkt'): 12,
#              ('wyłącznie', 'przez', 'podatnika'): 5,
#              ('przez', 'podatnika', 'podatku'): 10,
#              ('podatnika', 'podatku', 'od'): 6,
#              ('nie', 'korzystającego', 'ze'): 5,
#              ('korzystającego', 'ze', 'zwolnienia'): 7,
#              ('ze', 'zwolnienia', 'od'): 49,
#              ('zwolnienia', 'od', 'tego'): 6,
#              ('od', 'tego', 'podatku'): 8,
#              ('wydatki', 'na', 'cele'): 24,
#              ('w', 'kraju', 'i'): 62,
#              ('i', 'nie', 'zostały'): 7,
#              ('uzyskania', 'przychodów', 'lub'): 5,
#              ('przychodów', 'lub', 'nie'): 5,
#              ('lub', 'nie', 'zostały'): 9,
#              ('nie', 'zostały', 'zwrócone'): 7,
#              ('zostały', 'zwrócone', 'podatnikowi'): 7,
#              ('zwrócone', 'podatnikowi', 'w'): 9,
#              ('określonego', 'w', 'przepisach'): 39,
#              ('w', 'przepisach', 'o'): 574,
#              ('pierwszego', 'przedziału', 'skali'): 8,
#              ('przedziału', 'skali', 'podatkowej'): 5,
#              ('przed', 'zawarciem', 'związku'): 5,
#              ('zawarciem', 'związku', 'małżeńskiego'): 8,
#              ('w', 'okresie', 'obowiązywania'): 25,
#              ('okresie', 'obowiązywania', 'ustawy'): 15,
#              ('w', 'czasie', 'trwania'): 101,
#              ('czasie', 'trwania', 'związku'): 8,
#              ('trwania', 'związku', 'małżeńskiego'): 8,
#              ('każdemu', 'z', 'nich'): 9,
#              ('podlega', 'zmniejszeniu', 'o'): 7,
#              ('o', 'wydatki', 'poniesione'): 5,
#              ('wydatki', 'poniesione', 'w'): 9,
#              ('jeżeli', 'byli', 'opodatkowani'): 8,
#              ('każdego', 'z', 'małżonków'): 10,
#              ('odliczenia', 'od', 'dochodu'): 8,
#              ('od', 'dochodu', 'wydatków'): 7,
#              ('wydatków', 'poniesionych', 'na'): 15,
#              ('mieszkalnego', 'na', 'użytkowy'): 5,
#              ('do', 'dochodów', 'uzyskanych'): 12,
#              ('w', 'którym', 'nastąpiło'): 59,
#              ('z', 'tego', 'tytułu'): 135,
#              ('wymienionych', 'w', 'ust'): 274,
#              ('nie', 'dokonuje', 'się'): 24,
#              ('dokonuje', 'się', 'od'): 7,
#              ('opodatkowanych', 'w', 'sposób'): 5,
#              ('odliczenia', 'wydatków', 'inwestycyjnych'): 6,
#              ('wydatków', 'inwestycyjnych', 'od'): 8,
#              ('uzyskanych', 'na', 'terytorium'): 7,
#              ('na', 'terytorium', 'rzeczypospolitej'): 1036,
#              ('terytorium', 'rzeczypospolitej', 'polskiej'): 1226,
#              ('rzeczypospolitej', 'polskiej', 'z'): 34,
#              ('łączy', 'się', 'z'): 9,
#              ('z', 'innych', 'źródeł'): 57,
#              ('pobiera', 'się', 'od'): 19,
#              ('się', 'od', 'nich'): 5,
#              ('podatek', 'w', 'formie'): 6,
#              ('w', 'formie', 'ryczałtu'): 42,
#              ('z', 'odsetek', 'od'): 7,
#              ('odsetek', 'od', 'pożyczek'): 11,
#              ('jest', 'przedmiotem', 'działalności'): 7,
#              ('przedmiotem', 'działalności', 'gospodarczej'): 14,
#              ('a', 'także', 'z'): 63,
#              ('dywidend', 'i', 'innych'): 7,
#              ('i', 'innych', 'przychodów'): 5,
#              ('innych', 'przychodów', 'z'): 10,
#              ('przychodów', 'z', 'tytułu'): 17,
#              ('z', 'tytułu', 'udziału'): 47,
#              ('tytułu', 'udziału', 'w'): 34,
#              ('udziału', 'w', 'zyskach'): 34,
#              ('w', 'zyskach', 'osób'): 26,
#              ('zyskach', 'osób', 'prawnych'): 26,
#              ('chyba', 'że', 'w'): 41,
#              ('że', 'w', 'przypadku'): 43,
#              ('opodatkowania', 'dochodów', 'uzyskanych'): 5,
#              ('dochodów', 'uzyskanych', 'przez'): 13,
#              ('umowa', 'w', 'sprawie'): 14,
#              ('w', 'sprawie', 'zapobieżenia'): 8,
#              ('sprawie', 'zapobieżenia', 'podwójnemu'): 8,
#              ('zapobieżenia', 'podwójnemu', 'opodatkowaniu'): 8,
#              ('innych', 'niż', 'określone'): 58,
#              ('określone', 'w', 'art'): 701,
#              ('związanych', 'ze', 'sprzedażą'): 6,
#              ('osobie', 'nie', 'będącej'): 5,
#              ('świadczeń', 'pieniężnych', 'z'): 16,
#              ('pieniężnych', 'z', 'tytułu'): 32,
#              ('innych', 'niż', 'wymienione'): 64,
#              ('organom', 'kontroli', 'skarbowej'): 20,
#              ('wojskowym', 'służbom', 'informacyjnym'): 6,
#              ('i', 'żandarmerii', 'wojskowej'): 6,
#              ('żandarmerii', 'wojskowej', 'lub'): 29,
#              ('urzędowi', 'ochrony', 'państwa'): 12,
#              ('wypłacanych', 'z', 'funduszu'): 6,
#              ('z', 'funduszu', 'operacyjnego'): 13,
#              ('samodzielnie', 'lub', 'w'): 9,
#              ('lub', 'w', 'formie'): 17,
#              ('w', 'formie', 'spółki'): 50,
#              ('formie', 'spółki', 'cywilnej'): 8,
#              ('spółki', 'cywilnej', 'osób'): 7,
#              ('cywilnej', 'osób', 'fizycznych'): 7,
#              ('w', 'roku', 'poprzedzającym'): 78,
#              ('roku', 'poprzedzającym', 'rok'): 57,
#              ('poprzedzającym', 'rok', 'podatkowy'): 26,
#              ('wspólników', 'spółki', 'cywilnej'): 5,
#              ('są', 'wyłącznie', 'osoby'): 7,
#              ('wyłącznie', 'osoby', 'fizyczne'): 5,
#              ('które', 'na', 'podstawie'): 34,
#              ('odrębnych', 'przepisów', 'podlegają'): 14,
#              ('w', 'wysokości', 'określonej'): 115,
#              ('wysokości', 'określonej', 'w'): 106,
#              ('w', 'tych', 'przepisach'): 96,
#              ('się', 'odpowiednio', 'art'): 169,
#              ('o', 'koszty', 'uzyskania'): 7,
#              ('określony', 'w', 'ust'): 163,
#              ('odliczyć', 'od', 'przychodów'): 6,
#              ('wydatki', 'określone', 'w'): 18,
#              ('poczynając', 'od', 'roku'): 8,
#              ('od', 'roku', 'podatkowego'): 8,
#              ('odpowiadającym', 'wskaźnikowi', 'wzrostu'): 9,
#              ('wskaźnikowi', 'wzrostu', 'cen'): 7,
#              ('rok', 'podatkowy', 'w'): 7,
#              ('podatkowy', 'w', 'stosunku'): 6,
#              ('zasady', 'i', 'tryb'): 412,
#              ('podatku', 'od', 'przychodów'): 26,
#              ('zryczałtowanym', 'podatkiem', 'dochodowym'): 5,
#              ('organ', 'podatkowy', 'określi'): 6,
#              ('od', 'tej', 'kwoty'): 8,
#              ('podatek', 'w', 'wysokości'): 5,
#              ('z', 'zastrzeżeniem', 'ust'): 1378,
#              ('za', 'dany', 'rok'): 42,
#              ('na', 'zasadach', 'określonych'): 1044,
#              ('zasadach', 'określonych', 'w'): 924,
#              ('za', 'rok', 'podatkowy'): 44,
#              ('dochodu', 'uzyskanego', 'w'): 10,
#              ('uzyskanego', 'w', 'danym'): 8,
#              ('w', 'danym', 'miesiącu'): 43,
#              ('za', 'każdy', 'miesiąc'): 27,
#              ('o', 'kwotę', 'stanowiącą'): 9,
#              ('drugiego', 'przedziału', 'skali'): 5,
#              ('za', 'miesiące', 'od'): 7,
#              ('w', 'którym', 'dochód'): 8,
#              ('którym', 'dochód', 'podatnika'): 7,
#              ('dochód', 'podatnika', 'przekroczył'): 5,
#              ('za', 'miesiące', 'następujące'): 7,
#              ('miesiące', 'następujące', 'po'): 7,
#              ('do', 'opodatkowania', 'dochodów'): 6,
#              ('poinformować', 'o', 'tym'): 9,
#              ('w', 'tym', 'przypadku'): 105,
#              ('od', 'miesiąca', 'następującego'): 21,
#              ('przestał', 'spełniać', 'warunki'): 17,
#              ('według', 'zasad', 'określonych'): 128,
#              ('zasad', 'określonych', 'w'): 147,
#              ('zmniejsza', 'się', 'o'): 22,
#              ...})

# %%
pmi_trigrams = defaultdict(float)

for trigram, value in trigrams_filtered.items():
    denominator = 1
    for token in trigram:
        denominator *=  words_global_counter[token] / number_of_words_trigrams
    denominator *= 2 ** pmi_filtered[(trigram[0], trigram[1])]

    pmi_trigrams[trigram] = pmi_filtered[(trigram[0], trigram[1])] + np.log2((value/number_of_trigrams) / denominator)

pmi_trigrams_sorted = sorted(pmi_trigrams.items(), key=lambda x:x[1], reverse = True)

# %% [markdown]
# #### Clarin

# %%
trigrams_clarin = []
for _, content in clarin_data.items():
    trigrams_clarin.extend(create_ngram(content, 3))

# %%
trigrams_clarin_clean = []
for item in trigrams_clarin:
    if item[0].split(':')[0].isalpha() and item[1].split(':')[0].isalpha() and item[2].split(':')[0].isalpha():
        trigrams_clarin_clean.append(item)

# %%
trigrams_clarin_clean_counter = Counter(trigrams_clarin_clean)
trigrams_clarin_clean_counter.most_common(10)
# Out:
# [(('o:prep', 'który:adj', 'mowa:subst'), 28535),
#  (('który:adj', 'mowa:subst', 'w:prep'), 28442),
#  (('mowa:subst', 'w:prep', 'usta:subst'), 13474),
#  (('mowa:subst', 'w:prep', 'art:ign'), 12311),
#  (('ustawa:subst', 'z:prep', 'dzień:subst'), 8588),
#  (('właściwy:adj', 'do:prep', 'sprawa:subst'), 7966),
#  (('minister:subst', 'właściwy:adj', 'do:prep'), 7888),
#  (('w:prep', 'droga:subst', 'rozporządzenie:subst'), 4751),
#  (('zastępować:fin', 'się:qub', 'wyraz:subst'), 3653),
#  (('w:prep', 'ustawa:subst', 'z:prep'), 3646)]

# %%
number_of_tokens_clarin_trigrams = number_of_tokens_clarin
number_of_trigrams_clarin = sum(trigrams_clarin_clean_counter.values())

# %%
trigrams_filtered_clarin = defaultdict(int)

for k, v in trigrams_clarin_clean_counter.items():
    if v >= 5:
        trigrams_filtered_clarin[k] = v

# %%
pmi_trigrams_clarin = defaultdict(float)

for trigram, value in trigrams_filtered_clarin.items():
    denominator = 1
    for token in trigram:
        denominator *=  tokens_clarin_global_counter[token] / number_of_words_trigrams
    denominator *= 2 ** pmi_filtered[(trigram[0], trigram[1])]
    pmi_trigrams_clarin[trigram] = pmi_filtered[(trigram[0], trigram[1])] + np.log2((value/number_of_trigrams_clarin) / denominator)

pmi_trigrams_clarin_sorted = sorted(pmi_trigrams_clarin.items(), key=lambda x:x[1], reverse = True)

# %% [markdown]
# ### Use PMI (with 5 occurrence threshold) to compute top 10 results for the trigrams. Devise a method for computing the values, based on the results for bigrams.

# %%
pmi_trigrams_sorted[:10]
# Out:
# [(('finałowego', 'turnieju', 'mistrzostw'), 37.040670670650584),
#  (('profilem', 'zaufanym', 'epuap'), 36.7996625711468),
#  (('cienką', 'sierścią', 'zwierzęcą'), 36.74111038879168),
#  (('przedwczesnego', 'wyrębu', 'drzewostanu'), 36.61557950670782),
#  (('centralnemu', 'biuru', 'antykorupcyjnemu'), 36.34879296601292),
#  (('turnieju', 'mistrzostw', 'europy'), 36.27513592428761),
#  (('potwierdzonym', 'profilem', 'zaufanym'), 36.252174775844296),
#  (('szybkiemu', 'postępowi', 'technicznemu'), 36.12372641037815),
#  (('piłce', 'nożnej', 'uefa'), 36.10461758743044),
#  (('wypalonym', 'paliwem', 'jądrowym'), 35.901333989041696)]

# %%
pmi_trigrams_clarin_sorted[:10]
# Out:
# [(('porcelanowy:adj', 'młyn:subst', 'kulowy:adj'), 38.06904299083846),
#  (('wymiennik:subst', 'przeponowy:adj', 'rurowy:adj'), 37.19832600778343),
#  (('reakcja:subst', 'łańcuchowa:subst', 'rozszczepienie:subst'),
#   36.36543599361868),
#  (('piłka:subst', 'nożny:adj', 'uefa:subst'), 35.43943657506246),
#  (('stany:subst', 'zjednoczyć:ppas', 'ameryka:subst'), 35.19832600778343),
#  (('finałowy:adj', 'turniej:subst', 'mistrzostwa:subst'), 35.15666685614621),
#  (('przedwczesny:adj', 'wyrąb:subst', 'drzewostan:subst'), 34.98400688698266),
#  (('kurtka:subst', 'anorak:subst', 'etc:ign'), 34.84077400316534),
#  (('mecz:subst', 'piłka:subst', 'nożny:adj'), 34.70247098089625),
#  (('profil:subst', 'zaufany:adj', 'epuap:ign'), 34.61524324028049)]

# %% [markdown]
# ### Create a table comparing the results for copora without and with tagging and lemmatization (separate table for bigrams and trigrams).

# %%
import pandas as pd

# %%
df_pmi_filtered_sorted = pd.DataFrame.from_dict(pmi_filtered_sorted)
df_pmi_filtered_clarin_sorted = pd.DataFrame.from_dict(pmi_filtered_clarin_sorted)

# %%
df_bigrams = pd.concat([df_pmi_filtered_sorted, df_pmi_filtered_clarin_sorted], axis = 1)
df_bigrams.columns = ['Bigram_clean', 'PMI_clean', 'Bigram_clarin', 'PMI_clarin']

# %%
df_bigrams[:10]
# Out:
#                  Bigram_clean  PMI_clean  \
# 0  (świeckie, przygotowujące)  19.817294
# 1     (klęskami, żywiołowymi)  19.817294
# 2        (ręcznego, miotacza)  19.817294
# 3        (stajnią, wyścigową)  19.817294
# 4    (otworami, wiertniczymi)  19.817294
# 5          (teryto, rialnego)  19.817294
# 6      (obcowania, płciowego)  19.817294
# 7    (nietykalność, cielesną)  19.817294
# 8             (młyny, kulowe)  19.817294
# 9          (młynki, młotkowe)  19.817294
#
#                               Bigram_clarin  PMI_clarinn
# 0                (teryto:ign, rialnego:ign)    19.823459
# 1              (młynek:subst, młotkowy:adj)    19.823459
# 2            (grzegorz:subst, schetyna:ign)    19.823459
# 3              (pasta:subst, emulsyjny:adj)    19.560424
# 4        (odpowiedzieć:fin, dzialności:ign)    19.560424
# 5  (łańcuchowa:subst, rozszczepienie:subst)    19.560424
# 6     (chrom:subst, sześciowartościowy:adj)    19.560424
# 7            (adam:subst, mickiewicz:subst)    19.560424
# 8          (piotrek:subst, trybunalski:adj)    19.338032
# 9                  (młyn:subst, kulowy:adj)    19.338032

# %%
df_pmi_trigrams_sorted = pd.DataFrame.from_dict(pmi_trigrams_sorted)
df_pmi_trigrams_clarin_sorted = pd.DataFrame.from_dict(pmi_trigrams_clarin_sorted)
df_trigrams = pd.concat([df_pmi_trigrams_sorted, df_pmi_trigrams_clarin_sorted], axis = 1)
df_trigrams.columns = ['Trigram_clean', 'PMI_clean', 'Trigram_clarin', 'PMI_clarin']

# %%
df_trigrams[:10]
# Out:
#                             Trigram_clean  PMI_clean  \
# 0      (finałowego, turnieju, mistrzostw)  37.040671
# 1             (profilem, zaufanym, epuap)  36.799663
# 2           (cienką, sierścią, zwierzęcą)  36.741110
# 3   (przedwczesnego, wyrębu, drzewostanu)  36.615580
# 4  (centralnemu, biuru, antykorupcyjnemu)  36.348793
# 5          (turnieju, mistrzostw, europy)  36.275136
# 6     (potwierdzonym, profilem, zaufanym)  36.252175
# 7    (szybkiemu, postępowi, technicznemu)  36.123726
# 8                   (piłce, nożnej, uefa)  36.104618
# 9          (wypalonym, paliwem, jądrowym)  35.901334
#
#                                       Trigram_clarin  PMI_clarin
# 0          (porcelanowy:adj, młyn:subst, kulowy:adj)   38.069043
# 1      (wymiennik:subst, przeponowy:adj, rurowy:adj)   37.198326
# 2  (reakcja:subst, łańcuchowa:subst, rozszczepien...   36.365436
# 3               (piłka:subst, nożny:adj, uefa:subst)   35.439437
# 4      (stany:subst, zjednoczyć:ppas, ameryka:subst)   35.198326
# 5   (finałowy:adj, turniej:subst, mistrzostwa:subst)   35.156667
# 6  (przedwczesny:adj, wyrąb:subst, drzewostan:subst)   34.984007
# 7              (kurtka:subst, anorak:subst, etc:ign)   34.840774
# 8               (mecz:subst, piłka:subst, nożny:adj)   34.702471
# 9             (profil:subst, zaufany:adj, epuap:ign)   34.615243

# %% [markdown]
# ### Answer the following questions:
# - Why do we have to filter the bigrams, rather than the token sequence?
# - Which method works better for the bigrams and which for the trigrams?
# - What types of expressions are discovered by the methods.
# - Can you devise a different type of filtering that would yield better results?

# %% [markdown]
# Sekwencja tokenów nie niesie ze sobą wystarczającej informacji. Poprzez analizę ngramów możemy wyłuskać z tekstu inne znaczenia niż tylko dosłowne znaczenie pojedynczych słów, które często w połączeniu mają zupełnie inne znaczenie niż oddzielnie. Frazy mogą bowiem mieć charakter idiomatyczny lub też konkretyzować dane słowo.

# %% [markdown]
# Poprawę wyników mogłaby przynieść zmiana metryki w analizowanej metodzie. Zaproponować można tutaj metrykę z rodziny PMI^k
# , która pozwala zredukować wpływ wyrażeń, które występują rzadziej.
