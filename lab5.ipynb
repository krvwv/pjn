# %%
# !pip install transformers
# !pip install sacremoses

# %%
from transformers import pipeline
import pandas as pd

# %%
#RoBERTa
roberta = pipeline('fill-mask', model='xlm-roberta-base')
# Out:
# Downloading:   0%|          | 0.00/615 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.12G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.10M [00:00<?, ?B/s]

# %%
#HerBERT Allegro
herbert = pipeline('fill-mask', model='allegro/herbert-base-cased')
# Out:
# Downloading:   0%|          | 0.00/472 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/654M [00:00<?, ?B/s]
# Some weights of the model checkpoint at allegro/herbert-base-cased were not used when initializing BertForMaskedLM: ['cls.sso.sso_relationship.bias', 'cls.sso.sso_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/907k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/556k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/129 [00:00<?, ?B/s]

# %%
# DistilBERT
distilbert = pipeline("fill-mask", model="distilbert-base-multilingual-cased")
# Out:
# Downloading:   0%|          | 0.00/466 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/542M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.96M [00:00<?, ?B/s]

# %% [markdown]
# ### Devise a method to test if the langage model understands Polish cases. E.g. testing for nominal case could be expressed as "Warszawa to największe [MASK]", and the masked word should be in nominative case. Create sentences for each case.

# %%
def test_model(model, cases, replace_mask = False):
    results = pd.DataFrame(columns = ['case', 'content', 'prediction', 'score'])
    for case, content in cases.items():
        if replace_mask:
            content = content.replace("<mask>", "[MASK]")
        predictions = model(content)
        for prediction in predictions:
            results = results.append({
              'case' : case,
              'content' : content,
              'prediction' : prediction['sequence'],
              'score' : prediction['score']
          }, ignore_index=True)
        return results

# %%
cases = {
  "Nominative": "Warszawa to największe <mask>",
  "Genitive": "Szarlotka <mask> nie ma sobie równych.",
  "Dative": "Mówiłem <mask>, żeby tego nie robił.", 
  "Accusative": "Za tym wzniesieniem świetnie widać <mask>",
  "Instrumental": "Do domu zawsze wracam <mask>", 
  "Locative": "Przed snem zawsze myślę o <mask>",
  "Vocative": "Ożeż ty <mask>!"
}

roberta_1 = test_model(roberta, cases)
herbert_1 = test_model(herbert, cases)
distilbert_1 = test_model(distilbert, cases, True)

# %%
final_df_1 = pd.DataFrame({
        "case": roberta_1.case, 
        "sentence": roberta_1.content,
        "roberta_prediction": roberta_1.prediction,
        "roberta_score": roberta_1.score,
        "herbert_prediction": herbert_1.prediction,
        "herbert_score": herbert_1.score,
        "distilbert_prediction": distilbert_1.prediction,
        "distilbert_score": distilbert_1.score,           
})

# %%
final_df_1
# Out:
#             case                                   sentence  \
# 0     Nominative              Warszawa to największe <mask>
# 1     Nominative              Warszawa to największe <mask>
# 2     Nominative              Warszawa to największe <mask>
# 3     Nominative              Warszawa to największe <mask>
# 4     Nominative              Warszawa to największe <mask>
# 5       Genitive     Szarlotka <mask> nie ma sobie równych.
# 6       Genitive     Szarlotka <mask> nie ma sobie równych.
# 7       Genitive     Szarlotka <mask> nie ma sobie równych.
# 8       Genitive     Szarlotka <mask> nie ma sobie równych.
# 9       Genitive     Szarlotka <mask> nie ma sobie równych.
# 10        Dative       Mówiłem <mask>, żeby tego nie robił.
# 11        Dative       Mówiłem <mask>, żeby tego nie robił.
# 12        Dative       Mówiłem <mask>, żeby tego nie robił.
# 13        Dative       Mówiłem <mask>, żeby tego nie robił.
# 14        Dative       Mówiłem <mask>, żeby tego nie robił.
# 15    Accusative  Za tym wzniesieniem świetnie widać <mask>
# 16    Accusative  Za tym wzniesieniem świetnie widać <mask>
# 17    Accusative  Za tym wzniesieniem świetnie widać <mask>
# 18    Accusative  Za tym wzniesieniem świetnie widać <mask>
# 19    Accusative  Za tym wzniesieniem świetnie widać <mask>
# 20  Instrumental               Do domu zawsze wracam <mask>
# 21  Instrumental               Do domu zawsze wracam <mask>
# 22  Instrumental               Do domu zawsze wracam <mask>
# 23  Instrumental               Do domu zawsze wracam <mask>
# 24  Instrumental               Do domu zawsze wracam <mask>
# 25      Locative           Przed snem zawsze myślę o <mask>
# 26      Locative           Przed snem zawsze myślę o <mask>
# 27      Locative           Przed snem zawsze myślę o <mask>
# 28      Locative           Przed snem zawsze myślę o <mask>
# 29      Locative           Przed snem zawsze myślę o <mask>
# 30      Vocative                            Ożeż ty <mask>!
# 31      Vocative                            Ożeż ty <mask>!
# 32      Vocative                            Ożeż ty <mask>!
# 33      Vocative                            Ożeż ty <mask>!
# 34      Vocative                            Ożeż ty <mask>!
#
#                        roberta_prediction  roberta_score  \
# 0               Warszawa to największe...       0.296859
# 1           Warszawa to największe miasto       0.164943
# 2                 Warszawa to największe!       0.066985
# 3               Warszawa to największe...       0.053526
# 4             Warszawa to największe city       0.053058
# 5        Szarlotka, nie ma sobie równych.       0.248807
# 6     Szarlotka też nie ma sobie równych.       0.088874
# 7      Szarlotka to nie ma sobie równych.       0.067007
# 8   Szarlotka nigdy nie ma sobie równych.       0.055717
# 9       Szarlotka - nie ma sobie równych.       0.047522
# 10       Mówiłem mu, żeby tego nie robił.       0.632119
# 11    Mówiłem tylko, żeby tego nie robił.       0.069858
# 12      Mówiłem też, żeby tego nie robił.       0.039428
# 13     Mówiłem więc, żeby tego nie robił.       0.013103
# 14    Mówiłem sobie, żeby tego nie robił.       0.012808
# 15    Za tym wzniesieniem świetnie widać.       0.258331
# 16    Za tym wzniesieniem świetnie widać:       0.164342
# 17  Za tym wzniesieniem świetnie widać...       0.107686
# 18    Za tym wzniesieniem świetnie widać,       0.032262
# 19  Za tym wzniesieniem świetnie widać...       0.029251
# 20                 Do domu zawsze wracam.       0.437002
# 21                 Do domu zawsze wracam!       0.118186
# 22                  Do domu zawsze wracam       0.110742
# 23               Do domu zawsze wracam...       0.062515
# 24                 Do domu zawsze wracam,       0.048478
# 25        Przed snem zawsze myślę o sobie       0.667775
# 26          Przed snem zawsze myślę o tym       0.045873
# 27        Przed snem zawsze myślę o czymś       0.033325
# 28           Przed snem zawsze myślę o...       0.024846
# 29      Przed snem zawsze myślę o miłości       0.018643
# 30                              Ożeż tyś!       0.039446
# 31                            Ożeż ty mi!       0.021785
# 32                        Ożeż ty jesteś!       0.013105
# 33                            Ożeż ty ty!       0.011939
# 34                            Ożeż ty tu!       0.011279
#
#                           herbert_prediction  herbert_score  \
# 0              Warszawa to największe miasto       0.853428
# 1                   Warszawa to największe …       0.029933
# 2              Warszawa to największe miasta       0.024026
# 3            Warszawa to największe lotnisko       0.021139
# 4             Warszawa to największe centrum       0.015283
# 5         Szarlotka ta nie ma sobie równych.       0.060571
# 6     Szarlotka jednak nie ma sobie równych.       0.042849
# 7      Szarlotka wciąż nie ma sobie równych.       0.023965
# 8      Szarlotka nadal nie ma sobie równych.       0.020215
# 9        Szarlotka też nie ma sobie równych.       0.019942
# 10          Mówiłem mu, żeby tego nie robił.       0.875042
# 11        Mówiłem jego, żeby tego nie robił.       0.028525
# 12        Mówiłem jemu, żeby tego nie robił.       0.012347
# 13         Mówiłem jej, żeby tego nie robił.       0.009292
# 14          Mówiłem go, żeby tego nie robił.       0.009281
# 15      Za tym wzniesieniem świetnie widać …       0.388190
# 16    Za tym wzniesieniem świetnie widać las       0.090157
# 17   Za tym wzniesieniem świetnie widać góry       0.050575
# 18  Za tym wzniesieniem świetnie widać Tatry       0.045723
# 19       Za tym wzniesieniem świetnie widać.       0.043624
# 20                    Do domu zawsze wracam.       0.724350
# 21                    Do domu zawsze wracam!       0.096530
# 22                   Do domu zawsze wracam …       0.082385
# 23                     Do domu zawsze wracam       0.054737
# 24                    Do domu zawsze wracam,       0.004664
# 25           Przed snem zawsze myślę o sobie       0.139709
# 26           Przed snem zawsze myślę o tobie       0.061666
# 27         Przed snem zawsze myślę o dziecku       0.052898
# 28           Przed snem zawsze myślę o czymś       0.039561
# 29       Przed snem zawsze myślę o dzieciach       0.033191
# 30                           Ożeż ty jesteś!       0.067394
# 31                           Ożeż ty piękna!       0.041071
# 32                             Ożeż ty masz!       0.032108
# 33                             Ożeż ty mały!       0.031196
# 34                           Ożeż ty piękny!       0.029550
#
#                         distilbert_prediction  distilbert_score
# 0               Warszawa to największe miasto          0.558600
# 1               Warszawa to największe miasta          0.103281
# 2               Warszawa to największe Miasto          0.023797
# 3                     Warszawa to największe.          0.013984
# 4                   Warszawa to największesza          0.008158
# 5           Szarlotka 缚 nie ma sobie równych.          0.030699
# 6        Szarlotka wody nie ma sobie równych.          0.028570
# 7         Szarlotka nie nie ma sobie równych.          0.026713
# 8          Szarlotka ta nie ma sobie równych.          0.021784
# 9   Szarlotka człowieka nie ma sobie równych.          0.019279
# 10        Mówiłem sobie, żeby tego nie robił.          0.058699
# 11        Mówiłem wtedy, żeby tego nie robił.          0.043855
# 12        Mówiłem nawet, żeby tego nie robił.          0.038590
# 13          Mówiłem ten, żeby tego nie robił.          0.034820
# 14          Mówiłem nic, żeby tego nie robił.          0.027658
# 15       Za tym wzniesieniem świetnie widać :          0.308803
# 16        Za tym wzniesieniem świetnie widać.          0.031466
# 17     Za tym wzniesieniem świetnie widać sie          0.024153
# 18       Za tym wzniesieniem świetnie widaćły          0.022687
# 19    Za tym wzniesieniem świetnie widać jest          0.011740
# 20                     Do domu zawsze wracam!          0.203006
# 21                     Do domu zawsze wracam?          0.197628
# 22                    Do domu zawsze wracam :          0.112470
# 23                     Do domu zawsze wracam.          0.107126
# 24                Do domu zawsze wracam razem          0.019670
# 25            Przed snem zawsze myślę o Ziemi          0.043152
# 26            Przed snem zawsze myślę o sobie          0.033578
# 27               Przed snem zawsze myślę oczy          0.029788
# 28             Przed snem zawsze myślę o czym          0.029507
# 29               Przed snem zawsze myślę oczu          0.024522
# 30                                  Ożeż ty!!          0.037714
# 31                                  Ożeż tył!          0.019590
# 32                               Ożeż tyczka!          0.017860
# 33                                  Ożeż ty?!          0.017388
# 34                                 Ożeż tygo!          0.012989

# %% [markdown]
# ### Devise a method to test long-range relationships such as gender. E.e. you can use two verbs where withe masculine and feminine gender, where one of the verbs is masked. Both verbs should have the same gender, assuming the subject is the same. Define at least 3 such sentences.

# %%
cases_gender = {
  "sequence_1" : 'Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc <mask> czytać książkę.', #zaczalem
  "sequence_2" : 'Gdy mama, dowiedziała się o stanie zdrowia babci, <mask>, aby się nią zająć.', #przyjechala
  "sequence_3" : 'W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery  i <mask>, że odtąd królestwo będzie przekazywane z ojca na syna.' #oznajmił
}

roberta_2 = test_model(roberta, cases_gender)
herbert_2 = test_model(herbert, cases_gender)
distilbert_2 = test_model(distilbert, cases_gender, True)

# %%
pd.options.display.max_colwidth = 200
print(roberta_2)
# Out:
#           case  \
# 0   sequence_1
# 1   sequence_1
# 2   sequence_1
# 3   sequence_1
# 4   sequence_1
# 5   sequence_2
# 6   sequence_2
# 7   sequence_2
# 8   sequence_2
# 9   sequence_2
# 10  sequence_3
# 11  sequence_3
# 12  sequence_3
# 13  sequence_3
# 14  sequence_3
#
#                                                                                                                                                            content  \
# 0                                                                            Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc <mask> czytać książkę.
# 1                                                                            Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc <mask> czytać książkę.
# 2                                                                            Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc <mask> czytać książkę.
# 3                                                                            Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc <mask> czytać książkę.
# 4                                                                            Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc <mask> czytać książkę.
# 5                                                                                     Gdy mama, dowiedziała się o stanie zdrowia babci, <mask>, aby się nią zająć.
# 6                                                                                     Gdy mama, dowiedziała się o stanie zdrowia babci, <mask>, aby się nią zająć.
# 7                                                                                     Gdy mama, dowiedziała się o stanie zdrowia babci, <mask>, aby się nią zająć.
# 8                                                                                     Gdy mama, dowiedziała się o stanie zdrowia babci, <mask>, aby się nią zająć.
# 9                                                                                     Gdy mama, dowiedziała się o stanie zdrowia babci, <mask>, aby się nią zająć.
# 10  W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery  i <mask>, że odtąd królestwo będzie przekazywane z ojca na syna.
# 11  W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery  i <mask>, że odtąd królestwo będzie przekazywane z ojca na syna.
# 12  W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery  i <mask>, że odtąd królestwo będzie przekazywane z ojca na syna.
# 13  W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery  i <mask>, że odtąd królestwo będzie przekazywane z ojca na syna.
# 14  W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery  i <mask>, że odtąd królestwo będzie przekazywane z ojca na syna.
#
#                                                                                                                                                            prediction  \
# 0                                                                                Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc muszę czytać książkę.
# 1                                                                              Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc zamiast czytać książkę.
# 2                                                                               Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc miałem czytać książkę.
# 3                                                                               Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc zaczął czytać książkę.
# 4                                                                               Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc trzeba czytać książkę.
# 5                                                                                       Gdy mama, dowiedziała się o stanie zdrowia babci, chciała, aby się nią zająć.
# 6                                                                                       Gdy mama, dowiedziała się o stanie zdrowia babci, zaczęła, aby się nią zająć.
# 7                                                                                    Gdy mama, dowiedziała się o stanie zdrowia babci, postanowił, aby się nią zająć.
# 8                                                                                    Gdy mama, dowiedziała się o stanie zdrowia babci, powiedział, aby się nią zająć.
# 9                                                                                    Gdy mama, dowiedziała się o stanie zdrowia babci, zdecydował, aby się nią zająć.
# 10  W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery i powiedział, że odtąd królestwo będzie przekazywane z ojca na syna.
# 11       W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery i mówił, że odtąd królestwo będzie przekazywane z ojca na syna.
# 12  W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery i stwierdził, że odtąd królestwo będzie przekazywane z ojca na syna.
# 13    W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery i wiedział, że odtąd królestwo będzie przekazywane z ojca na syna.
# 14  W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery i zdecydował, że odtąd królestwo będzie przekazywane z ojca na syna.
#
#        score
# 0   0.271607
# 1   0.176417
# 2   0.140931
# 3   0.074916
# 4   0.070158
# 5   0.292583
# 6   0.152909
# 7   0.146143
# 8   0.062336
# 9   0.057131
# 10  0.576168
# 11  0.087082
# 12  0.067708
# 13  0.066876
# 14  0.053347

# %%
print(herbert_2)
# Out:
#           case  \
# 0   sequence_1
# 1   sequence_1
# 2   sequence_1
# 3   sequence_1
# 4   sequence_1
# 5   sequence_2
# 6   sequence_2
# 7   sequence_2
# 8   sequence_2
# 9   sequence_2
# 10  sequence_3
# 11  sequence_3
# 12  sequence_3
# 13  sequence_3
# 14  sequence_3
#
#                                                                                                                                                            content  \
# 0                                                                            Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc <mask> czytać książkę.
# 1                                                                            Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc <mask> czytać książkę.
# 2                                                                            Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc <mask> czytać książkę.
# 3                                                                            Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc <mask> czytać książkę.
# 4                                                                            Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc <mask> czytać książkę.
# 5                                                                                     Gdy mama, dowiedziała się o stanie zdrowia babci, <mask>, aby się nią zająć.
# 6                                                                                     Gdy mama, dowiedziała się o stanie zdrowia babci, <mask>, aby się nią zająć.
# 7                                                                                     Gdy mama, dowiedziała się o stanie zdrowia babci, <mask>, aby się nią zająć.
# 8                                                                                     Gdy mama, dowiedziała się o stanie zdrowia babci, <mask>, aby się nią zająć.
# 9                                                                                     Gdy mama, dowiedziała się o stanie zdrowia babci, <mask>, aby się nią zająć.
# 10  W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery  i <mask>, że odtąd królestwo będzie przekazywane z ojca na syna.
# 11  W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery  i <mask>, że odtąd królestwo będzie przekazywane z ojca na syna.
# 12  W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery  i <mask>, że odtąd królestwo będzie przekazywane z ojca na syna.
# 13  W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery  i <mask>, że odtąd królestwo będzie przekazywane z ojca na syna.
# 14  W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery  i <mask>, że odtąd królestwo będzie przekazywane z ojca na syna.
#
#                                                                                                                                                              prediction  \
# 0                                                                              Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc poszedłem czytać książkę.
# 1                                                                               Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc zacząłem czytać książkę.
# 2                                                                               Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc musiałem czytać książkę.
# 3                                                                           Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc postanowiłem czytać książkę.
# 4                                                                             Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc pojechałem czytać książkę.
# 5                                                                                       Gdy mama, dowiedziała się o stanie zdrowia babci, poprosiła, aby się nią zająć.
# 6                                                                                     Gdy mama, dowiedziała się o stanie zdrowia babci, postanowiła, aby się nią zająć.
# 7                                                                                         Gdy mama, dowiedziała się o stanie zdrowia babci, prosiła, aby się nią zająć.
# 8                                                                                   Gdy mama, dowiedziała się o stanie zdrowia babci, zaproponowała, aby się nią zająć.
# 9                                                                                        Gdy mama, dowiedziała się o stanie zdrowia babci, przyszła, aby się nią zająć.
# 10       W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery i obiecał, że odtąd królestwo będzie przekazywane z ojca na syna.
# 11  W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery i zapowiedział, że odtąd królestwo będzie przekazywane z ojca na syna.
# 12       W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery i ogłosił, że odtąd królestwo będzie przekazywane z ojca na syna.
# 13    W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery i postanowił, że odtąd królestwo będzie przekazywane z ojca na syna.
# 14       W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery i wierzył, że odtąd królestwo będzie przekazywane z ojca na syna.
#
#        score
# 0   0.490908
# 1   0.258044
# 2   0.099232
# 3   0.038085
# 4   0.025592
# 5   0.304587
# 6   0.146300
# 7   0.141541
# 8   0.074721
# 9   0.068042
# 10  0.143351
# 11  0.118467
# 12  0.109620
# 13  0.077653
# 14  0.073443

# %%
print(distilbert_2)
# Out:
#           case  \
# 0   sequence_1
# 1   sequence_1
# 2   sequence_1
# 3   sequence_1
# 4   sequence_1
# 5   sequence_2
# 6   sequence_2
# 7   sequence_2
# 8   sequence_2
# 9   sequence_2
# 10  sequence_3
# 11  sequence_3
# 12  sequence_3
# 13  sequence_3
# 14  sequence_3
#
#                                                                                                                                                            content  \
# 0                                                                            Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc [MASK] czytać książkę.
# 1                                                                            Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc [MASK] czytać książkę.
# 2                                                                            Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc [MASK] czytać książkę.
# 3                                                                            Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc [MASK] czytać książkę.
# 4                                                                            Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc [MASK] czytać książkę.
# 5                                                                                     Gdy mama, dowiedziała się o stanie zdrowia babci, [MASK], aby się nią zająć.
# 6                                                                                     Gdy mama, dowiedziała się o stanie zdrowia babci, [MASK], aby się nią zająć.
# 7                                                                                     Gdy mama, dowiedziała się o stanie zdrowia babci, [MASK], aby się nią zająć.
# 8                                                                                     Gdy mama, dowiedziała się o stanie zdrowia babci, [MASK], aby się nią zająć.
# 9                                                                                     Gdy mama, dowiedziała się o stanie zdrowia babci, [MASK], aby się nią zająć.
# 10  W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery  i [MASK], że odtąd królestwo będzie przekazywane z ojca na syna.
# 11  W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery  i [MASK], że odtąd królestwo będzie przekazywane z ojca na syna.
# 12  W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery  i [MASK], że odtąd królestwo będzie przekazywane z ojca na syna.
# 13  W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery  i [MASK], że odtąd królestwo będzie przekazywane z ojca na syna.
# 14  W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery  i [MASK], że odtąd królestwo będzie przekazywane z ojca na syna.
#
#                                                                                                                                                      prediction  \
# 0                                                                            Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc nie czytać książkę.
# 1                                                                           Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc dana czytać książkę.
# 2                                                                           Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc miał czytać książkę.
# 3                                                                            Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc ich czytać książkę.
# 4                                                                              Chciałem iść na lodowisko, ale zaczęła się burza śnieżna, więc 寓 czytać książkę.
# 5                                                                                       Gdy mama, dowiedziała się o stanie zdrowia babci, 魂, aby się nią zająć.
# 6                                                                                     Gdy mama, dowiedziała się o stanie zdrowia babci, aby, aby się nią zająć.
# 7                                                                                    Gdy mama, dowiedziała się o stanie zdrowia babci, dana, aby się nią zająć.
# 8                                                                                      Gdy mama, dowiedziała się o stanie zdrowia babci,няя, aby się nią zająć.
# 9                                                                                       Gdy mama, dowiedziała się o stanie zdrowia babci, ἶ, aby się nią zająć.
# 10  W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery i syna, że odtąd królestwo będzie przekazywane z ojca na syna.
# 11  W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery i برخی, że odtąd królestwo będzie przekazywane z ojca na syna.
# 12  W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery i ojca, że odtąd królestwo będzie przekazywane z ojca na syna.
# 13  W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery i tego, że odtąd królestwo będzie przekazywane z ojca na syna.
# 14     W jednej z wersji Edyp z Koryntu podbił Teby, został królem, poślubił Jokastę, kapłankę Hery i ঋ, że odtąd królestwo będzie przekazywane z ojca na syna.
#
#        score
# 0   0.084894
# 1   0.051495
# 2   0.026153
# 3   0.019836
# 4   0.019002
# 5   0.052176
# 6   0.044421
# 7   0.043734
# 8   0.041824
# 9   0.033350
# 10  0.054007
# 11  0.045445
# 12  0.036182
# 13  0.032855
# 14  0.024448

# %% [markdown]
# ### Check if the model captures real-world knolwedge. For instance a sentence "[MASK] wrze w temperaturze 100 stopni, a zamarza w temperaturze 0 stopni Celsjusza." checks if the model "knows" the description of water. Define at least 3 such sentences.

# %%
cases_knowledge = {
    'sequence_1' : "<mask> wrze w temperaturze 100 stopni, a zamarza w temperaturze 0 stopni Celsjusza.",
    'sequence_2' : "Mount <mask> to najwyższy szczyt świata.",
    'sequence_3' : "Powietrze składa się głownie z azotu i <mask>.",
}

roberta_3 = test_model(roberta, cases_knowledge)
herbert_3 = test_model(herbert, cases_knowledge)
distilbert_3 = test_model(distilbert, cases_knowledge, True)

# %%
final_df_3 = pd.DataFrame({
        "case": roberta_3.case, 
        "sentence": roberta_3.content,
        "roberta_prediction": roberta_3.prediction,
        "roberta_score": roberta_3.score,
        "herbert_prediction": herbert_3.prediction,
        "herbert_score": herbert_3.score,
        "distilbert_prediction": distilbert_3.prediction,
        "distilbert_score": distilbert_3.score,           
})

# %%
final_df_3
# Out:
#           case  \
# 0   sequence_1
# 1   sequence_1
# 2   sequence_1
# 3   sequence_1
# 4   sequence_1
# 5   sequence_2
# 6   sequence_2
# 7   sequence_2
# 8   sequence_2
# 9   sequence_2
# 10  sequence_3
# 11  sequence_3
# 12  sequence_3
# 13  sequence_3
# 14  sequence_3
#
#                                                                                sentence  \
# 0   <mask> wrze w temperaturze 100 stopni, a zamarza w temperaturze 0 stopni Celsjusza.
# 1   <mask> wrze w temperaturze 100 stopni, a zamarza w temperaturze 0 stopni Celsjusza.
# 2   <mask> wrze w temperaturze 100 stopni, a zamarza w temperaturze 0 stopni Celsjusza.
# 3   <mask> wrze w temperaturze 100 stopni, a zamarza w temperaturze 0 stopni Celsjusza.
# 4   <mask> wrze w temperaturze 100 stopni, a zamarza w temperaturze 0 stopni Celsjusza.
# 5                                              Mount <mask> to najwyższy szczyt świata.
# 6                                              Mount <mask> to najwyższy szczyt świata.
# 7                                              Mount <mask> to najwyższy szczyt świata.
# 8                                              Mount <mask> to najwyższy szczyt świata.
# 9                                              Mount <mask> to najwyższy szczyt świata.
# 10                                       Powietrze składa się głownie z azotu i <mask>.
# 11                                       Powietrze składa się głownie z azotu i <mask>.
# 12                                       Powietrze składa się głownie z azotu i <mask>.
# 13                                       Powietrze składa się głownie z azotu i <mask>.
# 14                                       Powietrze składa się głownie z azotu i <mask>.
#
#                                                                           roberta_prediction  \
# 0     Najlepiej wrze w temperaturze 100 stopni, a zamarza w temperaturze 0 stopni Celsjusza.
# 1             - wrze w temperaturze 100 stopni, a zamarza w temperaturze 0 stopni Celsjusza.
# 2   Najczęściej wrze w temperaturze 100 stopni, a zamarza w temperaturze 0 stopni Celsjusza.
# 3             – wrze w temperaturze 100 stopni, a zamarza w temperaturze 0 stopni Celsjusza.
# 4     Następnie wrze w temperaturze 100 stopni, a zamarza w temperaturze 0 stopni Celsjusza.
# 5                                                  Mount Everest to najwyższy szczyt świata.
# 6                                              Mount Kilimanjaro to najwyższy szczyt świata.
# 7                                                     Mount Fuji to najwyższy szczyt świata.
# 8                                                   Mount Carmel to najwyższy szczyt świata.
# 9                                                     Mount Buda to najwyższy szczyt świata.
# 10                                              Powietrze składa się głownie z azotu i soli.
# 11                                             Powietrze składa się głownie z azotu i cukru.
# 12                                              Powietrze składa się głownie z azotu i wody.
# 13                                              Powietrze składa się głownie z azotu i sera.
# 14                                             Powietrze składa się głownie z azotu i mleka.
#
#     roberta_score  \
# 0        0.114664
# 1        0.101124
# 2        0.040480
# 3        0.036354
# 4        0.033539
# 5        0.853797
# 6        0.106505
# 7        0.021932
# 8        0.005713
# 9        0.000958
# 10       0.337075
# 11       0.198842
# 12       0.101104
# 13       0.034029
# 14       0.028578
#
#                                                                         herbert_prediction  \
# 0        Woda wrze w temperaturze 100 stopni, a zamarza w temperaturze 0 stopni Celsjusza.
# 1      Słońce wrze w temperaturze 100 stopni, a zamarza w temperaturze 0 stopni Celsjusza.
# 2      Ziemia wrze w temperaturze 100 stopni, a zamarza w temperaturze 0 stopni Celsjusza.
# 3   Następnie wrze w temperaturze 100 stopni, a zamarza w temperaturze 0 stopni Celsjusza.
# 4       Ciało wrze w temperaturze 100 stopni, a zamarza w temperaturze 0 stopni Celsjusza.
# 5                                                    Mount Sky to najwyższy szczyt świata.
# 6                                                    Mount Ben to najwyższy szczyt świata.
# 7                                                   Mount Hill to najwyższy szczyt świata.
# 8                                                 Mount Rashid to najwyższy szczyt świata.
# 9                                                Mount Jackson to najwyższy szczyt świata.
# 10                                          Powietrze składa się głownie z azotu i siarki.
# 11                                           Powietrze składa się głownie z azotu i tlenu.
# 12                                           Powietrze składa się głownie z azotu i węgla.
# 13                                            Powietrze składa się głownie z azotu i wody.
# 14                                           Powietrze składa się głownie z azotu i azotu.
#
#     herbert_score  \
# 0        0.361990
# 1        0.045598
# 2        0.040449
# 3        0.029731
# 4        0.022546
# 5        0.319353
# 6        0.089540
# 7        0.046483
# 8        0.044928
# 9        0.025725
# 10       0.295419
# 11       0.243216
# 12       0.157169
# 13       0.046878
# 14       0.037369
#
#                                                               distilbert_prediction  \
# 0   Na wrze w temperaturze 100 stopni, a zamarza w temperaturze 0 stopni Celsjusza.
# 1   We wrze w temperaturze 100 stopni, a zamarza w temperaturze 0 stopni Celsjusza.
# 2   Od wrze w temperaturze 100 stopni, a zamarza w temperaturze 0 stopni Celsjusza.
# 3    W wrze w temperaturze 100 stopni, a zamarza w temperaturze 0 stopni Celsjusza.
# 4   we wrze w temperaturze 100 stopni, a zamarza w temperaturze 0 stopni Celsjusza.
# 5                                           Mount Jerzy to najwyższy szczyt świata.
# 6                                               Mount 僅 to najwyższy szczyt świata.
# 7                                            Mount Fuji to najwyższy szczyt świata.
# 8                                          Mount Terror to najwyższy szczyt świata.
# 9                                         Mount Everest to najwyższy szczyt świata.
# 10                                     Powietrze składa się głownie z azotu i wody.
# 11                                    Powietrze składa się głownie z azotu i ziemi.
# 12                                     Powietrze składa się głownie z azotu i lata.
# 13                                     Powietrze składa się głownie z azotu i soli.
# 14                                  Powietrze składa się głownie z azotu i борбору.
#
#     distilbert_score
# 0           0.088129
# 1           0.049293
# 2           0.033522
# 3           0.032501
# 4           0.029776
# 5           0.117299
# 6           0.087421
# 7           0.021483
# 8           0.011461
# 9           0.009276
# 10          0.461502
# 11          0.073745
# 12          0.026659
# 13          0.023160
# 14          0.014069

# %% [markdown]
# ### Answer the following questions:
# - Which of the models produced the best results?
# - Was any of the models able to capture Polish grammar?
# - Was any of the models able to capture long-distant relationships between the words?
# - Was any of the models able to capture world knowledge?
# - What are the most striking errors made by the models?

# %% [markdown]
# W 1, 2 i 3 zadaniu herbert był najlepszy.
#
# Bywa różnie, raz lepiej sobie radzą z gramatyką raz gorzej.
#
# Tak, herbert.
#
# Nie do końca. Nie zawsze prawidłowa odpowiedź miała największy score.
